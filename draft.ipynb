# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The Art of the Blockbuster
#
# **Author:** Jake Sherman
# ***

# %% [markdown]
# ## Overview
#
# While many typical Hollywood hits tend to be rather formulaic, producing the next big movie is anything but.  The problem with producing movies is the unpredictable nature of their profitability.  This notebook a analyzes production budget, genre, and film runtime to see if the art of the blockbuster is really more of a science.
#
# Findings show that low budget movies have the highest ROI on average, horror is the most profitable genre, and runtime is more of a dependent variable than profitability indicator.

# %% [markdown]
# ## Business Problem
#
# Producing a movie is extremely capital intensive and unlike traditional investments, a movie can bomb and leave investors with a total loss of investment in the blink of an eye.  There is extremely high volatility in performance relative to other investments, that is, often times movies are hit or miss.  This analysis aims to look at data, specifically relating to runtime, production budget, and film genre to see if there are ways a production company can focus its business plan to optimize profitability.

# %% [markdown]
# ## Data Understanding
#
# Data being used comes from a csv database containing information related to production budget and worldwide gross to determine the films ROI.  This dataframe was merged with a SQL database containing runtime and genre information. The target variable is ROI or return on investment which is calculated as ((worldwide theatrical gross / production budget -1)*100). The analysis looks at how ROI is affected by changes in runtime, genre, and production budget.
#
# Alternatively, another dataframe was created that contained only data from films that were considered a 'success' by this analysis.  The requirement for 'success' was if a film returned double its production budget or achieved an ROI of 100%.  This method is more focused on reliability of performance and reduces emphasis on outlier returns.

# %%
#Importing relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import csv


# %matplotlib inline

# %%
#Naming Data Files
box_office= pd.read_csv('zippedData/bom.movie_gross.csv.gz', compression= 'gzip')
movie_budgets= pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
movie_info= pd.read_csv('zippedData/tmdb.movies.csv.gz')
dw= pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep= '\t')
movie_reviews= pd.read_csv('zippedData/rt.reviews.tsv.gz', sep= '\t', encoding= 'unicode_escape')
#! unzip -n zippedData/im.db
conn = sqlite3.connect('zippedData/imdb.db')
cur = conn.cursor()
tables_query = '''SELECT name FROM sqlite_master WHERE type = 'table';'''
cur.execute(tables_query)
print(cur.fetchall())
# Out:
# [('movie_basics',), ('directors',), ('known_for',), ('movie_akas',), ('movie_ratings',), ('persons',), ('principals',), ('writers',)]

# %%
cur.execute('''SELECT primary_title, genres, runtime_minutes, start_year  FROM movie_basics;''')
cur.fetchall()
# Out:
# [('Sunghursh', 'Action,Crime,Drama', 175.0, 2013),
#  ('One Day Before the Rainy Season', 'Biography,Drama', 114.0, 2019),
#  ('The Other Side of the Wind', 'Drama', 122.0, 2018),
#  ('Sabse Bada Sukh', 'Comedy,Drama', None, 2018),
#  ('The Wandering Soap Opera', 'Comedy,Drama,Fantasy', 80.0, 2017),
#  ('A Thin Life', 'Comedy', 75.0, 2018),
#  ('Bigfoot', 'Horror,Thriller', None, 2017),
#  ('Joe Finds Grace', 'Adventure,Animation,Comedy', 83.0, 2017),
#  ('O Silêncio', 'Documentary,History', None, 2012),
#  ('Nema aviona za Zagreb', 'Biography', 82.0, 2012),
#  ('Pál Adrienn', 'Drama', 136.0, 2010),
#  ('So Much for Justice!', 'History', 100.0, 2010),
#  ('Cooper and Hemingway: The True Gen', 'Documentary', 180.0, 2013),
#  ('Children of the Green Dragon', 'Drama', 89.0, 2010),
#  ('T.G.M. - osvoboditel', 'Documentary', 60.0, 2018),
#  ('The Tragedy of Man', 'Animation,Drama,History', 160.0, 2011),
#  ("How Huang Fei-hong Rescued the Orphan from the Tiger's Den",
#   None,
#   None,
#   2011),
#  ('Heaven & Hell', 'Drama', 104.0, 2018),
#  ('The Final Journey', 'Drama', 120.0, 2010),
#  ('Los pájaros se van con la muerte', 'Drama,Mystery', 110.0, 2011),
#  ('Foodfight!', 'Action,Animation,Comedy', 91.0, 2012),
#  ('Godfather', 'Crime,Drama', None, 2012),
#  ('Gangavataran', None, 134.0, 2018),
#  ('Return to Babylon', 'Biography,Comedy,Drama', 75.0, 2013),
#  ('Akakis mogzauroba', 'Documentary', 44.0, 2012),
#  ('Seven Jews from My Class', 'Documentary', 40.0, 2018),
#  ('On kadin', 'Drama', None, 2019),
#  ('To Chase a Million', 'Action,Drama', 97.0, 2018),
#  ('Prague: The Restless Heart of Europe', 'Documentary,History', 59.0, 2018),
#  ('Short Time Heroes', 'Sci-Fi', 45.0, 2015),
#  ("Life's a Beach", 'Comedy', 100.0, 2012),
#  ('Abolição', 'Documentary', None, 2019),
#  ('Dark Blood', 'Thriller', 86.0, 2012),
#  ('Mortal Kombat', 'Action,Adventure,Fantasy', None, 2021),
#  ('Snowblind', 'Crime,Drama', None, 2015),
#  ('Second Coming', None, 95.0, 2012),
#  ('Lives No Longer Ours', 'Drama,Romance', 90.0, 2011),
#  ('Quantum Quest: A Cassini Space Odyssey',
#   'Adventure,Animation,Sci-Fi',
#   45.0,
#   2010),
#  ('Wazir', 'Action,Crime,Drama', 103.0, 2016),
#  ('The Wicker Tree', 'Drama,Horror', 96.0, 2011),
#  ('The Overnight', None, 88.0, 2010),
#  ('In My Sleep', 'Drama,Mystery,Thriller', 104.0, 2010),
#  ('My Land', 'Drama,Family', 102.0, 2018),
#  ('Rice Girl', 'Adventure,Comedy,Romance', 95.0, 2014),
#  ('Regret Not Speaking', None, None, 2011),
#  ('Tiden är en dröm, del 2', None, 109.0, 2014),
#  ('This Wretched Life', 'Comedy,Drama', 99.0, 2010),
#  ('Bunyan and Babe', 'Adventure,Animation,Comedy', 84.0, 2017),
#  ('On the Road', 'Adventure,Drama,Romance', 124.0, 2012),
#  ('Blind Sided', 'Comedy,Crime,Drama', None, 2010),
#  ('Chatô - The King of Brazil', 'Biography', 102.0, 2015),
#  ('The Evil Within', 'Horror', 98.0, 2017),
#  ('Transeúntes', 'Comedy,Drama', 101.0, 2015),
#  ('Haar Jeet', 'Drama', None, 2018),
#  ('The Secret Life of Walter Mitty', 'Adventure,Comedy,Drama', 114.0, 2013),
#  ('Fahrenheit 451', 'Drama,Sci-Fi,Thriller', 100.0, 2018),
#  ('Aman Ke Farishtey', 'Action', 137.0, 2016),
#  ('Nappily Ever After', 'Comedy,Drama,Romance', 98.0, 2018),
#  ('A Walk Among the Tombstones', 'Action,Crime,Drama', 114.0, 2014),
#  ('The Promise of Perfume', 'Documentary', 57.0, 2017),
#  ('Jurassic World', 'Action,Adventure,Sci-Fi', 124.0, 2015),
#  ('Spy', 'Action,Crime,Drama', 110.0, 2011),
#  ('The Rum Diary', 'Comedy,Drama', 119.0, 2011),
#  ('American Pastoral', 'Crime,Drama', 108.0, 2016),
#  ('Gnomeo & Juliet', 'Adventure,Animation,Comedy', 84.0, 2011),
#  ('The Payback Man', 'Crime,Drama,Thriller', None, 2010),
#  ('Cloud Cuckoo Land', 'Drama', 92.0, 2012),
#  ('The Three Stooges', 'Comedy,Family', 92.0, 2012),
#  ('Motherless Brooklyn', 'Crime,Drama', None, 2019),
#  ("Anderson's Cross", 'Comedy,Drama,Romance', 98.0, 2010),
#  ('Den milde smerte', 'Drama', 280.0, 2010),
#  ('Tangled', 'Adventure,Animation,Comedy', 100.0, 2010),
#  ('The Connecticut Kid', 'Adventure', 87.0, 2011),
#  ('John Carter', 'Action,Adventure,Sci-Fi', 132.0, 2012),
#  ('Capture the Flag', 'Drama', None, 2010),
#  ('Burnt by the Sun 2', 'Drama,History,War', 181.0, 2010),
#  ('Action Jackson', 'Action,Thriller', 144.0, 2014),
#  ('Gambit', 'Comedy,Crime', 89.0, 2012),
#  ('Bubbles', 'Drama', 80.0, 2011),
#  ('Seven Fallen Objects', 'Comedy,Drama', 90.0, 2011),
#  ('In Secret', 'Crime,Drama,Thriller', 107.0, 2013),
#  ('Cowboys & Aliens', 'Action,Sci-Fi,Thriller', 119.0, 2011),
#  ('Tekken', 'Action,Crime,Drama', 87.0, 2010),
#  ('Asleep in the Sun', 'Fantasy', 83.0, 2010),
#  ('Hempsters: Plant the Seed', 'Documentary', 90.0, 2010),
#  ('Disconnect', 'Drama,Mystery,Sci-Fi', 112.0, 2010),
#  ('The Stanford Prison Experiment', 'Biography,Drama,History', 122.0, 2015),
#  ('Venus & Vegas', 'Action,Comedy,Crime', 95.0, 2010),
#  ('The Ninth Cloud', 'Drama', 93.0, 2014),
#  ('El borde del tiempo', 'Drama', 100.0, 2011),
#  ('Beisbol', 'Documentary', None, 2010),
#  ('Pots and Pans', 'Drama', None, 2012),
#  ('Dinner for Schmucks', 'Comedy', 114.0, 2010),
#  ('Masters of the Universe', 'Action,Adventure,Drama', None, 2021),
#  ('A Million Little Pieces', 'Drama', 113.0, 2018),
#  ('The A-Team', 'Action,Adventure,Thriller', 117.0, 2010),
#  ('The Rescuer', 'Documentary', 84.0, 2011),
#  ('The Possession', 'Horror,Mystery,Thriller', 92.0, 2012),
#  ('The Queen of Sheba Meets the Atom Man', 'Comedy', 110.0, 2018),
#  ('Real Steel', 'Action,Drama,Family', 127.0, 2011),
#  ('Satin', 'Comedy,Drama,Music', 84.0, 2011),
#  ('Caleuche: El llamado del Mar', 'Drama,Fantasy,Horror', 100.0, 2012),
#  ("L'apocalisse delle scimmie", 'Drama', None, 2012),
#  ('The Giver', 'Drama,Romance,Sci-Fi', 97.0, 2014),
#  ('Toy Story 3', 'Adventure,Animation,Comedy', 103.0, 2010),
#  ('Mexican Devil', 'Horror,Thriller', None, 2010),
#  ('A Life in the Death of Joe Meek', 'Documentary', 122.0, 2013),
#  ('Alita: Battle Angel', 'Action,Adventure,Sci-Fi', 122.0, 2019),
#  ('Cargo, les hommes perdus.', 'Adventure,Romance', 93.0, 2010),
#  ('Sealand', 'Biography,Drama', None, 2019),
#  ('Moving Target', 'Drama,Thriller', None, 2011),
#  ('Segurança Nacional', 'Action', 86.0, 2010),
#  ('Stolen Memories', 'Documentary', None, 2012),
#  ('My Nappy Roots: A Journey Through Black Hair-itage',
#   'Documentary',
#   90.0,
#   2010),
#  ('Danger Close: The Battle of Long Tan', 'Action,Drama,War', None, 2019),
#  ('Lincoln', 'Biography,Drama,History', 150.0, 2012),
#  ('Milenge Milenge', 'Drama,Romance', 109.0, 2010),
#  ('Before We Go', 'Comedy,Drama,Romance', 95.0, 2014),
#  ('The History of Love', 'Drama,Romance,War', 134.0, 2016),
#  ('Vidas pequeñas', 'Drama', 115.0, 2010),
#  ('7 Days', 'Crime,Drama,Horror', 105.0, 2010),
#  ('Scott Pilgrim vs. the World', 'Action,Comedy,Fantasy', 112.0, 2010),
#  ('Dream Street', 'Drama', None, 2010),
#  ('Surviving in L.A.', 'Comedy,Drama,Romance', None, 2019),
#  ('A Bird of the Air', 'Drama,Romance', 108.0, 2011),
#  ('Shazam!', 'Action,Adventure,Comedy', 132.0, 2019),
#  ('Puss in Boots', 'Action,Adventure,Animation', 90.0, 2011),
#  ('Diary of a Bad Lad', 'Comedy,Crime', 92.0, 2010),
#  ('Mad World', 'Drama', 98.0, 2010),
#  ('The Passing', 'Horror', 92.0, 2011),
#  ('Clawed', 'Horror', 95.0, 2017),
#  ('Wonder Woman', 'Action,Adventure,Fantasy', 141.0, 2017),
#  ('Blunt Movie', 'Comedy,Romance', 83.0, 2013),
#  ('Party Crashers', 'Comedy', 88.0, 2012),
#  ('42', 'Biography,Drama,Sport', 128.0, 2013),
#  ('El hada buena - Una fábula peronista', 'Comedy,Drama,Sci-Fi', 85.0, 2010),
#  ('Life of Pi', 'Adventure,Drama,Fantasy', 127.0, 2012),
#  ('Being Flynn', 'Drama', 102.0, 2012),
#  ('The Crazies', 'Horror,Thriller', 101.0, 2010),
#  ('The Equalizer', 'Action,Crime,Thriller', 132.0, 2014),
#  ('Memorias del desarrollo', 'Drama', 113.0, 2010),
#  ('Captain America: The First Avenger',
#   'Action,Adventure,Sci-Fi',
#   124.0,
#   2011),
#  ('A Long Way Down', 'Comedy,Drama', 96.0, 2014),
#  ('Sin City: A Dame to Kill For', 'Crime,Thriller', 102.0, 2014),
#  ('Generation P', 'Comedy,Drama,Sci-Fi', 112.0, 2011),
#  ('One Step Beyond: The True Story of Géraldine Fasnacht',
#   'Documentary',
#   56.0,
#   2012),
#  ('Drunkboat', 'Drama', 98.0, 2010),
#  ('The Grasslands', 'Drama', 114.0, 2011),
#  ('The Only Living Boy in New York', 'Drama', 89.0, 2017),
#  ("Texxas Jam '78", 'Documentary', 60.0, 2012),
#  ('Saving Private Perez', 'Adventure,Comedy,Western', 105.0, 2011),
#  ('Steve Phoenix: The Untold Story', 'Drama', 110.0, 2012),
#  ('High-Rise', 'Drama,Horror,Sci-Fi', 119.0, 2015),
#  ('Satan Hates You', 'Horror', 94.0, 2010),
#  ('Silent Alarm', 'Comedy,Drama,Thriller', 82.0, 2011),
#  ('Federal', 'Drama,Thriller', 91.0, 2010),
#  ('The Devil You Know', 'Mystery,Thriller', 76.0, 2013),
#  ('Guns, Drugs and Dirty Money', 'Action,Comedy,Crime', 123.0, 2010),
#  ('House at the End of the Drive', 'Horror,Thriller', 91.0, 2014),
#  ('Piranha 3D', 'Comedy,Horror', 88.0, 2010),
#  ('Komaram Puli', 'Action,Crime,Thriller', 163.0, 2010),
#  ('Act Your Age', 'Comedy,Drama', 101.0, 2011),
#  ('Taken by Force', 'Action,Drama', 90.0, 2010),
#  ('Sensual', 'Drama', 99.0, 2010),
#  ('Golapi Ekhon Bilatey', 'Musical', None, 2010),
#  ('Margaret', 'Drama', 150.0, 2011),
#  ('Alan Partridge', 'Action,Comedy,Crime', 90.0, 2013),
#  ('Harlem Hostel', 'Comedy,Drama', 81.0, 2010),
#  ('Smoking/Non-Smoking', 'Drama', 84.0, 2011),
#  ('Platinum Illusions', 'Action,Drama', None, 2011),
#  ('Ex Machina', 'Drama,Mystery,Sci-Fi', 108.0, 2014),
#  ('Hot Country, Cold Winter', 'Drama', 104.0, 2016),
#  ('Tower Heist', 'Action,Comedy,Crime', 104.0, 2011),
#  ('The Smurfs', 'Adventure,Animation,Comedy', 103.0, 2011),
#  ('The Mechanic', 'Action,Crime,Thriller', 93.0, 2011),
#  ('Escape from Heaven', 'Comedy,Fantasy', None, 2018),
#  ('Prince of Persia: The Sands of Time',
#   'Action,Adventure,Fantasy',
#   116.0,
#   2010),
#  ('Stan', 'Comedy', None, 2011),
#  ('Bamboo Shark', 'Comedy', None, 2011),
#  ('Cielito lindo', 'Drama,Thriller', 91.0, 2010),
#  ('Clutch', 'Action,Drama', None, 2012),
#  ('Hail, Caesar!', 'Comedy,Drama,Music', 106.0, 2016),
#  ('Persona Au Gratin', 'Comedy', 93.0, 2012),
#  ('The Deafening Silence of a Very Bright Light', 'Drama', 92.0, 2010),
#  ('Stiffs', 'Comedy', 104.0, 2010),
#  ('Unstoppable', 'Action,Thriller', 98.0, 2010),
#  ('Sid Bernstein Presents...', 'Documentary', 100.0, 2010),
#  ('Extremely Loud & Incredibly Close', 'Adventure,Drama,Mystery', 129.0, 2011),
#  ('The Tree of Life', 'Drama,Fantasy', 139.0, 2011),
#  ('El horror de la dama del lago', 'Fantasy,Horror,Thriller', 90.0, 2010),
#  ('Ant-Man', 'Action,Adventure,Comedy', 117.0, 2015),
#  ('The Greater Meaning of Water', 'Drama,Sport', 60.0, 2010),
#  ('Perfect Life', 'Horror,Thriller', 98.0, 2010),
#  ('Abhishapt', 'Drama', None, 2011),
#  ('Season of the Witch', 'Action,Adventure,Fantasy', 95.0, 2011),
#  ('Atlas Shrugged: Part I', 'Drama,Mystery,Sci-Fi', 97.0, 2011),
#  ('The Losers', 'Action,Adventure,Crime', 97.0, 2010),
#  ('Hall Pass', 'Comedy,Romance', 105.0, 2011),
#  ('Felix Austria!', 'Biography,Documentary,History', 77.0, 2013),
#  ('The Croods', 'Action,Adventure,Animation', 98.0, 2013),
#  ('Bandage', 'Drama,Music,Romance', 119.0, 2010),
#  ('Barry Munday', 'Comedy,Drama,Romance', 95.0, 2010),
#  ('Chasing 3000', 'Family,Sport', 115.0, 2010),
#  ('Monkey Man', 'Comedy', None, 2011),
#  ('A Woman Is a Woman', 'Comedy,Drama', 102.0, 2010),
#  ('Gente mala del norte', 'Drama,History', 97.0, 2011),
#  ('La daga de Rasputín', 'Adventure,Comedy', 99.0, 2011),
#  ('U Want Me 2 Kill Him?', 'Drama,Thriller', 92.0, 2013),
#  ('Sushi in Suhl', 'Comedy,Drama', 100.0, 2012),
#  ('Red Tails', 'Action,Adventure,Drama', 125.0, 2012),
#  ('Making Change', 'Drama', 94.0, 2012),
#  ('Aftermath', 'Crime,Thriller', 84.0, 2013),
#  ('PrimeMates', 'Comedy,Drama', 82.0, 2010),
#  ('Silence', 'Adventure,Drama,History', 161.0, 2016),
#  ('The Invited', 'Horror,Thriller', 95.0, 2010),
#  ('Double Tap', 'Action,Crime,Drama', 100.0, 2011),
#  ('Something Borrowed', 'Comedy,Drama,Romance', 112.0, 2011),
#  ('Suburbicon', 'Comedy,Crime,Drama', 105.0, 2017),
#  ('Tulip Fever', 'Drama,History,Romance', 105.0, 2017),
#  ('Furry Vengeance', 'Comedy,Family', 92.0, 2010),
#  ('Nina', 'Biography,Drama,Music', 90.0, 2016),
#  ('CHIPS', 'Action,Comedy,Crime', 100.0, 2017),
#  ('Ramona and Beezus', 'Adventure,Comedy,Family', 103.0, 2010),
#  ('Good Sharma', 'Drama', 100.0, 2010),
#  ('Bad Blood', 'Horror,Mystery,Romance', 107.0, 2012),
#  ('O Inimigo Sem Rosto', 'Crime,Drama', 85.0, 2010),
#  ('Prisoners of the Sun', 'Action,Adventure,Horror', 85.0, 2013),
#  ('The Hero of Color City', 'Animation,Family', 77.0, 2014),
#  ('Rings', 'Drama,Horror,Mystery', 102.0, 2017),
#  ('Without Remorse', 'Action,Crime,Drama', None, 2020),
#  ('Tranced', 'Drama,Fantasy,Romance', None, 2010),
#  ("Who Is Harry Nilsson (And Why Is Everybody Talkin' About Him?)",
#   'Biography,Documentary,Music',
#   116.0,
#   2010),
#  ('Love & Other Drugs', 'Comedy,Drama,Romance', 112.0, 2010),
#  ('Syrup', 'Comedy,Drama,Romance', 90.0, 2013),
#  ('A Thousand Words', 'Comedy,Drama', 91.0, 2012),
#  ('Escape from Planet Earth', 'Adventure,Animation,Comedy', 89.0, 2013),
#  ('Have You Seen Me?', 'Comedy', None, 2016),
#  ('The Legend of Secret Pass', 'Animation,Family,Fantasy', 92.0, 2019),
#  ('Waste of Space', 'Adventure,Comedy,Sci-Fi', 78.0, 2010),
#  ('Me and My Umbrella', 'Family,Fantasy', 78.0, 2010),
#  ('Night of the Templar', 'Horror,Mystery', 101.0, 2013),
#  ("What's Your Number?", 'Comedy,Romance', 106.0, 2011),
#  ('California Indian', 'Drama', 90.0, 2011),
#  ('King of the Avenue', 'Drama,Fantasy,Thriller', 83.0, 2010),
#  ('Samsara', 'Documentary,Music', 102.0, 2011),
#  ('Till You Get to Baraboo', 'Comedy,Romance', 80.0, 2011),
#  ('Man of Steel', 'Action,Adventure,Sci-Fi', 143.0, 2013),
#  ('Jersey Justice', 'Action,Thriller', 100.0, 2014),
#  ('Kill', 'Comedy,Horror,Thriller', 90.0, 2011),
#  ('The Chosen Heaven', 'Drama,Thriller', 123.0, 2010),
#  ('Cell', 'Action,Drama,Horror', 98.0, 2016),
#  ('The Rain Fairy', 'Family,Fantasy', 100.0, 2010),
#  ('The Illusionist', 'Animation,Drama', 80.0, 2010),
#  ('Night Catches Us', 'Drama,Romance', 90.0, 2010),
#  ('Drive', 'Crime,Drama', 100.0, 2011),
#  ('Kid Cannabis', 'Biography,Comedy,Crime', 110.0, 2014),
#  ('Santorini Blue', 'Comedy,Drama', 90.0, 2013),
#  ('War of the Dead', 'Action,Adventure,Horror', 86.0, 2011),
#  ('The Wolfman', 'Drama,Fantasy,Horror', 103.0, 2010),
#  ('Escalade', 'Thriller', 80.0, 2011),
#  ('Irreversi', 'Thriller', None, 2010),
#  ('The Last Full Measure', 'Drama,War', None, 2019),
#  ('The Attack', 'Drama,Mystery,War', 102.0, 2012),
#  ('The Boxtrolls', 'Adventure,Animation,Comedy', 96.0, 2014),
#  ('The Man Who Knew Infinity', 'Biography,Drama', 108.0, 2015),
#  ('The Incredible Burt Wonderstone', 'Adventure,Comedy,Fantasy', 100.0, 2013),
#  ('Dallas Buyers Club', 'Biography,Drama', 117.0, 2013),
#  ('Elliot Loves', 'Comedy,Romance', 92.0, 2012),
#  ('The First Grader', 'Biography,Drama,Romance', 103.0, 2010),
#  ('Jack Reacher', 'Action,Crime,Thriller', 130.0, 2012),
#  ('R.I.P.D.', 'Action,Adventure,Comedy', 96.0, 2013),
#  ('Miles Ahead', 'Biography,Drama,Music', 100.0, 2015),
#  ('The Yellow Wallpaper', 'Thriller', 115.0, 2012),
#  ('Wilde Salomé', 'Documentary,Drama', 95.0, 2011),
#  ('Scary Movie 5', 'Comedy', 86.0, 2013),
#  ('13', 'Drama,Thriller', 91.0, 2010),
#  ('The Guardians', 'Comedy,Family', 88.0, 2010),
#  ('Ironmen', 'Biography,Drama', 119.0, 2010),
#  ('Clash of the Titans', 'Action,Adventure,Fantasy', 106.0, 2010),
#  ('The Dirt', 'Biography,Comedy,Drama', 107.0, 2019),
#  ('Nemesis', 'Drama', 83.0, 2010),
#  ('Thor', 'Action,Adventure,Fantasy', 115.0, 2011),
#  ('Red Dog', 'Biography,Comedy,Drama', 92.0, 2011),
#  ('Warcraft', 'Action,Adventure,Fantasy', 123.0, 2016),
#  ("Devil's Knot", 'Biography,Crime,Drama', 114.0, 2013),
#  ('Folk!', 'Documentary', None, 2010),
#  ("It's Kind of a Funny Story", 'Comedy,Drama,Romance', 101.0, 2010),
#  ('The Mule', 'Comedy,Drama', 100.0, 2013),
#  ('Spoon', 'Action,Drama,Fantasy', None, 2011),
#  ('The Witches', 'Adventure,Comedy,Family', None, 2020),
#  ('A Letter to Elia', 'Documentary', 60.0, 2010),
#  ('The Last Pogo Jumps Again', 'Documentary,Music', 200.0, 2013),
#  ('Tooth Fairy', 'Comedy,Family,Fantasy', 101.0, 2010),
#  ('Belle du Seigneur', 'Drama,Romance', 104.0, 2012),
#  ('Cross the Line', 'Action', 87.0, 2010),
#  ('The Danish Girl', 'Biography,Drama,Romance', 119.0, 2015),
#  ('Eyes of the Mothman', 'Documentary', 150.0, 2011),
#  ('Jack and Jill', 'Comedy', 91.0, 2011),
#  ('Take Me Home Tonight', 'Comedy,Drama,Romance', 97.0, 2011),
#  ('Plumíferos - Aventuras voladoras',
#   'Adventure,Animation,Family',
#   80.0,
#   2010),
#  ('Lavoe', 'Drama,Music', 90.0, 2011),
#  ('The Do-Deca-Pentathlon', 'Comedy', 76.0, 2012),
#  ('Meridian Lines', 'Drama', None, 2013),
#  ('American Flyer', 'Adventure', 100.0, 2010),
#  ('Percy Jackson & the Olympians: The Lightning Thief',
#   'Adventure,Family,Fantasy',
#   118.0,
#   2010),
#  ('Ashes', 'Drama', 77.0, 2010),
#  ("She's Out of My League", 'Comedy,Romance', 104.0, 2010),
#  ('Card Subject to Change', 'Documentary', 87.0, 2010),
#  ('The Book Thief', 'Drama,War', 131.0, 2013),
#  ('Conan the Barbarian', 'Action,Adventure,Fantasy', 113.0, 2011),
#  ('Shanghai Hotel', 'Drama', 110.0, 2011),
#  ('Interstellar', 'Adventure,Drama,Sci-Fi', 169.0, 2014),
#  ('World War Z', 'Action,Adventure,Horror', 116.0, 2013),
#  ('Flipped', 'Comedy,Drama,Romance', 90.0, 2010),
#  ("Valentine's Day", 'Comedy,Romance', 125.0, 2010),
#  ('The Power of Few', 'Action,Crime,Drama', 96.0, 2013),
#  ('Dreamkiller', 'Thriller', 110.0, 2010),
#  ('Soupernatural', 'Drama', None, 2010),
#  ('Manhattan Minutiae', 'Comedy,Music,Romance', 99.0, 2016),
#  ('Priest', 'Action,Adventure,Fantasy', 87.0, 2011),
#  ('The Long Falling', 'Drama', 105.0, 2011),
#  ('Maximum Ride', 'Action,Adventure,Comedy', 88.0, 2016),
#  ('Caravaggio and My Mother the Pope', 'Comedy,Drama', 90.0, 2018),
#  ('Return to Yucca Flats: Desert Man-Beast', 'Comedy,Horror', 79.0, 2010),
#  ('Magic', 'Adventure,Family', None, 2010),
#  ('Wild in the Streets', 'Documentary', 82.0, 2012),
#  ('Dracula Untold', 'Action,Drama,Fantasy', 92.0, 2014),
#  ('Gallowwalkers', 'Action,Horror,Thriller', 90.0, 2012),
#  ('Waking Madison', 'Drama', 89.0, 2010),
#  ('Godzilla', 'Action,Adventure,Sci-Fi', 123.0, 2014),
#  ('Land', 'Documentary', 76.0, 2010),
#  ('The Babymakers', 'Comedy', 95.0, 2012),
#  ('Electric Slide', 'Action,Biography,Crime', 95.0, 2014),
#  ('Krystal', 'Comedy,Drama', 90.0, 2017),
#  ("Pee-wee's Big Holiday", 'Adventure,Comedy,Family', 90.0, 2016),
#  ('Approaching Midnight', 'Crime,Drama,Romance', 86.0, 2013),
#  ('Hotel Transylvania', 'Animation,Comedy,Family', 91.0, 2012),
#  ('Pet Sematary', 'Horror,Mystery,Thriller', 101.0, 2019),
#  ('Retreat!', 'Comedy,Drama,War', None, 2016),
#  ('Bhopal: A Prayer for Rain', 'Drama', 96.0, 2014),
#  ('Everyday Sunshine: The Story of Fishbone',
#   'Documentary,Music',
#   107.0,
#   2010),
#  ('The Town', 'Crime,Drama,Thriller', 125.0, 2010),
#  ('Río de oro', 'Western', None, 2010),
#  ('Whatever Happened to Pete Blaggit?', 'Comedy,Sci-Fi', 94.0, 2012),
#  ('The Kids Are All Right', 'Comedy,Drama,Romance', 106.0, 2010),
#  ('The Fallen Word', 'Drama,Fantasy,Mystery', 60.0, 2013),
#  ("Ivan Mosjoukine ou L'enfant du carnaval", 'Documentary', 67.0, 2016),
#  ('Killer by Nature', 'Adventure,Crime,Drama', 94.0, 2010),
#  ('Pox', 'Comedy,Sci-Fi', 100.0, 2011),
#  ('Hoodwinked Too! Hood vs. Evil', 'Animation,Comedy,Crime', 86.0, 2011),
#  ('Gangster Exchange', 'Action', 95.0, 2010),
#  ('Loot', 'Action,Comedy,Crime', 110.0, 2011),
#  ('Neowolf', 'Horror,Thriller', 88.0, 2010),
#  ('Night Traveler', 'Adventure', None, 2013),
#  ('Fun in the Army', 'Comedy', None, 2010),
#  ('The Speed of Thought', 'Sci-Fi,Thriller', 93.0, 2011),
#  ('The Avengers', 'Action,Adventure,Sci-Fi', 143.0, 2012),
#  ('Epic', 'Adventure,Animation,Family', 102.0, 2013),
#  ('The Sighting', 'Horror,Sci-Fi,Thriller', 98.0, 2016),
#  ('Duel of Legends', 'Action,Drama,Sport', None, 2018),
#  ('Amsteroid', 'Sci-Fi', 98.0, 2018),
#  ('Jack & Diane', 'Drama,Horror,Romance', 110.0, 2012),
#  ('Jackson Arms', 'Romance', 90.0, 2015),
#  ('Risen', 'Biography,Drama', 121.0, 2010),
#  ('Sir Billi', 'Adventure,Animation,Comedy', 76.0, 2012),
#  ('Folie à deux', 'Drama', None, 2012),
#  ('Bloudím', 'Drama', 75.0, 2010),
#  ('Naked Run', 'Comedy', 84.0, 2011),
#  ('A Summer Song', 'Drama', None, 2010),
#  ('This Is What Love in Action Looks Like', 'Documentary', 74.0, 2011),
#  ('Kolorádó Kid', 'Drama,Romance', 111.0, 2010),
#  ('The Sweeney', 'Action,Crime,Drama', 112.0, 2012),
#  ('2001 Maniacs: Field of Screams', 'Comedy,Horror', 84.0, 2010),
#  ('Bolden', 'Drama', 108.0, 2019),
#  ('Immortal Island', 'Adventure,Horror,Thriller', 84.0, 2011),
#  ('Wide Blue Yonder', 'Comedy,Drama', 82.0, 2010),
#  ('The Golden Greek: The Harry Agganis Story', 'Documentary', None, 2010),
#  ('Super Troopers 2', 'Comedy,Crime,Mystery', 99.0, 2018),
#  ('Evangelion: 3.0 You Can (Not) Redo', 'Action,Animation,Drama', 96.0, 2012),
#  ('Zenitram', 'Action,Adventure,Comedy', 103.0, 2010),
#  ('Lupin the 3rd', 'Action,Adventure,Comedy', 133.0, 2014),
#  ('Dukun', 'Horror,Thriller', 108.0, 2018),
#  ('Mr. Peabody & Sherman', 'Adventure,Animation,Comedy', 92.0, 2014),
#  ('Letting Go', 'Drama,Romance', 83.0, 2012),
#  ('6 Month Rule', 'Comedy', 100.0, 2011),
#  ('Catharsis', 'Mystery', 89.0, 2011),
#  ('Jungle Cruise', 'Adventure', None, 2020),
#  ('Touch Wood', 'Comedy', None, 2010),
#  ('The Nightclub Days', 'Comedy', None, 2012),
#  ('Surprise, Surprise', 'Drama', 83.0, 2010),
#  ('My Soul to Take', 'Horror,Mystery,Thriller', 107.0, 2010),
#  ('Red State', 'Action,Crime,Horror', 88.0, 2011),
#  ('The Dot Man', 'Drama,Thriller', None, 2017),
#  ('Beijing Taxi', 'Documentary', 78.0, 2010),
#  ('The Secret Philosophy', 'Thriller', 90.0, 2010),
#  ("Rain Falls from Earth: Surviving Cambodia's Darkest Hour",
#   'Documentary',
#   None,
#   2011),
#  ('Rift', 'Horror,Thriller', 100.0, 2011),
#  ('Bury the Hatchet', 'Documentary', 120.0, 2010),
#  ('Chûshingura', None, 76.0, 2016),
#  ('Bulletface', 'Thriller', 82.0, 2010),
#  ('First Circle', 'Documentary', 72.0, 2010),
#  ('Jewtopia', 'Comedy,Romance', 90.0, 2012),
#  ('Please Give', 'Comedy,Drama', 87.0, 2010),
#  ("Harm's Way", 'Thriller', 82.0, 2010),
#  ('Torn', 'Thriller', None, 2010),
#  ('Eat Pray Love', 'Drama,Romance', 133.0, 2010),
#  ('Mama I Want to Sing', 'Musical', 100.0, 2011),
#  ('Sanctum', 'Adventure,Drama,Thriller', 108.0, 2011),
#  ('AIR: The Musical', 'Comedy,Musical,Romance', 100.0, 2010),
#  ('Snitch', 'Action,Drama,Thriller', 112.0, 2013),
#  ('Wreckage', 'Horror,Thriller', 87.0, 2010),
#  ('Drain Baby', 'Horror', None, 2011),
#  ("Legends of Oz: Dorothy's Return", 'Adventure,Animation,Family', 88.0, 2013),
#  ('The Wedding Ringer', 'Comedy', 101.0, 2015),
#  ('Hyenas', 'Horror', 92.0, 2011),
#  ('Repo', 'Comedy,Drama', 97.0, 2010),
#  ('Rollerboy', 'Documentary', 81.0, 2013),
#  ('Honor', 'Crime,Drama,Thriller', 118.0, 2010),
#  ('The Switch', 'Comedy,Drama,Romance', 101.0, 2010),
#  ('RxCannabis: A Freedom Tale', 'Documentary', 83.0, 2018),
#  ('Hamlet A.D.D.', 'Animation,Comedy,Fantasy', 95.0, 2014),
#  ('Gun of the Black Sun', 'Fantasy', 90.0, 2011),
#  ('Letters to Juliet', 'Adventure,Comedy,Drama', 105.0, 2010),
#  ('How to Train Your Dragon', 'Action,Adventure,Animation', 98.0, 2010),
#  ('Shrek Forever After', 'Adventure,Animation,Comedy', 93.0, 2010),
#  ('Blur', 'Drama,Mystery,Thriller', 90.0, 2011),
#  ('From Prada to Nada', 'Comedy,Drama,Romance', 107.0, 2011),
#  ('The Whistleblower', 'Action,Biography,Crime', 112.0, 2010),
#  ("Don't Fade Away", 'Drama', 89.0, 2010),
#  ('The Key Man', 'Crime,Drama,Thriller', 80.0, 2011),
#  ('Suite Française', 'Drama,Romance,War', 107.0, 2014),
#  ('Psych:9', 'Horror,Mystery,Thriller', 98.0, 2010),
#  ('Acts of Violence', 'Crime,Drama,Thriller', None, 2010),
#  ('Westbrick Murders', 'Action,Crime,Thriller', 90.0, 2010),
#  ('The Hobbit: An Unexpected Journey',
#   'Adventure,Family,Fantasy',
#   169.0,
#   2012),
#  ('Love & Mercy', 'Biography,Drama,Music', 121.0, 2014),
#  ('The Thing', 'Horror,Mystery,Sci-Fi', 103.0, 2011),
#  ('The Grind', 'Crime,Thriller', 85.0, 2012),
#  ("The Unlikely's", 'Comedy', None, 2016),
#  ('Black Butterflies', 'Biography,Drama', 100.0, 2011),
#  ('Prey', 'Adventure,Drama,Horror', 90.0, 2010),
#  ('Eager to Die', 'Drama,Thriller', 109.0, 2010),
#  ('Exposed', 'Drama,Mystery,Thriller', 82.0, 2012),
#  ("A Merry Friggin' Christmas", 'Comedy', 88.0, 2014),
#  ("Movin' In", 'Comedy,Romance', 95.0, 2010),
#  ('House Under Siege', 'Action,Thriller', 78.0, 2010),
#  ('Monkeyman935', 'Horror', None, 2010),
#  ('Unthinkable', 'Crime,Drama,Thriller', 97.0, 2010),
#  ('Jackboots on Whitehall', 'Animation,Comedy,Sci-Fi', 91.0, 2010),
#  ('Gangster Kittens', 'Drama,Thriller', None, 2016),
#  ('Periphery', 'Drama', None, 2011),
#  ('Victim', 'Horror,Thriller', 90.0, 2010),
#  ('The Legend of Tarzan', 'Action,Adventure,Drama', 110.0, 2016),
#  ('The Happy Housewife', 'Comedy,Drama,Romance', 100.0, 2010),
#  ('The Dead Undead', 'Action,Horror,Sci-Fi', 89.0, 2010),
#  ('Truth About Kerry', 'Drama,Mystery,Thriller', 84.0, 2010),
#  ('Pizza with Bullets', 'Comedy', 99.0, 2010),
#  ('Harry Potter and the Deathly Hallows: Part 1',
#   'Adventure,Fantasy,Mystery',
#   146.0,
#   2010),
#  ('Road to Red', 'Action,Adventure,Horror', 120.0, 2016),
#  ("White Men Can't Dance", 'Drama,Family', 105.0, 2012),
#  ('The Penthouse', 'Comedy', 89.0, 2010),
#  ('Deep Gold 3D', 'Action', 86.0, 2011),
#  ('The Man in the Silo', 'Drama', 55.0, 2016),
#  ('June 9', 'Horror,Mystery,Thriller', 95.0, 2018),
#  ('Glenn, the Flying Robot', 'Drama,Sci-Fi', 85.0, 2010),
#  ('The Waiter', 'Action,Crime,Drama', 92.0, 2010),
#  ('Rabbit Hole', 'Drama', 91.0, 2010),
#  ('Joe Dick', 'Comedy', 96.0, 2017),
#  ("The Devil's Flower", 'Mystery,Romance', 90.0, 2010),
#  ('The Last Airbender', 'Action,Adventure,Family', 103.0, 2010),
#  ('Freaky Deaky', 'Comedy,Crime,Thriller', 90.0, 2012),
#  ('Silent Hill: Revelation', 'Horror', 95.0, 2012),
#  ('Arthur 3: The War of the Two Worlds',
#   'Adventure,Animation,Family',
#   101.0,
#   2010),
#  ('White Knuckles', 'Drama,Thriller', 88.0, 2010),
#  ('Salt', 'Action,Mystery,Thriller', 100.0, 2010),
#  ('Source Code', 'Action,Drama,Sci-Fi', 93.0, 2011),
#  ('Black Swan', 'Drama,Thriller', 108.0, 2010),
#  ('Green Zone', 'Action,Drama,Thriller', 115.0, 2010),
#  ('The Amazing Spider-Man', 'Action,Adventure,Sci-Fi', 136.0, 2012),
#  ('Coffee Sex You', 'Drama', 88.0, 2014),
#  ('The Killer Inside Me', 'Crime,Drama,Horror', 109.0, 2010),
#  ('Robin Hood', 'Action,Adventure,Drama', 140.0, 2010),
#  ('Reach Me', 'Comedy,Crime,Drama', 95.0, 2014),
#  ('Nine Dead', 'Crime,Drama,Horror', 98.0, 2010),
#  ('Heart of Now', 'Drama', 90.0, 2010),
#  ('Let Me Survive', 'Drama', None, 2013),
#  ('Beautiful Darling', 'Documentary', 85.0, 2010),
#  ('Private Security Officer: Los Angeles', 'Action,Comedy,Crime', 84.0, 2010),
#  ('Truth in Numbers? Everything, According to Wikipedia',
#   'Documentary',
#   85.0,
#   2010),
#  ('Avenge', 'Drama', 88.0, 2014),
#  ('A Monster in Paris', 'Adventure,Animation,Comedy', 90.0, 2011),
#  ('Devour', 'Horror', None, 2011),
#  ('The Trouble with Cali', 'Comedy', None, 2012),
#  ('The House of Sun', 'Drama', 110.0, 2010),
#  ('Made in Romania', 'Comedy', 95.0, 2010),
#  ('Feast of the Assumption: BTK and the Otero Family Murders',
#   'Crime,Documentary',
#   86.0,
#   2010),
#  ("The Sorcerer's Apprentice", 'Action,Adventure,Family', 109.0, 2010),
#  ('The Fighter', 'Biography,Drama,Sport', 116.0, 2010),
#  ("Pushin' Up Daisies", 'Comedy', 87.0, 2010),
#  ('Have You Heard from Johannesburg: Hell of a Job',
#   'Documentary',
#   57.0,
#   2010),
#  ('Have You Heard from Johannesburg: Road to Resistance',
#   'Documentary',
#   65.0,
#   2010),
#  ("L'imbroglio nel lenzuolo", 'Comedy,Romance', 105.0, 2010),
#  ('The Conspirator', 'Crime,Drama,History', 122.0, 2010),
#  ('Little Witch on a Broomstick', 'Animation,Comedy,Family', 90.0, 2011),
#  ('Strange Frame: Love & Sax', 'Animation,Crime,Music', 98.0, 2012),
#  ('White Wall', 'Action,Mystery,Sci-Fi', 91.0, 2010),
#  ('Hugo', 'Adventure,Drama,Family', 126.0, 2011),
#  ('Little Fockers', 'Comedy,Romance', 98.0, 2010),
#  ('The Chosen One', 'Comedy,Drama', 101.0, 2010),
#  ('The Reason', 'Drama,Fantasy,History', 70.0, 2010),
#  ('Back Roads', 'Crime,Drama,Thriller', 101.0, 2018),
#  ('Have You Heard from Johannesburg: Fair Play', 'Documentary', 96.0, 2010),
#  ('Have You Heard from Johannesburg: The Bottom Line',
#   'Documentary',
#   86.0,
#   2010),
#  ('Lives and Deaths of the Poets', 'Comedy', 93.0, 2011),
#  ('Headhunter: The Assessment Weekend', 'Action,Thriller', 93.0, 2010),
#  ('Justice League', 'Action,Adventure,Fantasy', 120.0, 2017),
#  ('Black Limousine', 'Drama', 102.0, 2010),
#  ('Hitchcock', 'Biography,Comedy,Drama', 98.0, 2012),
#  ('Sinatra Club', 'Action,Biography,Crime', 88.0, 2010),
#  ('Boyle Heights', 'Action', 101.0, 2010),
#  ('Chooriyan', 'Drama,Musical,Romance', None, 2015),
#  ('Fair Game', 'Biography,Drama,Thriller', 108.0, 2010),
#  ('Sucker Punch', 'Action,Adventure,Fantasy', 110.0, 2011),
#  ('Have You Heard from Johannesburg: Free at Last', 'Documentary', 78.0, 2010),
#  ('Lottery Ticket', 'Comedy', 99.0, 2010),
#  ('The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'Adventure,Family,Fantasy',
#   113.0,
#   2010),
#  ('Four', 'Drama,Romance', 75.0, 2012),
#  ('Heredity', 'Horror,Thriller', None, 2010),
#  ('Funkytown', 'Drama,Music', 132.0, 2011),
#  ('The Unwanted', 'Drama,Thriller', 95.0, 2013),
#  ('The Adventures of Tintin', 'Action,Adventure,Animation', 107.0, 2011),
#  ("You're Nobody 'til Somebody Kills You", 'Horror,Thriller', 86.0, 2012),
#  ('Fantasy Island', 'Adventure,Comedy,Fantasy', None, 2020),
#  ('El Padrino II: Border Intrusion', 'Crime', 90.0, 2011),
#  ('A Dance for Grace', 'Drama', None, 2010),
#  ('Multiple Sarcasms', 'Drama', 97.0, 2010),
#  ('Machete', 'Action,Crime,Thriller', 105.0, 2010),
#  ('The Magic Crystal', 'Adventure,Animation,Comedy', 80.0, 2011),
#  ('A Flat', 'Drama,Horror,Romance', 103.0, 2010),
#  ('The Gainesville Ripper', 'Horror', 90.0, 2010),
#  ('Dear John', 'Drama,Romance,War', 108.0, 2010),
#  ('Detention', 'Horror,Thriller', 81.0, 2010),
#  ('The Green Hornet', 'Action,Comedy,Crime', 119.0, 2011),
#  ('The Significant Other', 'Comedy,Romance', 90.0, 2012),
#  ('Hanna', 'Action,Drama,Thriller', 111.0, 2011),
#  ('The Wolf of Wall Street', 'Biography,Crime,Drama', 180.0, 2013),
#  ('Adventure Scouts', 'Action,Adventure,Comedy', 83.0, 2010),
#  ('The Courier', 'Action,Crime,Drama', 95.0, 2012),
#  ('The Unforgiven', 'Drama', 115.0, 2011),
#  ('Pelé: Birth of a Legend', 'Biography,Drama,Sport', 107.0, 2016),
#  ('The Extendables', 'Comedy', 84.0, 2014),
#  ('Legend of the Red Reaper', 'Action,Adventure,Fantasy', 99.0, 2013),
#  ('The Slimbones', 'Animation', None, 2014),
#  ('Bibliothèque Pascal', 'Drama', 105.0, 2010),
#  ('The Experiment', 'Drama,Thriller', 96.0, 2010),
#  ('Looking for the Lost Tango', 'Documentary,Music', 90.0, 2010),
#  ('Two Knives', 'Action', 107.0, 2011),
#  ('Straw Dogs', 'Action,Drama,Thriller', 110.0, 2011),
#  ('Mistero di un Impiegato', 'Drama', None, 2019),
#  ('Disrupted Land', 'Documentary', 77.0, 2019),
#  ('Chalu Dya Tumcha', None, 125.0, 2017),
#  ('The Rental', 'Horror', None, 2020),
#  ('Lusitanian Ghosts', 'Documentary,Music', 70.0, 2018),
#  ('Adalat', 'Drama', None, 2019),
#  ('Jadugar 2', 'Comedy', None, 2019),
#  ('Fiddler: A Miracle of Miracles', 'Documentary', 92.0, 2019),
#  ('Child of Wisdom', 'Drama', None, 2019),
#  ('Ali the Blind Boxer', 'Drama', None, 2019),
#  ('The Truth: Lost at Sea', 'Documentary', 57.0, 2017),
#  ('Soccer in the City', 'Documentary', 88.0, 2019),
#  ('When I Became a Butterfly', 'Thriller', 102.0, 2019),
#  ('Paradise', 'Drama,Thriller', 78.0, 2019),
#  ('Aporia', 'Action,Adventure,Horror', 85.0, 2019),
#  ('Alalá', 'Documentary', None, 2016),
#  ('Lysis', 'Adventure', None, 2018),
#  ('In Their Own Words, Billy the Kid & The Lincoln County War',
#   'Documentary',
#   None,
#   2019),
#  ('Invasores', 'Documentary', 60.0, 2010),
#  ('Chinese Speaking Vampires', 'Action', None, 2019),
#  ('Dhuntaaraa', 'Family', 92.0, 2015),
#  ('Barof 2019', 'Drama', None, 2019),
#  ('The Lost Memories', 'Drama,Thriller', None, 2016),
#  ('La notte è piccola per noi', 'Drama', 90.0, 2016),
#  ('Debout', 'Documentary', 85.0, 2019),
#  ('Krishnam', 'Drama', 128.0, 2019),
#  ('Kala-a-zar', 'Drama', 70.0, 2019),
#  ('Hunting Season', 'Comedy', None, 2019),
#  ('Feeling of revulsion', 'Documentary', None, 2018),
#  ("He's My Daddy Too", 'Drama', None, 2019),
#  ('Life Mein Twist Hai', 'Romance', None, 2014),
#  ('Dora Andrade', 'Biography,Documentary', None, 2012),
#  ('Weltweite Freundschaften', 'Documentary', None, 2018),
#  ('Mesto!', 'Drama', None, 2018),
#  ('Sifir: Etkisiz Eleman', 'Comedy', None, 2019),
#  ('Dangebaaz', 'Drama', None, 2015),
#  ('Terror in the Skies', 'Documentary', 67.0, 2019),
#  ('In Our Blood - El Comienzo de Todo, Àlex Crivillé',
#   'Documentary',
#   None,
#   2019),
#  ('In Our Blood - Sin Límite, Marc Márquez', 'Documentary', None, 2019),
#  ('Bull', 'Drama', 105.0, 2019),
#  ('Troublemaker', 'Documentary', 56.0, 2019),
#  ('Snatchers', 'Comedy,Horror,Sci-Fi', 96.0, 2019),
#  ('Willie', 'Documentary,Sport', None, 2019),
#  ('Trouble Makers', 'Comedy,Romance', 85.0, 2019),
#  ('Family Obligations', 'Comedy,Drama', 81.0, 2019),
#  ('Girl in the Icebox', 'Documentary', None, 2014),
#  ('Meu Nome é Daniel', 'Documentary', 82.0, 2018),
#  ('Encrypted: The Cyber Crime', 'Drama', None, 2019),
#  ('The Stateless Diplomat', 'Documentary', 79.0, 2018),
#  ("Bigger Like Me (Extended Director's Cut)", 'Documentary', 100.0, 2019),
#  ("Versailles Rediscovered - The Sun King's Vanished Palace",
#   'Documentary',
#   52.0,
#   2019),
#  ('Rosso Autunno', 'Drama', None, 2010),
#  ('Mossville: When Great Trees Fall', 'Documentary', 76.0, 2019),
#  ('Turtle', 'Drama', None, 2019),
#  ('Green Brothers', 'Action,Thriller', None, 2017),
#  ('The Sholay Girl', 'Action,Biography,Drama', 106.0, 2019),
#  ('Le sang de la haine', 'Crime,Drama', 75.0, 2016),
#  ('Chhand Priticha', None, 134.0, 2017),
#  ('Dhingana', 'Comedy', None, 2017),
#  ('17 Blocks', 'Documentary', 96.0, 2019),
#  ('Leftover Women', 'Documentary', 85.0, 2019),
#  ('Happy Birthday', None, None, 2017),
#  ('My Neighbor Wants Me Dead', 'Comedy,Fantasy,Horror', 51.0, 2019),
#  ('Watson', 'Documentary', None, 2019),
#  ("A Woman's Work: The NFL's Cheerleader Problem", 'Documentary', None, 2019),
#  ('Dominican Dream', 'Documentary', None, 2019),
#  ("Lil' Buck: Real Swan", 'Documentary', 85.0, 2019),
#  ('Nomad: In the Footsteps of Bruce Chatwin', 'Documentary', None, 2019),
#  ('All I Can Say', 'Documentary,Music', None, 2019),
#  ('Changing the Game', 'Documentary', 88.0, 2019),
#  ('The Soul of Soho', 'Documentary', None, 2019),
#  ('Lucky Grandma', 'Drama', None, 2019),
#  ('The Rest', 'Documentary', 78.0, 2019),
#  ('Red, White & Wasted', 'Drama', 89.0, 2019),
#  ('Martha: A Picture Story', None, None, 2019),
#  ("You Don't Nomi", 'Documentary', 92.0, 2019),
#  ('Linda Ronstadt: The Sound of My Voice', 'Documentary', None, 2019),
#  ('The Remix: Hip Hop X Fashion', 'Documentary', None, 2019),
#  ('Slay the Dragon', 'Documentary', None, 2019),
#  ('Trixie Mattel: Moving Parts', 'Documentary', 91.0, 2019),
#  ('Pohon Terkenal', 'Drama', 96.0, 2019),
#  ('Assholes: A Theory', 'Documentary', 81.0, 2019),
#  ('Balloons over Babylon', 'Documentary', 70.0, 2019),
#  ('Saalaiyoram', 'Drama', 125.0, 2016),
#  ('Zawierucha in Hollywood', 'Documentary', 55.0, 2019),
#  ('As Above, So Below', 'Documentary', None, 2012),
#  ('P.O.W. Open Air am Meer', 'Sport', None, 2017),
#  ('The Promise', 'Drama', None, 2017),
#  ('Cinderella', 'Musical', 150.0, 2018),
#  ('Forced Marriage', 'Comedy,Drama', 52.0, 2018),
#  ('RC Propbusters: Untold', 'Documentary', 63.0, 2019),
#  ('Jai Chhathi Maa', 'Family', 141.0, 2019),
#  ('Obstáculos Orgullo Y Recompensa', 'Crime,Thriller,Western', None, 2019),
#  ('Tenir tête', 'Documentary', 78.0, 2019),
#  ('Ancestral Waters', 'Documentary', None, 2019),
#  ('Yaz Kis Demeden', 'Documentary', 61.0, 2019),
#  ('Tanri göçmen çocuklari sever mi anne?', 'Documentary', 96.0, 2019),
#  ('Kader postasi', 'Drama,Romance', 104.0, 2019),
#  ('Megamind', 'Action,Animation,Comedy', 95.0, 2010),
#  ('Five Million Dollar Life', 'Mystery', None, 2019),
#  ('Forest of the Dead Sharks', 'Action,Comedy,Horror', 50.0, 2019),
#  ('Death Whisper', 'Horror', 91.0, 2019),
#  ('Mr. Nelson: On the North Side', 'Documentary', None, 2019),
#  ('Skvoznyye Shagi', 'Drama', None, 2018),
#  ('Bastan basa', 'Documentary', 57.0, 2019),
#  ('Vargit zamani', 'Documentary', 52.0, 2018),
#  ('Köpek filmi', 'Documentary', 60.0, 2019),
#  ('Lucie, après moi le déluge', 'Documentary', 58.0, 2019),
#  ('Back from 2038', 'Comedy,Fantasy', 88.0, 2019),
#  ('Ispade Rajavum Idhaya Raniyum', 'Drama,Romance', 141.0, 2019),
#  ('Dumlupinar: Vatan Sag Olsun', 'History', None, 2020),
#  ('Quand je veux, si je veux!', 'Documentary', 73.0, 2019),
#  ('Un lien qui nous élève', 'Documentary', 88.0, 2019),
#  ('Kutha Bolu Naka', 'Family', None, 2013),
#  ('Jai Maharashtra Dhaba Bhatinda', 'Romance', None, 2013),
#  ('Navra Majha Bhavra', 'Comedy', None, 2013),
#  ('Parees', 'Drama', None, 2013),
#  ('The Purple Mist', 'Drama', 106.0, 2019),
#  ('Egise Taara Juvvalu', 'Drama', None, 2017),
#  ('Lost Einstein', 'Drama,Sci-Fi', 48.0, 2018),
#  ('One Family', 'Documentary', 87.0, 2018),
#  ('Ila Ayithe Ela', 'Drama', None, 2017),
#  ('Bikers Kental 2', 'Comedy', 94.0, 2019),
#  ('P Storm', 'Action,Crime', 96.0, 2019),
#  ('Empty Temple', 'Documentary,History', 13.0, 2018),
#  ('Emiliano Queiroz: o Ator em sua Essência',
#   'Biography,Documentary',
#   None,
#   2018),
#  ('Gone Kesh', 'Drama', 110.0, 2019),
#  ('Stage 3', 'Action', 90.0, 2018),
#  ('Nuit', 'Documentary', 15.0, 2019),
#  ('When the Persimmons Grew', 'Documentary', 118.0, 2019),
#  ('Villa Caprice', 'Drama', None, 2020),
#  ('Jeremiah', 'Documentary', 56.0, 2016),
#  ("Chicago I'm Home", 'Comedy', 78.0, 2019),
#  ('100 Kada 10', 'Comedy', None, 2019),
#  ('Garud Puran', 'Comedy', None, 2019),
#  ('16 Bars', 'Documentary', 94.0, 2018),
#  ('Ne travaille pas (1968 - 2018)', 'Documentary', 88.0, 2018),
#  ('Yollara düstük', 'Documentary', 56.0, 2014),
#  ("Pietro Valdoni. L'uomo, il chirurgo, l'innovatore",
#   'Documentary',
#   66.0,
#   2017),
#  ('Worlds of Ursula K. Le Guin', 'Documentary', 68.0, 2018),
#  ('The Protector', 'Romance', 126.0, 2019),
#  ('Anuttara', 'Drama', 86.0, 2018),
#  ('A Song In The Storm', 'Documentary', 105.0, 2018),
#  ('A Song in the Storm', 'Documentary', 105.0, 2018),
#  ('Sucker for Love', 'Drama', 94.0, 2019),
#  ('It Could Be Him', 'Comedy', None, 2019),
#  ('SIUAT Sumanth 3', 'Action', None, 2016),
#  ('The Agreement', 'Documentary', None, 2019),
#  ('Nemesis', 'Action,Thriller', None, 2019),
#  ('Nedunalvaadai', 'Drama', None, 2019),
#  ('Mon Cousin', 'Comedy', None, 2020),
#  ('Africa with a broken neck', 'Documentary', 58.0, 2016),
#  ('Art and Life of Baba Pathak', 'Biography,Documentary', 52.0, 2011),
#  ('Waiting for the Boatman', 'Drama', 45.0, 2016),
#  ('Deep Swimmer', 'Drama', 45.0, 2016),
#  ('Freistaat Mittelpunkt', 'Documentary', 79.0, 2019),
#  ('Katha Karana Heena', 'Drama,Family', None, 2019),
#  ('Under 18 - Storie di sogni periferici', 'Documentary', None, 2019),
#  ('The Macao memory', 'Documentary', None, 2019),
#  ('67 49 32 Kuzey', 'Documentary', 55.0, 2019),
#  ('Satyarthi', 'Documentary', 52.0, 2019),
#  ('Hiwwe wie Driwwe - Pfälzisch in Amerika', 'Documentary', 91.0, 2019),
#  ('Aghavan', 'Family', 158.0, 2019),
#  ('The Elusive Elseblades', 'Musical', 53.0, 2019),
#  ('Dracula', 'Drama', None, 2019),
#  ('Hombres de ideas avanzadas', 'Documentary', None, 2011),
#  ('The Cult', 'Horror,Thriller', 76.0, 2019),
#  ('The Young Messiah', 'Drama,Fantasy', 111.0, 2016),
#  ('If You Only Knew', 'Drama', 106.0, 2011),
#  ('Machiwarla Budha', 'Drama', 114.0, 2017),
#  ('Maza Algar', None, None, 2017),
#  ('Between Me and My Mind', 'Documentary', None, 2019),
#  ('Kanchani Aaj Bhi Hai', 'Horror', None, 2019),
#  ('Brightness of Noon: The Intersect of Faith, Immigration and Refugees Part 2',
#   'Documentary',
#   58.0,
#   2019),
#  ('Piedone nyomában', 'Documentary', 65.0, 2019),
#  ('1200+ Dir', 'Documentary', 89.0, 2018),
#  ('Eleições', 'Documentary', 100.0, 2019),
#  ('Saboa', 'Drama', None, 2018),
#  ('Night of the Dead Geisha', 'Comedy,Horror', 48.0, 2018),
#  ('Patterns of Evidence: The Moses Controversy', 'Documentary', 140.0, 2019),
#  ('Miguelito', 'Documentary,Music', 94.0, 2019),
#  ('The Road To Hippie', 'Comedy', 90.0, 2019),
#  ('Nagarsevak - Ek Nayak', 'Action', 120.0, 2017),
#  ('Lal Singh Chaddha', 'Comedy,Drama', None, 2020),
#  ('Kyodai', 'Horror', 77.0, 2017),
#  ('Stay', 'Drama,Romance', 87.0, 2018),
#  ('Nationalmuseum - ljuset återvänder', 'Documentary', 58.0, 2018),
#  ('Latinos en el corredor de la muerte', 'Documentary', None, 2018),
#  ('El mercado de la inocencia', 'Documentary', None, 2018),
#  ('Pay Up, Cheaters!: The Story of The Beat Farmers',
#   'Documentary',
#   80.0,
#   2012),
#  ('Incels, a Documentary', 'Documentary', None, 2019),
#  ('Call of Life', 'Documentary', 60.0, 2010),
#  ('O Xanthos Magos When the Show Ends', 'Biography,Documentary', 53.0, 2019),
#  ("Grandmother's Farm", 'Comedy,Horror,Mystery', 71.0, 2013),
#  ('One God, Three Religions', 'Documentary', 50.0, 2019),
#  ('Pahil Paul Jivanch', 'Drama', 122.0, 2017),
#  ('Premay Namaha', 'Romance', 144.0, 2017),
#  ('Rangeela Raybaa', 'Romance', 143.0, 2017),
#  ('Viral 2019', 'Comedy', None, 2019),
#  ('Spandan What is Relationship', 'Romance', 142.0, 2017),
#  ('Lucky One', 'Drama', 76.0, 2019),
#  ('Desert Moon', 'Horror', None, 2019),
#  ('Tatva', 'Drama', 106.0, 2017),
#  ('Ubuntu', None, 114.0, 2017),
#  ('Super Sketch', 'Thriller', None, 2018),
#  ('Sergiu Celibidache - Feuerkopf und Philosoph', 'Documentary', 52.0, 2012),
#  ('The Place of the Three Waterfalls. Little Stories of Hiroshima',
#   'Documentary',
#   65.0,
#   2018),
#  ('Mukherjee Dar Bou', 'Drama,Family', None, 2019),
#  ('New Breed', 'Action', None, 2018),
#  ('Curse', 'Horror', None, 2019),
#  ('Dr. MM. Kalburgi Documentary', 'Documentary', None, 2017),
#  ('A Short History of a Few Bad Things', 'Drama', None, 2018),
#  ('Im Dickicht Der Städte', 'Drama', 123.0, 2013),
#  ('Zvyozdy svetyat vsem', 'Drama,Romance', None, 2014),
#  ('Piola', None, None, 2019),
#  ('Canova', 'Documentary', None, 2019),
#  ('Mbretëria', 'Drama', None, 2019),
#  ('Alone - The Legend of Miriam Yalan-Shtekelis', 'Documentary', 55.0, 2018),
#  ("Jay's Longhorn", 'Documentary', 93.0, 2019),
#  ('Death of a Traveling Life Insurance Salesman', 'Drama', 71.0, 2019),
#  ('Art in the City, 2 hour abridged', 'Documentary', 119.0, 2019),
#  ('Bring me the head of Jade Brooks', 'Action', 75.0, 2019),
#  ('El Hombre de la Montaña', 'Documentary', 70.0, 2018),
#  ('Los atardeceres rojos', 'Documentary', 87.0, 2019),
#  ('Der Fliegender Holländer', 'Musical', None, 2016),
#  ('When I Last Saw Jesse', 'Documentary', None, 2019),
#  ('The 45', 'Drama,Thriller', None, 2016),
#  ('Precure Miracle Universe Movie', 'Adventure,Animation,Family', 70.0, 2019),
#  ('Harapan Project: Carlos, the Messenger of Hope',
#   'Biography,Documentary,Family',
#   58.0,
#   2013),
#  ('Mle Kyu', 'Comedy,Drama', 120.0, 2019),
#  ("Killer's Whisper", 'Drama,Horror,Thriller', None, 2019),
#  ('Matoma: One in a Million', 'Documentary,Music', 78.0, 2018),
#  ('Wakya', None, None, 2017),
#  ('Expressionism', 'Documentary', None, 2018),
#  ('Biscuit', None, 124.0, 2017),
#  ('Delta Byrd Sings', 'Drama', None, 2019),
#  ('Bumper Lottery', None, 118.0, 2017),
#  ('Entre Muntanyes', 'Documentary', None, 2019),
#  ('Flatmates', 'Drama', None, 2019),
#  ('My Silent Lips', 'Horror', 82.0, 2019),
#  ('Xiao nv tian shi', 'Comedy,Romance', 63.0, 2017),
#  ('Mohyla', 'Adventure,Family,Sci-Fi', 74.0, 2019),
#  ('Prathighatana', 'Drama', 117.0, 2014),
#  ('Old Is Gold', 'Comedy,Drama', 136.0, 2019),
#  ('Hum tum', 'Romance', None, 2014),
#  ('Muttayikkallanum Mammaliyum', 'Drama', 122.0, 2019),
#  ('Tokyo Necronomicon', 'Horror', None, 2019),
#  ('Countdown', 'Thriller', None, 2019),
#  ('My Stupid Boss 2', 'Comedy,Drama', 96.0, 2019),
#  ('Premak Basaat', 'Romance', None, 2018),
#  ('Hollywood Necronomicon', 'Mystery', None, 2013),
#  ('Suporter Masuk Pesantren', 'Comedy,Drama', 84.0, 2019),
#  ('Southern Gothic', 'Documentary', None, 2019),
#  ('Paranaue: The Documentary', 'Documentary,Music', 62.0, 2018),
#  ('Perspectives of the Mind', 'Animation,Comedy,Drama', 47.0, 2019),
#  ('A Idade da Água', 'Documentary', 82.0, 2018),
#  ('Village of the Missing', 'Documentary', None, 2019),
#  ('Geher', 'Horror', None, 2019),
#  ('A fast passing angel', 'Documentary,Drama,Family', 92.0, 2019),
#  ('My Name Is Violeta', 'Documentary', 73.0, 2019),
#  ('In Our Blood - El Legado, Jorge Lorenzo', 'Documentary', None, 2019),
#  ('Gonarezhou: The Movie', 'Drama', 100.0, 2019),
#  ('Untitled Marvel Film', 'Action', None, 2021),
#  ('Untitled Disney Marvel Film', 'Action', None, 2022),
#  ('1H20', 'Drama', None, 2019),
#  ('Shifting Gears II', 'Documentary', 20.0, 2019),
#  ('Barcley', 'Drama', None, 2017),
#  ('No Good LUV', 'Drama', None, 2019),
#  ('Ameddig bírjuk: Gemini 70 felett', 'Documentary', 69.0, 2019),
#  ('Doña Julia', 'Documentary', 72.0, 2015),
#  ('The Kidnapper 2', 'Action', None, 2016),
#  ('Frankenstein: Presented by the 4th Wall Players', 'Horror', None, 2014),
#  ('Alle sorgenti della vita -Flora Gualdani', 'Documentary', 50.0, 2019),
#  ('Oblepikhovoe leto', 'Biography,Drama', 87.0, 2018),
#  ('The Kidnapper 4', 'Action', None, 2018),
#  ('Lo peor de los deseos', 'Thriller', 93.0, 2018),
#  ('Snow to Sand', 'Documentary', 60.0, 2019),
#  ('Block Z', 'Horror,Thriller', None, 2019),
#  ('Between Maybes', 'Drama,Romance', 107.0, 2019),
#  ('Bumi Itu Bulat', 'Drama', 103.0, 2019),
#  ('Rangu', 'Action', 156.0, 2018),
#  ('Billich: Beyond The Canvas', 'Documentary', None, 2019),
#  ('Inside the Walls', 'Drama,Horror,Mystery', None, 2017),
#  ('War of Art', 'Documentary', 102.0, 2019),
#  ('The Exorcist III: Legion', 'Horror', 105.0, 2016),
#  ('Butsaagui Amlalt', 'Drama', 95.0, 2019),
#  ('Zwitscherland', 'Documentary', None, 2018),
#  ('The Door', 'Comedy,Drama', 110.0, 2019),
#  ('Durs Appenzellerland', 'Documentary', None, 2018),
#  ('Parallel Road', 'Documentary', 58.0, 2017),
#  ('La vida en común', 'Drama,Mystery', 70.0, 2019),
#  ('Alem-i Cin 2', 'Horror', 93.0, 2019),
#  ('De hormigón armado', 'Drama', 90.0, 2015),
#  ('Eises Kälte - Frozen in Time', 'Mystery', 92.0, 2018),
#  ('Nikos Dragoumis: Enas zografos sti skia tis istorias (1874-1933)',
#   'Biography,Documentary',
#   None,
#   2015),
#  ('¿Qué fue de Pavlosky?', 'Documentary', None, 2019),
#  ('Gafas a ver', 'Comedy,Drama', 73.0, 2014),
#  ('Rejected', 'Drama,Fantasy', None, 2018),
#  ('Gente de Zona: En Letra De Otro', 'Documentary,Music', None, 2018),
#  ('Ya podaryu tebe pobedu', 'Drama', 101.0, 2019),
#  ('La ola de crímenes', 'Drama', 70.0, 2017),
#  ('Staged Killer', 'Thriller', 88.0, 2019),
#  ('When Rumi meets Francis', 'Drama', 51.0, 2017),
#  ('Die Wiese', 'Documentary', 93.0, 2019),
#  ('Pur laine', 'Comedy,Drama', 88.0, 2018),
#  ('Kids Of Wuzhumuqin Town', 'Drama,Family', 84.0, 2015),
#  ('The Sentries', 'Family', 73.0, 2018),
#  ('Joan Miró, the inner fire', 'Documentary', 61.0, 2018),
#  ('James & Pat & Dave', 'Comedy,Romance', None, 2019),
#  ('Unarmed Man', 'Drama', None, 2019),
#  ('Mr Misfortune', 'Thriller', 92.0, 2019),
#  ('Vaa Deal', 'Action', None, 2019),
#  ('Mystified', 'Adventure,Fantasy', 86.0, 2019),
#  ('Reincarnation', 'Drama', None, 2019),
#  ('Tian Shang De Hai Zi', 'Drama', None, 2018),
#  ('The Age of Sebastian', 'Drama', 70.0, 2018),
#  ('Drama', 'Drama', 117.0, 2019),
#  ("Bigfoot's Lament", 'Fantasy', 60.0, 2019),
#  ('Arayakadavil', 'Drama', None, 2019),
#  ('British Bungalow', 'Horror,Thriller', 117.0, 2019),
#  ("Thing I Don't Get", 'Drama', 71.0, 2018),
#  ('Therottam', 'Action,Thriller', 117.0, 2019),
#  ('Brené Brown: The Call to Courage', 'Documentary,Drama', 76.0, 2019),
#  ('Grass is Greener', 'Documentary', 97.0, 2019),
#  ('Fiancées', 'Documentary', None, 2019),
#  ('Crossing the river of life', 'Documentary', 55.0, 2018),
#  ('Killing Your Daughter', 'Thriller', None, 2019),
#  ('Shell and Joint', 'Drama', 154.0, 2018),
#  ('Love and Mercy', 'Biography,Drama,Family', 104.0, 2019),
#  ("Jeremiah's Woods", 'Comedy,Horror', 83.0, 2018),
#  ('AB', 'Documentary', 48.0, 2019),
#  ('Vogel Lost Vogel', 'Documentary', 55.0, 2018),
#  ('I Miss Oromia', 'Documentary', 86.0, 2018),
#  ("Shiva's Daughter", 'Drama', 88.0, 2019),
#  ('VI', 'Thriller', None, 2019),
#  ('The Art of Directing: John Huston', 'Documentary', 75.0, 2017),
#  ('Young: Belljar of Ineffable Youth', 'Documentary', 130.0, 2015),
#  ('Ropani', 'Documentary,Musical', 27.0, 2017),
#  ('3D Print Masters', 'Biography,Documentary', 52.0, 2019),
#  ('Ghost Town: The Curse of Bryerstone', 'Adventure', None, 2019),
#  ('Tunguska Butterfly', None, 91.0, 2019),
#  ('Mullapoo Viplavam', 'Drama', 136.0, 2019),
#  ('Vellai Pookal', 'Thriller', 122.0, 2019),
#  ('Mere Pyare Deshvasiyom', 'Comedy', 110.0, 2019),
#  ('Fatei and the sea', 'Documentary', None, 2018),
#  ('Das Bürgermeistermädchen', 'Comedy,Drama', 57.0, 2018),
#  ('Calling', 'Crime', None, 2019),
#  ('O Ballet de Hugo Bianchi', 'Biography,Documentary', None, 2019),
#  ('MeloDylan', 'Drama', 92.0, 2019),
#  ('Rotenberg', 'Documentary', 78.0, 2018),
#  ('Octubre', 'Documentary', 80.0, 2018),
#  ('Zombolicious', 'Comedy', None, 2019),
#  ('Walking Out', 'Adventure,Drama,Mystery', 118.0, 2017),
#  ("La fin da la val l'è mia la fin dal mund", 'Documentary', 63.0, 2018),
#  ('Nourathar', 'Documentary', 51.0, 2014),
#  ('As Cores da Serpente', 'Documentary', 70.0, 2019),
#  ('The 500 Foot Sister', 'Animation', 115.0, 2019),
#  (';', None, None, 2017),
#  ('Leur souffle', 'Documentary', 120.0, 2019),
#  ('Urgence de femme', 'Documentary', None, 2016),
#  ('Blood of God', 'Drama', None, 2019),
#  ('My Second Year in College', 'Drama', 99.0, 2019),
#  ('For The Voiceless', 'Documentary', 119.0, 2019),
#  ('Frozen Faith: Cryonics and the Quest to Cheat Death',
#   'Documentary',
#   None,
#   2016),
#  ('And the Winners Are!', 'Documentary', 82.0, 2019),
#  ('Heinz', 'Animation', None, 2018),
#  ("Bill Viola, expérience de l'infini", 'Documentary', 52.0, 2014),
#  ('Second Hand Store Horror Tales', 'Horror', None, 2018),
#  ('Hot Gimmick: Girl Meets Boy', 'Drama', None, 2019),
#  ('Invaded', 'Thriller', None, 2019),
#  ('Windfall', 'Comedy,Crime,Drama', None, 2019),
#  ('Jattan Diyan Dildariyan', 'Drama', None, 2016),
#  ("Yücel'in Çiçekleri", 'Documentary,History', 69.0, 2018),
#  ('Lustrum', 'Documentary', 90.0, 2018),
#  ('Unmadiyude Maranam', 'Fantasy', 78.0, 2019),
#  ("Vivre l'anarchie", 'Documentary', 90.0, 2019),
#  ('Canapa Nostra', 'Documentary', None, 2019),
#  ("Dreux, la vie d'après", 'Documentary', None, 2017),
#  ('Bhuj: The Pride of India', 'History', None, 2020),
#  ('Bring Out Your Dead', None, None, 2019),
#  ('Les Set Caixes', 'Documentary', 55.0, 2017),
#  ('O Olho e a Faca', 'Drama', 99.0, 2018),
#  ("Sasha's Hell", 'Drama,Horror', 98.0, 2019),
#  ('Puck & Hans - Made in Holland', 'Documentary', 52.0, 2019),
#  ('Antropofaga Makumba', 'Drama', 86.0, 2018),
#  ('Cartas da Bessarábia', 'Documentary', None, 2016),
#  ('Knock Down', 'Documentary', None, 2018),
#  ('Hypnotisøren og Danserinden', 'Drama', 100.0, 2020),
#  ('Inland', 'Documentary', 95.0, 2019),
#  ('Because We Are Girls', 'Documentary', None, 2019),
#  ('Untitled Disney Marvel Film', 'Action', None, 2022),
#  ('Untitled Marvel Film', 'Action', None, 2021),
#  ('Charismatic Megafauna', 'Documentary', None, 2019),
#  ('Inverse Everest', 'Documentary', None, 2019),
#  ('Man on the Bus', 'Documentary', 84.0, 2019),
#  ('Epokalipsa', 'Horror', 180.0, 2019),
#  ('The Tiny Life of Butcher Duke', 'Comedy', 78.0, 2019),
#  ('My Nudity Means Nothing', 'Drama', 85.0, 2019),
#  ('Snatched', 'Drama', 11.0, 2016),
#  ('No Longer Human: Dazai Osamu and Three Women', 'Biography', None, 2019),
#  ('Red Velvet', 'Drama', 11.0, 2018),
#  ('Song of Youth', 'Drama', None, 2019),
#  ('88A-12', 'Fantasy', 8.0, 2016),
#  ('Despair', 'Drama', None, 2019),
#  ('Goa Girls', 'Romance', None, 2016),
#  ('Dr Prasad c/o sitara', 'Comedy,Horror,Thriller', 97.0, 2018),
#  ('Mantan Manten', 'Drama', 102.0, 2019),
#  ('Innerscape', 'Drama', 80.0, 2019),
#  ('Charlie Chaplin: The Making of a Genius', 'Documentary', None, 2019),
#  ('Agaton', 'Biography,Documentary,Drama', 45.0, 2018),
#  ('Miehiä ja poikia', 'Documentary', 85.0, 2019),
#  ('Blizhe, chem kazhetsya', 'Drama', None, 2016),
#  ('Totally Crazy', 'Musical', 90.0, 2017),
#  ("Made in Abyss: Journey's Dawn", 'Adventure,Animation,Fantasy', 139.0, 2019),
#  ('Futari Ecchi', 'Comedy,Romance', None, 2019),
#  ('Made in Abyss: Wandering Twilight',
#   'Adventure,Animation,Fantasy',
#   110.0,
#   2019),
#  ('Made in Abyss: Fukaki Tamashî no Reimei',
#   'Adventure,Animation,Fantasy',
#   None,
#   2020),
#  ('Last Breath', 'Horror', 91.0, 2010),
#  ('Senseless me', 'Documentary', 84.0, 2019),
#  ('Bionic Showgirl', 'Musical', None, 2019),
#  ('Myanmar: An Unholy Alliance', 'Documentary', None, 2019),
#  ('Seytan-i Ins', 'Horror', 82.0, 2019),
#  ('Iluze', 'Documentary', 60.0, 2019),
#  ('The Unbendable', 'Drama', 75.0, 2016),
#  ('The Iron Lady', 'Biography,Drama', 105.0, 2011),
#  ('Good Girlfriend', 'Adult,Drama,Romance', None, 2018),
#  ('Taste of Friend Daughters', 'Adult,Drama,Romance', None, 2018),
#  ('Bunker of Blood 07: Killjoys Carnage Caravan', 'Horror', 88.0, 2019),
#  ('Maa Purnagiri', 'Family', 148.0, 2019),
#  ('DIO CÈ', 'Documentary', None, 2019),
#  ('Mazlum Kuzey & Kuddusi 2 La! Kasada Para Var!', 'Comedy', None, 2019),
#  ('Kaun Mera Kaun Tera', 'Comedy', None, 2017),
#  ('YSLA', 'Musical', None, 2019),
#  ('Rive-Sud Origine', 'Documentary,Mystery,Sci-Fi', 70.0, 2019),
#  ('Zhili-byli my', 'Family', 97.0, 2017),
#  ('The Shadow of Gold', 'Documentary', 78.0, 2019),
#  ('The Game', 'Horror', None, 2019),
#  ('Despedida de soltero', 'Thriller', 90.0, 2013),
#  ('Renegade', 'Action', None, 2019),
#  ('But What Was She Wearing?', 'Documentary', 110.0, 2018),
#  ('Once in a Hundred Years: The Life and Legacy of Marian Anderson',
#   'Documentary',
#   None,
#   2019),
#  ('Kuvana', 'Drama', None, 2019),
#  ...]

# %% [markdown]
# ## Data Preparation
#
# The IMDB SQLdatabase only contains information on films dating back to 2010 so all films prior to 2010 were dropped in order to conduct the genre and runtime analysis. Entries with no runtime or genre were also dropped.
#
# Film festivals also only recognize an entry as a feature film if it is at least 75 minutes long so all entries shorter were dropped.
#
# Each film was associated with three genres.  This analysis dropped the secondary and tertiary genre to focus on the impact the primary genre has on ROI.
#
# ROI column was added to the dataframe.
#
# The study of production budget added back movies prior to 2010 as their runtime and genre were not required. However, some movies were self produced by film makers and/or had celebrity favors that allowed for a lower production budget than would otherwise be required- all entries below $1M production budget were dropped.
#
# Although production budgets have a strong correlation to worldwide gross, there is no positive correlation to ROI.  As such production budgets were broken down into 4 tiers recognized in the industry:
#         Low Budget Films: $0.5M-$5M
#         Mid-Level Budget Films: $5M-$50M
#         Big Budget Films: $50M-$100M
#         Blockbuster Films: $100M+
# Each tier is analyzed against ROI to determine the optimal production budget tier.

# %%
#Extract needed columns from SQL database
genre_df= pd.read_sql('''SELECT primary_title, genres, runtime_minutes, start_year FROM movie_basics;''', conn)
genre_df
# Out:
#                                       primary_title                genres  \
# 0                                         Sunghursh    Action,Crime,Drama
# 1                   One Day Before the Rainy Season       Biography,Drama
# 2                        The Other Side of the Wind                 Drama
# 3                                   Sabse Bada Sukh          Comedy,Drama
# 4                          The Wandering Soap Opera  Comedy,Drama,Fantasy
# ...                                             ...                   ...
# 146139                          Kuambil Lagi Hatiku                 Drama
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro           Documentary
# 146141                              Dankyavar Danka                Comedy
# 146142                                       6 Gunn                  None
# 146143               Chico Albuquerque - Revelações           Documentary
#
#         runtime_minutes  start_year
# 0                 175.0        2013
# 1                 114.0        2019
# 2                 122.0        2018
# 3                   NaN        2018
# 4                  80.0        2017
# ...                 ...         ...
# 146139            123.0        2019
# 146140              NaN        2015
# 146141              NaN        2013
# 146142            116.0        2017
# 146143              NaN        2013
#
# [146144 rows x 4 columns]

# %%
print(genre_df.dtypes)
print(genre_df.shape)
# Out:
# primary_title       object
# genres              object
# runtime_minutes    float64
# start_year           int64
# dtype: object
# (146144, 4)

# %%
genre_df = genre_df.sort_values(by= 'start_year', ascending=False)
genre_df.tail(50)
#Analysis of genre and movie runtime will date back as far 2010
# Out:
#                                             primary_title  \
# 33645                        The Hutou Fortress: Bacteria
# 14446                                              Gesher
# 14459                                           Leftovers
# 14458                                     Labranza oculta
# 14456                                Keepers of the Light
# 14455                       Jimmy Tingle's American Dream
# 14453                                    Invisible Voices
# 136617                  Kreschtheater - Knapp dran vorbei
# 14452                                      I Am an Island
# 14451                        How to Make it in Filmmaking
# 14449                                           Hopeville
# 14447                                          Hamesima X
# 14445                                  For One Night Only
# 14497                                             Babylon
# 14443                                          Fast Women
# 14442                               Crossing the Mountain
# 88210                                      Den shakhtyora
# 74649                               le temps des vertiges
# 14437                             Y'en aura pas de facile
# 14436                                The Heart That Beats
# 14435                            Step Away from the Stone
# 14434                                            Mexicali
# 14433                                              Djambo
# 118027                                            Freedom
# 14460                                      List of Saints
# 14461                            Local Warming: The Movie
# 14462                          The Colors of the Mountain
# 14464                  Sinterklaas en het pakjes mysterie
# 14496                                    A Soldiers Story
# 14495                                   A River of Skulls
# 14494                                       Twice a Woman
# 14493                                       Taxidermy USA
# 14492                                     The Unforgiving
# 74723                        Guess Who's Coming to Dinner
# 14490                                    Shine Baby Shine
# 14489                                 Schooling the World
# 14488                                         Robot World
# 14487                          Rex Kyro: Mission to Marry
# 14486   Port Belly Project: the Belly Dancers of North...
# 74719                            Civil War: Left for Dead
# 14484                                     Mein Deudshland
# 33656                                        Saving Dolma
# 118118                                       Halloween II
# 95893                                         Tum Jo Mile
# 14474            Nunca más asistas a este tipo de fiestas
# 74712                      Civil War Life: Shot to Pieces
# 14471                         Heinrich Kieber - Datendieb
# 74692                                Mushrooms of America
# 118065                                             Zamana
# 94000                                    A Boy and A Girl
#
#                               genres  runtime_minutes  start_year
# 33645                            War              NaN        2010
# 14446                          Drama             84.0        2010
# 14459                         Comedy             96.0        2010
# 14458    Animation,Documentary,Drama             66.0        2010
# 14456       Documentary,Drama,Family             85.0        2010
# 14455             Comedy,Documentary             70.0        2010
# 14453              Documentary,Drama             93.0        2010
# 136617                   Documentary             45.0        2010
# 14452                          Drama             52.0        2010
# 14451          Biography,Documentary             57.0        2010
# 14449                   Drama,Family             90.0        2010
# 14447          Drama,Sci-Fi,Thriller             91.0        2010
# 14445        Horror,Mystery,Thriller             91.0        2010
# 14497                    Crime,Drama             55.0        2010
# 14443              Documentary,Sport             97.0        2010
# 14442                    Documentary             98.0        2010
# 88210                    Documentary             56.0        2010
# 74649                    Documentary              NaN        2010
# 14437                         Comedy             94.0        2010
# 14436                    Documentary             82.0        2010
# 14435                          Drama            110.0        2010
# 14434                      Adventure             68.0        2010
# 14433        Documentary,Drama,Music             41.0        2010
# 118027                        Horror              NaN        2010
# 14460             Action,Crime,Drama             45.0        2010
# 14461            Action,Comedy,Drama             71.0        2010
# 14462                          Drama             90.0        2010
# 14464                         Family             75.0        2010
# 14496                Documentary,War             90.0        2010
# 14495                  Drama,Western            100.0        2010
# 14494                          Drama             94.0        2010
# 14493                     Reality-TV              NaN        2010
# 14492                Horror,Thriller             75.0        2010
# 74723                            War              NaN        2010
# 14490                   Comedy,Drama            103.0        2010
# 14489                    Documentary             66.0        2010
# 14488              Documentary,Music             61.0        2010
# 14487                  Comedy,Sci-Fi            108.0        2010
# 14486   Biography,Documentary,Family             78.0        2010
# 74719                    Documentary             91.0        2010
# 14484                  Drama,Romance             86.0        2010
# 33656                    Documentary             62.0        2010
# 118118                        Horror              NaN        2010
# 95893                        Romance            125.0        2010
# 14474                  Comedy,Horror             70.0        2010
# 74712                    Documentary             79.0        2010
# 14471                    Documentary             52.0        2010
# 74692   Adventure,Comedy,Documentary             46.0        2010
# 118065                         Drama            140.0        2010
# 94000                        Romance              NaN        2010

# %%
genre_df.sort_values(by='runtime_minutes').head(50)
# Out:
#                                             primary_title  \
# 22903                                              Tierra
# 57140                                     Shark Sanctuary
# 114067                           One Minute Of Resistance
# 93214              Great Valley Nature Center Documentary
# 2570    Lamentation For Little Girls Who Are In Love W...
# 116943   Warnings missed? The crop circle of May 21, 2017
# 125975           parTy boi, black diamonds in ice castles
# 3298                                       Happy New Year
# 95787                         A Serendipitous Exploration
# 72190                          Powered By Green Smoothies
# 117258                                           Champion
# 113278                                     First and Last
# 136059                                        Summer Love
# 140571                                  For A Better Life
# 54307    Guerreiros da paz e poesia: It All Depends on Us
# 60809                                            November
# 98755                             Isa One Minute Portrait
# 107782                                    I Want to Boxeo
# 131229                                           Ms. Race
# 3116                    Occupying Wall Street for Pokémon
# 118872                                     Giuliano's web
# 79195                                        A Good Night
# 98062                                           Randyland
# 131154                                           Handmade
# 106420         Fort Funston: Wonder and Beauty In and Out
# 105198                                        Paris Shoot
# 88799                             Equality in Employement
# 97113                                           Neverland
# 117649     A Poem for Alton Sterling and Philando Castile
# 114657                                           The Wave
# 131200                                           Gigantic
# 37345                                 They've Seen It All
# 114134  Everything: Why Citizens Should Know Their U.S...
# 110973                                 Regresar el Tiempo
# 117259                                   Take a step back
# 120152                                      What is Love?
# 59386                                Solitary Confinement
# 15584                                      Found in Korea
# 11285                                     Paint by Desert
# 116783                             Stories Behind the Fog
# 5401                                    Vanilla Ice Cream
# 102792                                        In the Ring
# 33702                                        Dalia Rawson
# 131234                       Short Film: The Lost Dream's
# 129630                                     Smaller Things
# 51387                       Seward Harbor Flipbook Vol. 1
# 112611                                          The Boxer
# 123610                            Voice Memo: July 6 2016
# 43133          Snow White and the Huntsman: Stunning Evil
# 83271                                     Drowning Dreams
#
#                              genres  runtime_minutes  start_year
# 22903            Documentary,Family              1.0        2010
# 57140         Adventure,Documentary              1.0        2012
# 114067             Documentary,News              1.0        2017
# 93214                   Documentary              1.0        2015
# 2570                      Animation              1.0        2019
# 116943   Documentary,Horror,Mystery              1.0        2017
# 125975                  Documentary              1.0        2017
# 3298                      Animation              1.0        2019
# 95787                   Documentary              1.0        2016
# 72190   Adventure,Documentary,Sport              1.0        2014
# 117258            Documentary,Sport              1.0        2017
# 113278              Documentary,War              1.0        2016
# 136059                 Comedy,Short              1.0        2018
# 140571           Documentary,Family              1.0        2018
# 54307             Documentary,Music              1.0        2013
# 60809           Documentary,History              1.0        2014
# 98755                   Documentary              1.0        2016
# 107782            Documentary,Drama              2.0        2016
# 131229                  Documentary              2.0        2018
# 3116             Comedy,Documentary              2.0        2011
# 118872          Documentary,History              2.0        2016
# 79195             Documentary,Drama              2.0        2015
# 98062                   Documentary              2.0        2016
# 131154                  Documentary              2.0        2017
# 106420                  Documentary              2.0        2017
# 105198                  Documentary              2.0        2017
# 88799            Comedy,Documentary              2.0        2015
# 97113         Adventure,Documentary              2.0        2016
# 117649            Documentary,Drama              2.0        2016
# 114657     Action,Documentary,Sport              2.0        2017
# 131200                  Documentary              2.0        2018
# 37345         Adventure,Documentary              2.0        2011
# 114134                  Documentary              2.0        2017
# 110973            Documentary,Drama              2.0        2017
# 117259                  Documentary              2.0        2017
# 120152          Documentary,Romance              2.0        2017
# 59386        Crime,Documentary,News              2.0        2013
# 15584      Documentary,Drama,Family              2.0        2019
# 11285           Documentary,Western              2.0        2010
# 116783                  Documentary              2.0        2017
# 5401                          Drama              2.0        2019
# 102792                  Documentary              2.0        2016
# 33702         Biography,Documentary              2.0        2012
# 131234                  Documentary              2.0        2018
# 129630                  Documentary              2.0        2017
# 51387            Documentary,Family              2.0        2013
# 112611                  Documentary              2.0        2016
# 123610                  Documentary              2.0        2017
# 43133                   Documentary              2.0        2012
# 83271                   Documentary              2.0        2015

# %%
#As this is a study of feature lengh films, we will drop all rows with runtime_minutes below 75
genre_df = genre_df.drop(genre_df[genre_df.runtime_minutes<75].index)

# %%
#Almost half the database was comprised of short films
genre_df.shape
# Out:
# (111705, 4)

# %%
#Extracting just the year from release date and then converting to int
movie_budgets['release_date']= movie_budgets['release_date'].map(lambda x: x[-4:])
movie_budgets['release_date']=movie_budgets['release_date'].astype(int)

# %%
movie_budgets.dtypes
# Out:
# id                    int64
# release_date          int32
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
#Drop movies released before 2010 to match with SQL database
movie_budgets_2010= movie_budgets.drop(movie_budgets[movie_budgets.release_date<2010].index)

# %%
movie_budgets_2010.head(50)
# Out:
#     id  release_date                                             movie  \
# 1    2          2011       Pirates of the Caribbean: On Stranger Tides
# 2    3          2019                                      Dark Phoenix
# 3    4          2015                           Avengers: Age of Ultron
# 4    5          2017                 Star Wars Ep. VIII: The Last Jedi
# 5    6          2015              Star Wars Ep. VII: The Force Awakens
# 6    7          2018                            Avengers: Infinity War
# 8    9          2017                                    Justice League
# 9   10          2015                                           Spectre
# 10  11          2012                             The Dark Knight Rises
# 11  12          2018                           Solo: A Star Wars Story
# 12  13          2013                                   The Lone Ranger
# 13  14          2012                                       John Carter
# 14  15          2010                                           Tangled
# 16  17          2016                        Captain America: Civil War
# 17  18          2016                Batman v Superman: Dawn of Justice
# 18  19          2012                 The Hobbit: An Unexpected Journey
# 20  21          2013               The Hobbit: The Desolation of Smaug
# 21  22          2014         The Hobbit: The Battle of the Five Armies
# 22  23          2017                           The Fate of the Furious
# 24  25          2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 26  27          2012                                      The Avengers
# 28  29          2013                                      Man of Steel
# 30  31          2012                            The Amazing Spider-Man
# 31  32          2012                                        Battleship
# 32  33          2017                     Transformers: The Last Knight
# 33  34          2015                                    Jurassic World
# 34  35          2012                                    Men in Black 3
# 36  37          2014                   Transformers: Age of Extinction
# 38  39          2010                                        Robin Hood
# 41  42          2018                                     Black Panther
# 43  44          2018                                     Incredibles 2
# 44  45          2016                      Rogue One: A Star Wars Story
# 45  46          2016                                      Finding Dory
# 46  47          2010                                       Toy Story 3
# 47  48          2013                                        Iron Man 3
# 48  49          2017                     Guardians of the Galaxy Vol 2
# 50  51          2010                               Alice in Wonderland
# 51  52          2012                                           Skyfall
# 52  53          2013                               Monsters University
# 53  54          2013                         Oz the Great and Powerful
# 54  55          2014                        X-Men: Days of Future Past
# 55  56          2014                          The Amazing Spider-Man 2
# 56  57          2011                                            Cars 2
# 57  58          2010                                      Tron: Legacy
# 59  60          2018       Fantastic Beasts: The Crimes of Grindelwald
# 61  62          2011                                     Green Lantern
# 62  63          2010                   Prince of Persia: Sands of Time
# 63  64          2011                    Transformers: Dark of the Moon
# 64  65          2017                                         The Mummy
# 65  66          2013                             Jack the Giant Slayer
#
#    production_budget domestic_gross worldwide_gross
# 1       $410,600,000   $241,063,875  $1,045,663,875
# 2       $350,000,000    $42,762,350    $149,762,350
# 3       $330,600,000   $459,005,868  $1,403,013,963
# 4       $317,000,000   $620,181,382  $1,316,721,747
# 5       $306,000,000   $936,662,225  $2,053,311,220
# 6       $300,000,000   $678,815,482  $2,048,134,200
# 8       $300,000,000   $229,024,295    $655,945,209
# 9       $300,000,000   $200,074,175    $879,620,923
# 10      $275,000,000   $448,139,099  $1,084,439,099
# 11      $275,000,000   $213,767,512    $393,151,347
# 12      $275,000,000    $89,302,115    $260,002,115
# 13      $275,000,000    $73,058,679    $282,778,100
# 14      $260,000,000   $200,821,936    $586,477,240
# 16      $250,000,000   $408,084,349  $1,140,069,413
# 17      $250,000,000   $330,360,194    $867,500,281
# 18      $250,000,000   $303,003,568  $1,017,003,568
# 20      $250,000,000   $258,366,855    $960,366,855
# 21      $250,000,000   $255,119,788    $945,577,621
# 22      $250,000,000   $225,764,765  $1,234,846,267
# 24      $230,000,000   $172,558,876    $788,241,137
# 26      $225,000,000   $623,279,547  $1,517,935,897
# 28      $225,000,000   $291,045,518    $667,999,518
# 30      $220,000,000   $262,030,663    $757,890,267
# 31      $220,000,000    $65,233,400    $313,477,717
# 32      $217,000,000   $130,168,683    $602,893,340
# 33      $215,000,000   $652,270,625  $1,648,854,864
# 34      $215,000,000   $179,020,854    $654,213,485
# 36      $210,000,000   $245,439,076  $1,104,039,076
# 38      $210,000,000   $105,487,148    $322,459,006
# 41      $200,000,000   $700,059,566  $1,348,258,224
# 43      $200,000,000   $608,581,744  $1,242,520,711
# 44      $200,000,000   $532,177,324  $1,049,102,856
# 45      $200,000,000   $486,295,561  $1,021,215,193
# 46      $200,000,000   $415,004,880  $1,068,879,522
# 47      $200,000,000   $408,992,272  $1,215,392,272
# 48      $200,000,000   $389,813,101    $862,316,233
# 50      $200,000,000   $334,191,110  $1,025,491,110
# 51      $200,000,000   $304,360,277  $1,110,526,981
# 52      $200,000,000   $268,488,329    $743,588,329
# 53      $200,000,000   $234,770,996    $490,359,051
# 54      $200,000,000   $233,921,534    $747,862,775
# 55      $200,000,000   $202,853,933    $708,996,336
# 56      $200,000,000   $191,450,875    $560,155,383
# 57      $200,000,000   $172,062,763    $400,062,763
# 59      $200,000,000   $159,555,901    $652,220,086
# 61      $200,000,000   $116,601,172    $219,535,492
# 62      $200,000,000    $90,759,676    $336,359,676
# 63      $195,000,000   $352,390,543  $1,123,790,543
# 64      $195,000,000    $80,101,125    $409,953,905
# 65      $195,000,000    $65,187,603    $197,687,603

# %%
#Merge dataframes to have genre, runtime_minutes, production_budget, and worldwide_gross on same dataframe
budgets_genres_df= movie_budgets_2010.merge(genre_df, left_on=('movie'), right_on=('primary_title'), how='inner')
budgets_genres_df.head(50)
# Out:
#     id  release_date                                             movie  \
# 0    2          2011       Pirates of the Caribbean: On Stranger Tides
# 1    3          2019                                      Dark Phoenix
# 2    4          2015                           Avengers: Age of Ultron
# 3    7          2018                            Avengers: Infinity War
# 4    9          2017                                    Justice League
# 5   10          2015                                           Spectre
# 6   11          2012                             The Dark Knight Rises
# 7   12          2018                           Solo: A Star Wars Story
# 8   13          2013                                   The Lone Ranger
# 9   14          2012                                       John Carter
# 10  15          2010                                           Tangled
# 11  17          2016                        Captain America: Civil War
# 12  18          2016                Batman v Superman: Dawn of Justice
# 13  19          2012                 The Hobbit: An Unexpected Journey
# 14  21          2013               The Hobbit: The Desolation of Smaug
# 15  22          2014         The Hobbit: The Battle of the Five Armies
# 16  23          2017                           The Fate of the Furious
# 17  25          2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 18  27          2012                                      The Avengers
# 19  29          2013                                      Man of Steel
# 20  31          2012                            The Amazing Spider-Man
# 21  32          2012                                        Battleship
# 22  33          2017                     Transformers: The Last Knight
# 23  34          2015                                    Jurassic World
# 24  35          2012                                    Men in Black 3
# 25  37          2014                   Transformers: Age of Extinction
# 26  39          2010                                        Robin Hood
# 27  39          2010                                        Robin Hood
# 28  39          2010                                        Robin Hood
# 29  39          2010                                        Robin Hood
# 30   9          2018                                        Robin Hood
# 31   9          2018                                        Robin Hood
# 32   9          2018                                        Robin Hood
# 33   9          2018                                        Robin Hood
# 34  42          2018                                     Black Panther
# 35  44          2018                                     Incredibles 2
# 36  45          2016                      Rogue One: A Star Wars Story
# 37  46          2016                                      Finding Dory
# 38  47          2010                                       Toy Story 3
# 39  48          2013                                        Iron Man 3
# 40  51          2010                               Alice in Wonderland
# 41  51          2010                               Alice in Wonderland
# 42  52          2012                                           Skyfall
# 43  53          2013                               Monsters University
# 44  54          2013                         Oz the Great and Powerful
# 45  55          2014                        X-Men: Days of Future Past
# 46  56          2014                          The Amazing Spider-Man 2
# 47  57          2011                                            Cars 2
# 48  60          2018       Fantastic Beasts: The Crimes of Grindelwald
# 49  62          2011                                     Green Lantern
#
#    production_budget domestic_gross worldwide_gross  \
# 0       $410,600,000   $241,063,875  $1,045,663,875
# 1       $350,000,000    $42,762,350    $149,762,350
# 2       $330,600,000   $459,005,868  $1,403,013,963
# 3       $300,000,000   $678,815,482  $2,048,134,200
# 4       $300,000,000   $229,024,295    $655,945,209
# 5       $300,000,000   $200,074,175    $879,620,923
# 6       $275,000,000   $448,139,099  $1,084,439,099
# 7       $275,000,000   $213,767,512    $393,151,347
# 8       $275,000,000    $89,302,115    $260,002,115
# 9       $275,000,000    $73,058,679    $282,778,100
# 10      $260,000,000   $200,821,936    $586,477,240
# 11      $250,000,000   $408,084,349  $1,140,069,413
# 12      $250,000,000   $330,360,194    $867,500,281
# 13      $250,000,000   $303,003,568  $1,017,003,568
# 14      $250,000,000   $258,366,855    $960,366,855
# 15      $250,000,000   $255,119,788    $945,577,621
# 16      $250,000,000   $225,764,765  $1,234,846,267
# 17      $230,000,000   $172,558,876    $788,241,137
# 18      $225,000,000   $623,279,547  $1,517,935,897
# 19      $225,000,000   $291,045,518    $667,999,518
# 20      $220,000,000   $262,030,663    $757,890,267
# 21      $220,000,000    $65,233,400    $313,477,717
# 22      $217,000,000   $130,168,683    $602,893,340
# 23      $215,000,000   $652,270,625  $1,648,854,864
# 24      $215,000,000   $179,020,854    $654,213,485
# 25      $210,000,000   $245,439,076  $1,104,039,076
# 26      $210,000,000   $105,487,148    $322,459,006
# 27      $210,000,000   $105,487,148    $322,459,006
# 28      $210,000,000   $105,487,148    $322,459,006
# 29      $210,000,000   $105,487,148    $322,459,006
# 30       $99,000,000    $30,824,628     $84,747,441
# 31       $99,000,000    $30,824,628     $84,747,441
# 32       $99,000,000    $30,824,628     $84,747,441
# 33       $99,000,000    $30,824,628     $84,747,441
# 34      $200,000,000   $700,059,566  $1,348,258,224
# 35      $200,000,000   $608,581,744  $1,242,520,711
# 36      $200,000,000   $532,177,324  $1,049,102,856
# 37      $200,000,000   $486,295,561  $1,021,215,193
# 38      $200,000,000   $415,004,880  $1,068,879,522
# 39      $200,000,000   $408,992,272  $1,215,392,272
# 40      $200,000,000   $334,191,110  $1,025,491,110
# 41      $200,000,000   $334,191,110  $1,025,491,110
# 42      $200,000,000   $304,360,277  $1,110,526,981
# 43      $200,000,000   $268,488,329    $743,588,329
# 44      $200,000,000   $234,770,996    $490,359,051
# 45      $200,000,000   $233,921,534    $747,862,775
# 46      $200,000,000   $202,853,933    $708,996,336
# 47      $200,000,000   $191,450,875    $560,155,383
# 48      $200,000,000   $159,555,901    $652,220,086
# 49      $200,000,000   $116,601,172    $219,535,492
#
#                                        primary_title  \
# 0        Pirates of the Caribbean: On Stranger Tides
# 1                                       Dark Phoenix
# 2                            Avengers: Age of Ultron
# 3                             Avengers: Infinity War
# 4                                     Justice League
# 5                                            Spectre
# 6                              The Dark Knight Rises
# 7                            Solo: A Star Wars Story
# 8                                    The Lone Ranger
# 9                                        John Carter
# 10                                           Tangled
# 11                        Captain America: Civil War
# 12                Batman v Superman: Dawn of Justice
# 13                 The Hobbit: An Unexpected Journey
# 14               The Hobbit: The Desolation of Smaug
# 15         The Hobbit: The Battle of the Five Armies
# 16                           The Fate of the Furious
# 17  Pirates of the Caribbean: Dead Men Tell No Tales
# 18                                      The Avengers
# 19                                      Man of Steel
# 20                            The Amazing Spider-Man
# 21                                        Battleship
# 22                     Transformers: The Last Knight
# 23                                    Jurassic World
# 24                                    Men in Black 3
# 25                   Transformers: Age of Extinction
# 26                                        Robin Hood
# 27                                        Robin Hood
# 28                                        Robin Hood
# 29                                        Robin Hood
# 30                                        Robin Hood
# 31                                        Robin Hood
# 32                                        Robin Hood
# 33                                        Robin Hood
# 34                                     Black Panther
# 35                                     Incredibles 2
# 36                      Rogue One: A Star Wars Story
# 37                                      Finding Dory
# 38                                       Toy Story 3
# 39                                        Iron Man 3
# 40                               Alice in Wonderland
# 41                               Alice in Wonderland
# 42                                           Skyfall
# 43                               Monsters University
# 44                         Oz the Great and Powerful
# 45                        X-Men: Days of Future Past
# 46                          The Amazing Spider-Man 2
# 47                                            Cars 2
# 48       Fantastic Beasts: The Crimes of Grindelwald
# 49                                     Green Lantern
#
#                         genres  runtime_minutes  start_year
# 0     Action,Adventure,Fantasy            136.0        2011
# 1      Action,Adventure,Sci-Fi            113.0        2019
# 2      Action,Adventure,Sci-Fi            141.0        2015
# 3      Action,Adventure,Sci-Fi            149.0        2018
# 4     Action,Adventure,Fantasy            120.0        2017
# 5    Action,Adventure,Thriller            148.0        2015
# 6              Action,Thriller            164.0        2012
# 7     Action,Adventure,Fantasy            135.0        2018
# 8     Action,Adventure,Western            150.0        2013
# 9      Action,Adventure,Sci-Fi            132.0        2012
# 10  Adventure,Animation,Comedy            100.0        2010
# 11     Action,Adventure,Sci-Fi            147.0        2016
# 12    Action,Adventure,Fantasy            151.0        2016
# 13    Adventure,Family,Fantasy            169.0        2012
# 14           Adventure,Fantasy            161.0        2013
# 15           Adventure,Fantasy            144.0        2014
# 16       Action,Crime,Thriller            136.0        2017
# 17    Action,Adventure,Fantasy            129.0        2017
# 18     Action,Adventure,Sci-Fi            143.0        2012
# 19     Action,Adventure,Sci-Fi            143.0        2013
# 20     Action,Adventure,Sci-Fi            136.0        2012
# 21     Action,Adventure,Sci-Fi            131.0        2012
# 22     Action,Adventure,Sci-Fi            154.0        2017
# 23     Action,Adventure,Sci-Fi            124.0        2015
# 24     Action,Adventure,Comedy            106.0        2012
# 25     Action,Adventure,Sci-Fi            165.0        2014
# 26                        None              NaN        2018
# 27   Action,Adventure,Thriller            116.0        2018
# 28                Action,Drama             92.0        2013
# 29      Action,Adventure,Drama            140.0        2010
# 30                        None              NaN        2018
# 31   Action,Adventure,Thriller            116.0        2018
# 32                Action,Drama             92.0        2013
# 33      Action,Adventure,Drama            140.0        2010
# 34     Action,Adventure,Sci-Fi            134.0        2018
# 35  Action,Adventure,Animation            118.0        2018
# 36     Action,Adventure,Sci-Fi            133.0        2016
# 37  Adventure,Animation,Comedy             97.0        2016
# 38  Adventure,Animation,Comedy            103.0        2010
# 39     Action,Adventure,Sci-Fi            130.0        2013
# 40    Adventure,Family,Fantasy            108.0        2010
# 41             Fantasy,Musical             99.0        2010
# 42   Action,Adventure,Thriller            143.0        2012
# 43  Adventure,Animation,Comedy            104.0        2013
# 44    Adventure,Family,Fantasy            130.0        2013
# 45     Action,Adventure,Sci-Fi            132.0        2014
# 46     Action,Adventure,Sci-Fi            142.0        2014
# 47  Adventure,Animation,Comedy            106.0        2011
# 48    Adventure,Family,Fantasy            134.0        2018
# 49     Action,Adventure,Sci-Fi            114.0        2011

# %%
#Drop duplicate entries
budgets_genres_df=budgets_genres_df.drop_duplicates(subset= 'movie', keep='first')
budgets_genres_df.head(50)
# Out:
#     id  release_date                                             movie  \
# 0    2          2011       Pirates of the Caribbean: On Stranger Tides
# 1    3          2019                                      Dark Phoenix
# 2    4          2015                           Avengers: Age of Ultron
# 3    7          2018                            Avengers: Infinity War
# 4    9          2017                                    Justice League
# 5   10          2015                                           Spectre
# 6   11          2012                             The Dark Knight Rises
# 7   12          2018                           Solo: A Star Wars Story
# 8   13          2013                                   The Lone Ranger
# 9   14          2012                                       John Carter
# 10  15          2010                                           Tangled
# 11  17          2016                        Captain America: Civil War
# 12  18          2016                Batman v Superman: Dawn of Justice
# 13  19          2012                 The Hobbit: An Unexpected Journey
# 14  21          2013               The Hobbit: The Desolation of Smaug
# 15  22          2014         The Hobbit: The Battle of the Five Armies
# 16  23          2017                           The Fate of the Furious
# 17  25          2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 18  27          2012                                      The Avengers
# 19  29          2013                                      Man of Steel
# 20  31          2012                            The Amazing Spider-Man
# 21  32          2012                                        Battleship
# 22  33          2017                     Transformers: The Last Knight
# 23  34          2015                                    Jurassic World
# 24  35          2012                                    Men in Black 3
# 25  37          2014                   Transformers: Age of Extinction
# 26  39          2010                                        Robin Hood
# 34  42          2018                                     Black Panther
# 35  44          2018                                     Incredibles 2
# 36  45          2016                      Rogue One: A Star Wars Story
# 37  46          2016                                      Finding Dory
# 38  47          2010                                       Toy Story 3
# 39  48          2013                                        Iron Man 3
# 40  51          2010                               Alice in Wonderland
# 42  52          2012                                           Skyfall
# 43  53          2013                               Monsters University
# 44  54          2013                         Oz the Great and Powerful
# 45  55          2014                        X-Men: Days of Future Past
# 46  56          2014                          The Amazing Spider-Man 2
# 47  57          2011                                            Cars 2
# 48  60          2018       Fantastic Beasts: The Crimes of Grindelwald
# 49  62          2011                                     Green Lantern
# 50  64          2011                    Transformers: Dark of the Moon
# 51  65          2017                                         The Mummy
# 52  66          2013                             Jack the Giant Slayer
# 53  67          2015                                         Furious 7
# 54  68          2013                           Star Trek Into Darkness
# 55  69          2013                                       World War Z
# 56  70          2013                                  The Great Gatsby
# 57  72          2013                                       Pacific Rim
#
#    production_budget domestic_gross worldwide_gross  \
# 0       $410,600,000   $241,063,875  $1,045,663,875
# 1       $350,000,000    $42,762,350    $149,762,350
# 2       $330,600,000   $459,005,868  $1,403,013,963
# 3       $300,000,000   $678,815,482  $2,048,134,200
# 4       $300,000,000   $229,024,295    $655,945,209
# 5       $300,000,000   $200,074,175    $879,620,923
# 6       $275,000,000   $448,139,099  $1,084,439,099
# 7       $275,000,000   $213,767,512    $393,151,347
# 8       $275,000,000    $89,302,115    $260,002,115
# 9       $275,000,000    $73,058,679    $282,778,100
# 10      $260,000,000   $200,821,936    $586,477,240
# 11      $250,000,000   $408,084,349  $1,140,069,413
# 12      $250,000,000   $330,360,194    $867,500,281
# 13      $250,000,000   $303,003,568  $1,017,003,568
# 14      $250,000,000   $258,366,855    $960,366,855
# 15      $250,000,000   $255,119,788    $945,577,621
# 16      $250,000,000   $225,764,765  $1,234,846,267
# 17      $230,000,000   $172,558,876    $788,241,137
# 18      $225,000,000   $623,279,547  $1,517,935,897
# 19      $225,000,000   $291,045,518    $667,999,518
# 20      $220,000,000   $262,030,663    $757,890,267
# 21      $220,000,000    $65,233,400    $313,477,717
# 22      $217,000,000   $130,168,683    $602,893,340
# 23      $215,000,000   $652,270,625  $1,648,854,864
# 24      $215,000,000   $179,020,854    $654,213,485
# 25      $210,000,000   $245,439,076  $1,104,039,076
# 26      $210,000,000   $105,487,148    $322,459,006
# 34      $200,000,000   $700,059,566  $1,348,258,224
# 35      $200,000,000   $608,581,744  $1,242,520,711
# 36      $200,000,000   $532,177,324  $1,049,102,856
# 37      $200,000,000   $486,295,561  $1,021,215,193
# 38      $200,000,000   $415,004,880  $1,068,879,522
# 39      $200,000,000   $408,992,272  $1,215,392,272
# 40      $200,000,000   $334,191,110  $1,025,491,110
# 42      $200,000,000   $304,360,277  $1,110,526,981
# 43      $200,000,000   $268,488,329    $743,588,329
# 44      $200,000,000   $234,770,996    $490,359,051
# 45      $200,000,000   $233,921,534    $747,862,775
# 46      $200,000,000   $202,853,933    $708,996,336
# 47      $200,000,000   $191,450,875    $560,155,383
# 48      $200,000,000   $159,555,901    $652,220,086
# 49      $200,000,000   $116,601,172    $219,535,492
# 50      $195,000,000   $352,390,543  $1,123,790,543
# 51      $195,000,000    $80,101,125    $409,953,905
# 52      $195,000,000    $65,187,603    $197,687,603
# 53      $190,000,000   $353,007,020  $1,518,722,794
# 54      $190,000,000   $228,778,661    $467,381,584
# 55      $190,000,000   $202,359,711    $531,514,650
# 56      $190,000,000   $144,840,419    $351,040,419
# 57      $190,000,000   $101,802,906    $411,002,906
#
#                                        primary_title  \
# 0        Pirates of the Caribbean: On Stranger Tides
# 1                                       Dark Phoenix
# 2                            Avengers: Age of Ultron
# 3                             Avengers: Infinity War
# 4                                     Justice League
# 5                                            Spectre
# 6                              The Dark Knight Rises
# 7                            Solo: A Star Wars Story
# 8                                    The Lone Ranger
# 9                                        John Carter
# 10                                           Tangled
# 11                        Captain America: Civil War
# 12                Batman v Superman: Dawn of Justice
# 13                 The Hobbit: An Unexpected Journey
# 14               The Hobbit: The Desolation of Smaug
# 15         The Hobbit: The Battle of the Five Armies
# 16                           The Fate of the Furious
# 17  Pirates of the Caribbean: Dead Men Tell No Tales
# 18                                      The Avengers
# 19                                      Man of Steel
# 20                            The Amazing Spider-Man
# 21                                        Battleship
# 22                     Transformers: The Last Knight
# 23                                    Jurassic World
# 24                                    Men in Black 3
# 25                   Transformers: Age of Extinction
# 26                                        Robin Hood
# 34                                     Black Panther
# 35                                     Incredibles 2
# 36                      Rogue One: A Star Wars Story
# 37                                      Finding Dory
# 38                                       Toy Story 3
# 39                                        Iron Man 3
# 40                               Alice in Wonderland
# 42                                           Skyfall
# 43                               Monsters University
# 44                         Oz the Great and Powerful
# 45                        X-Men: Days of Future Past
# 46                          The Amazing Spider-Man 2
# 47                                            Cars 2
# 48       Fantastic Beasts: The Crimes of Grindelwald
# 49                                     Green Lantern
# 50                    Transformers: Dark of the Moon
# 51                                         The Mummy
# 52                             Jack the Giant Slayer
# 53                                         Furious 7
# 54                           Star Trek Into Darkness
# 55                                       World War Z
# 56                                  The Great Gatsby
# 57                                       Pacific Rim
#
#                         genres  runtime_minutes  start_year
# 0     Action,Adventure,Fantasy            136.0        2011
# 1      Action,Adventure,Sci-Fi            113.0        2019
# 2      Action,Adventure,Sci-Fi            141.0        2015
# 3      Action,Adventure,Sci-Fi            149.0        2018
# 4     Action,Adventure,Fantasy            120.0        2017
# 5    Action,Adventure,Thriller            148.0        2015
# 6              Action,Thriller            164.0        2012
# 7     Action,Adventure,Fantasy            135.0        2018
# 8     Action,Adventure,Western            150.0        2013
# 9      Action,Adventure,Sci-Fi            132.0        2012
# 10  Adventure,Animation,Comedy            100.0        2010
# 11     Action,Adventure,Sci-Fi            147.0        2016
# 12    Action,Adventure,Fantasy            151.0        2016
# 13    Adventure,Family,Fantasy            169.0        2012
# 14           Adventure,Fantasy            161.0        2013
# 15           Adventure,Fantasy            144.0        2014
# 16       Action,Crime,Thriller            136.0        2017
# 17    Action,Adventure,Fantasy            129.0        2017
# 18     Action,Adventure,Sci-Fi            143.0        2012
# 19     Action,Adventure,Sci-Fi            143.0        2013
# 20     Action,Adventure,Sci-Fi            136.0        2012
# 21     Action,Adventure,Sci-Fi            131.0        2012
# 22     Action,Adventure,Sci-Fi            154.0        2017
# 23     Action,Adventure,Sci-Fi            124.0        2015
# 24     Action,Adventure,Comedy            106.0        2012
# 25     Action,Adventure,Sci-Fi            165.0        2014
# 26                        None              NaN        2018
# 34     Action,Adventure,Sci-Fi            134.0        2018
# 35  Action,Adventure,Animation            118.0        2018
# 36     Action,Adventure,Sci-Fi            133.0        2016
# 37  Adventure,Animation,Comedy             97.0        2016
# 38  Adventure,Animation,Comedy            103.0        2010
# 39     Action,Adventure,Sci-Fi            130.0        2013
# 40    Adventure,Family,Fantasy            108.0        2010
# 42   Action,Adventure,Thriller            143.0        2012
# 43  Adventure,Animation,Comedy            104.0        2013
# 44    Adventure,Family,Fantasy            130.0        2013
# 45     Action,Adventure,Sci-Fi            132.0        2014
# 46     Action,Adventure,Sci-Fi            142.0        2014
# 47  Adventure,Animation,Comedy            106.0        2011
# 48    Adventure,Family,Fantasy            134.0        2018
# 49     Action,Adventure,Sci-Fi            114.0        2011
# 50     Action,Adventure,Sci-Fi            154.0        2011
# 51    Action,Adventure,Fantasy            110.0        2017
# 52           Adventure,Fantasy            114.0        2013
# 53       Action,Crime,Thriller            137.0        2015
# 54     Action,Adventure,Sci-Fi            132.0        2013
# 55     Action,Adventure,Horror            116.0        2013
# 56               Drama,Romance            143.0        2013
# 57     Action,Adventure,Sci-Fi            131.0        2013

# %%
#Drop $ for integer conversion
budgets_genres_df['production_budget']= budgets_genres_df['production_budget'].map(lambda x: x[1:])
budgets_genres_df['domestic_gross']= budgets_genres_df['domestic_gross'].map(lambda x: x[1:])
budgets_genres_df['worldwide_gross']= budgets_genres_df['worldwide_gross'].map(lambda x: x[1:])
budgets_genres_df
# Out:
#       id  release_date                                        movie  \
# 0      2          2011  Pirates of the Caribbean: On Stranger Tides
# 1      3          2019                                 Dark Phoenix
# 2      4          2015                      Avengers: Age of Ultron
# 3      7          2018                       Avengers: Infinity War
# 4      9          2017                               Justice League
# ...   ..           ...                                          ...
# 2399  56          2013                     All Superheroes Must Die
# 2400  59          2011                                   The Ridges
# 2401  73          2012                                    Newlyweds
# 2402  78          2018                                       Red 11
# 2403  81          2015                         A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross  \
# 0          410,600,000    241,063,875   1,045,663,875
# 1          350,000,000     42,762,350     149,762,350
# 2          330,600,000    459,005,868   1,403,013,963
# 3          300,000,000    678,815,482   2,048,134,200
# 4          300,000,000    229,024,295     655,945,209
# ...                ...            ...             ...
# 2399            20,000              0               0
# 2400            17,300              0               0
# 2401             9,000          4,584           4,584
# 2402             7,000              0               0
# 2403             1,400              0               0
#
#                                     primary_title                    genres  \
# 0     Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 1                                    Dark Phoenix   Action,Adventure,Sci-Fi
# 2                         Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# 3                          Avengers: Infinity War   Action,Adventure,Sci-Fi
# 4                                  Justice League  Action,Adventure,Fantasy
# ...                                           ...                       ...
# 2399                     All Superheroes Must Die           Sci-Fi,Thriller
# 2400                                   The Ridges     Drama,Horror,Thriller
# 2401                                    Newlyweds              Comedy,Drama
# 2402                                       Red 11    Horror,Sci-Fi,Thriller
# 2403                         A Plague So Pleasant     Drama,Horror,Thriller
#
#       runtime_minutes  start_year
# 0               136.0        2011
# 1               113.0        2019
# 2               141.0        2015
# 3               149.0        2018
# 4               120.0        2017
# ...               ...         ...
# 2399             78.0        2011
# 2400             89.0        2011
# 2401             95.0        2011
# 2402             77.0        2019
# 2403             76.0        2013
#
# [1780 rows x 10 columns]

# %%
#Converting budgets and returns to integers
budgets_genres_df['production_budget']= budgets_genres_df['production_budget'].str.replace(',','').astype(int)
budgets_genres_df['domestic_gross']= budgets_genres_df['domestic_gross'].str.replace(',','').astype(int)
budgets_genres_df['worldwide_gross']= budgets_genres_df['worldwide_gross'].str.replace(',','').astype(int)
budgets_genres_df
# Out:
#       id  release_date                                        movie  \
# 0      2          2011  Pirates of the Caribbean: On Stranger Tides
# 1      3          2019                                 Dark Phoenix
# 2      4          2015                      Avengers: Age of Ultron
# 3      7          2018                       Avengers: Infinity War
# 4      9          2017                               Justice League
# ...   ..           ...                                          ...
# 2399  56          2013                     All Superheroes Must Die
# 2400  59          2011                                   The Ridges
# 2401  73          2012                                    Newlyweds
# 2402  78          2018                                       Red 11
# 2403  81          2015                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             410600000       241063875       1045663875
# 1             350000000        42762350        149762350
# 2             330600000       459005868       1403013963
# 3             300000000       678815482       2048134200
# 4             300000000       229024295        655945209
# ...                 ...             ...              ...
# 2399              20000               0                0
# 2400              17300               0                0
# 2401               9000            4584             4584
# 2402               7000               0                0
# 2403               1400               0                0
#
#                                     primary_title                    genres  \
# 0     Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 1                                    Dark Phoenix   Action,Adventure,Sci-Fi
# 2                         Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# 3                          Avengers: Infinity War   Action,Adventure,Sci-Fi
# 4                                  Justice League  Action,Adventure,Fantasy
# ...                                           ...                       ...
# 2399                     All Superheroes Must Die           Sci-Fi,Thriller
# 2400                                   The Ridges     Drama,Horror,Thriller
# 2401                                    Newlyweds              Comedy,Drama
# 2402                                       Red 11    Horror,Sci-Fi,Thriller
# 2403                         A Plague So Pleasant     Drama,Horror,Thriller
#
#       runtime_minutes  start_year
# 0               136.0        2011
# 1               113.0        2019
# 2               141.0        2015
# 3               149.0        2018
# 4               120.0        2017
# ...               ...         ...
# 2399             78.0        2011
# 2400             89.0        2011
# 2401             95.0        2011
# 2402             77.0        2019
# 2403             76.0        2013
#
# [1780 rows x 10 columns]

# %%
#ADD ROI column and convert type to float
budgets_genres_df['ROI']= ((budgets_genres_df['worldwide_gross'] / budgets_genres_df['production_budget']-1)*100)
budgets_genres_df['ROI']= budgets_genres_df['ROI'].astype(float)
budgets_genres_df
# Out:
#       id  release_date                                        movie  \
# 0      2          2011  Pirates of the Caribbean: On Stranger Tides
# 1      3          2019                                 Dark Phoenix
# 2      4          2015                      Avengers: Age of Ultron
# 3      7          2018                       Avengers: Infinity War
# 4      9          2017                               Justice League
# ...   ..           ...                                          ...
# 2399  56          2013                     All Superheroes Must Die
# 2400  59          2011                                   The Ridges
# 2401  73          2012                                    Newlyweds
# 2402  78          2018                                       Red 11
# 2403  81          2015                         A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             410600000       241063875       1045663875
# 1             350000000        42762350        149762350
# 2             330600000       459005868       1403013963
# 3             300000000       678815482       2048134200
# 4             300000000       229024295        655945209
# ...                 ...             ...              ...
# 2399              20000               0                0
# 2400              17300               0                0
# 2401               9000            4584             4584
# 2402               7000               0                0
# 2403               1400               0                0
#
#                                     primary_title                    genres  \
# 0     Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 1                                    Dark Phoenix   Action,Adventure,Sci-Fi
# 2                         Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# 3                          Avengers: Infinity War   Action,Adventure,Sci-Fi
# 4                                  Justice League  Action,Adventure,Fantasy
# ...                                           ...                       ...
# 2399                     All Superheroes Must Die           Sci-Fi,Thriller
# 2400                                   The Ridges     Drama,Horror,Thriller
# 2401                                    Newlyweds              Comedy,Drama
# 2402                                       Red 11    Horror,Sci-Fi,Thriller
# 2403                         A Plague So Pleasant     Drama,Horror,Thriller
#
#       runtime_minutes  start_year         ROI
# 0               136.0        2011  154.667286
# 1               113.0        2019  -57.210757
# 2               141.0        2015  324.384139
# 3               149.0        2018  582.711400
# 4               120.0        2017  118.648403
# ...               ...         ...         ...
# 2399             78.0        2011 -100.000000
# 2400             89.0        2011 -100.000000
# 2401             95.0        2011  -49.066667
# 2402             77.0        2019 -100.000000
# 2403             76.0        2013 -100.000000
#
# [1780 rows x 11 columns]

# %%
#Start_year is redundant with release_date
budgets_genres_df= budgets_genres_df.drop(columns = 'start_year')
budgets_genres_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   2          2011  Pirates of the Caribbean: On Stranger Tides
# 1   3          2019                                 Dark Phoenix
# 2   4          2015                      Avengers: Age of Ultron
# 3   7          2018                       Avengers: Infinity War
# 4   9          2017                               Justice League
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0          410600000       241063875       1045663875
# 1          350000000        42762350        149762350
# 2          330600000       459005868       1403013963
# 3          300000000       678815482       2048134200
# 4          300000000       229024295        655945209
#
#                                  primary_title                    genres  \
# 0  Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 1                                 Dark Phoenix   Action,Adventure,Sci-Fi
# 2                      Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# 3                       Avengers: Infinity War   Action,Adventure,Sci-Fi
# 4                               Justice League  Action,Adventure,Fantasy
#
#    runtime_minutes         ROI
# 0            136.0  154.667286
# 1            113.0  -57.210757
# 2            141.0  324.384139
# 3            149.0  582.711400
# 4            120.0  118.648403

# %%
budgets_genres_df.dtypes
# Out:
# id                     int64
# release_date           int32
# movie                 object
# production_budget      int32
# domestic_gross         int32
# worldwide_gross        int32
# primary_title         object
# genres                object
# runtime_minutes      float64
# ROI                  float64
# dtype: object

# %%
#check if any null values for genre or runtime
budgets_genres_df['runtime_minutes'].isnull().sum()
budgets_genres_df['genres'].isnull().sum()
# Out:
# 13

# %%
#drop null values
budgets_genres_df= budgets_genres_df.dropna()
budgets_genres_df.head(50)
# Out:
#     id  release_date                                             movie  \
# 0    2          2011       Pirates of the Caribbean: On Stranger Tides
# 1    3          2019                                      Dark Phoenix
# 2    4          2015                           Avengers: Age of Ultron
# 3    7          2018                            Avengers: Infinity War
# 4    9          2017                                    Justice League
# 5   10          2015                                           Spectre
# 6   11          2012                             The Dark Knight Rises
# 7   12          2018                           Solo: A Star Wars Story
# 8   13          2013                                   The Lone Ranger
# 9   14          2012                                       John Carter
# 10  15          2010                                           Tangled
# 11  17          2016                        Captain America: Civil War
# 12  18          2016                Batman v Superman: Dawn of Justice
# 13  19          2012                 The Hobbit: An Unexpected Journey
# 14  21          2013               The Hobbit: The Desolation of Smaug
# 15  22          2014         The Hobbit: The Battle of the Five Armies
# 16  23          2017                           The Fate of the Furious
# 17  25          2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 18  27          2012                                      The Avengers
# 19  29          2013                                      Man of Steel
# 20  31          2012                            The Amazing Spider-Man
# 21  32          2012                                        Battleship
# 22  33          2017                     Transformers: The Last Knight
# 23  34          2015                                    Jurassic World
# 24  35          2012                                    Men in Black 3
# 25  37          2014                   Transformers: Age of Extinction
# 34  42          2018                                     Black Panther
# 35  44          2018                                     Incredibles 2
# 36  45          2016                      Rogue One: A Star Wars Story
# 37  46          2016                                      Finding Dory
# 38  47          2010                                       Toy Story 3
# 39  48          2013                                        Iron Man 3
# 40  51          2010                               Alice in Wonderland
# 42  52          2012                                           Skyfall
# 43  53          2013                               Monsters University
# 44  54          2013                         Oz the Great and Powerful
# 45  55          2014                        X-Men: Days of Future Past
# 46  56          2014                          The Amazing Spider-Man 2
# 47  57          2011                                            Cars 2
# 48  60          2018       Fantastic Beasts: The Crimes of Grindelwald
# 49  62          2011                                     Green Lantern
# 50  64          2011                    Transformers: Dark of the Moon
# 51  65          2017                                         The Mummy
# 52  66          2013                             Jack the Giant Slayer
# 53  67          2015                                         Furious 7
# 54  68          2013                           Star Trek Into Darkness
# 55  69          2013                                       World War Z
# 56  70          2013                                  The Great Gatsby
# 57  72          2013                                       Pacific Rim
# 58  73          2015                                 The Good Dinosaur
#
#     production_budget  domestic_gross  worldwide_gross  \
# 0           410600000       241063875       1045663875
# 1           350000000        42762350        149762350
# 2           330600000       459005868       1403013963
# 3           300000000       678815482       2048134200
# 4           300000000       229024295        655945209
# 5           300000000       200074175        879620923
# 6           275000000       448139099       1084439099
# 7           275000000       213767512        393151347
# 8           275000000        89302115        260002115
# 9           275000000        73058679        282778100
# 10          260000000       200821936        586477240
# 11          250000000       408084349       1140069413
# 12          250000000       330360194        867500281
# 13          250000000       303003568       1017003568
# 14          250000000       258366855        960366855
# 15          250000000       255119788        945577621
# 16          250000000       225764765       1234846267
# 17          230000000       172558876        788241137
# 18          225000000       623279547       1517935897
# 19          225000000       291045518        667999518
# 20          220000000       262030663        757890267
# 21          220000000        65233400        313477717
# 22          217000000       130168683        602893340
# 23          215000000       652270625       1648854864
# 24          215000000       179020854        654213485
# 25          210000000       245439076       1104039076
# 34          200000000       700059566       1348258224
# 35          200000000       608581744       1242520711
# 36          200000000       532177324       1049102856
# 37          200000000       486295561       1021215193
# 38          200000000       415004880       1068879522
# 39          200000000       408992272       1215392272
# 40          200000000       334191110       1025491110
# 42          200000000       304360277       1110526981
# 43          200000000       268488329        743588329
# 44          200000000       234770996        490359051
# 45          200000000       233921534        747862775
# 46          200000000       202853933        708996336
# 47          200000000       191450875        560155383
# 48          200000000       159555901        652220086
# 49          200000000       116601172        219535492
# 50          195000000       352390543       1123790543
# 51          195000000        80101125        409953905
# 52          195000000        65187603        197687603
# 53          190000000       353007020       1518722794
# 54          190000000       228778661        467381584
# 55          190000000       202359711        531514650
# 56          190000000       144840419        351040419
# 57          190000000       101802906        411002906
# 58          187500000       123087120        333771037
#
#                                        primary_title  \
# 0        Pirates of the Caribbean: On Stranger Tides
# 1                                       Dark Phoenix
# 2                            Avengers: Age of Ultron
# 3                             Avengers: Infinity War
# 4                                     Justice League
# 5                                            Spectre
# 6                              The Dark Knight Rises
# 7                            Solo: A Star Wars Story
# 8                                    The Lone Ranger
# 9                                        John Carter
# 10                                           Tangled
# 11                        Captain America: Civil War
# 12                Batman v Superman: Dawn of Justice
# 13                 The Hobbit: An Unexpected Journey
# 14               The Hobbit: The Desolation of Smaug
# 15         The Hobbit: The Battle of the Five Armies
# 16                           The Fate of the Furious
# 17  Pirates of the Caribbean: Dead Men Tell No Tales
# 18                                      The Avengers
# 19                                      Man of Steel
# 20                            The Amazing Spider-Man
# 21                                        Battleship
# 22                     Transformers: The Last Knight
# 23                                    Jurassic World
# 24                                    Men in Black 3
# 25                   Transformers: Age of Extinction
# 34                                     Black Panther
# 35                                     Incredibles 2
# 36                      Rogue One: A Star Wars Story
# 37                                      Finding Dory
# 38                                       Toy Story 3
# 39                                        Iron Man 3
# 40                               Alice in Wonderland
# 42                                           Skyfall
# 43                               Monsters University
# 44                         Oz the Great and Powerful
# 45                        X-Men: Days of Future Past
# 46                          The Amazing Spider-Man 2
# 47                                            Cars 2
# 48       Fantastic Beasts: The Crimes of Grindelwald
# 49                                     Green Lantern
# 50                    Transformers: Dark of the Moon
# 51                                         The Mummy
# 52                             Jack the Giant Slayer
# 53                                         Furious 7
# 54                           Star Trek Into Darkness
# 55                                       World War Z
# 56                                  The Great Gatsby
# 57                                       Pacific Rim
# 58                                 The Good Dinosaur
#
#                         genres  runtime_minutes         ROI
# 0     Action,Adventure,Fantasy            136.0  154.667286
# 1      Action,Adventure,Sci-Fi            113.0  -57.210757
# 2      Action,Adventure,Sci-Fi            141.0  324.384139
# 3      Action,Adventure,Sci-Fi            149.0  582.711400
# 4     Action,Adventure,Fantasy            120.0  118.648403
# 5    Action,Adventure,Thriller            148.0  193.206974
# 6              Action,Thriller            164.0  294.341491
# 7     Action,Adventure,Fantasy            135.0   42.964126
# 8     Action,Adventure,Western            150.0   -5.453776
# 9      Action,Adventure,Sci-Fi            132.0    2.828400
# 10  Adventure,Animation,Comedy            100.0  125.568169
# 11     Action,Adventure,Sci-Fi            147.0  356.027765
# 12    Action,Adventure,Fantasy            151.0  247.000112
# 13    Adventure,Family,Fantasy            169.0  306.801427
# 14           Adventure,Fantasy            161.0  284.146742
# 15           Adventure,Fantasy            144.0  278.231048
# 16       Action,Crime,Thriller            136.0  393.938507
# 17    Action,Adventure,Fantasy            129.0  242.713538
# 18     Action,Adventure,Sci-Fi            143.0  574.638176
# 19     Action,Adventure,Sci-Fi            143.0  196.888675
# 20     Action,Adventure,Sci-Fi            136.0  244.495576
# 21     Action,Adventure,Sci-Fi            131.0   42.489871
# 22     Action,Adventure,Sci-Fi            154.0  177.831032
# 23     Action,Adventure,Sci-Fi            124.0  666.909239
# 24     Action,Adventure,Comedy            106.0  204.285342
# 25     Action,Adventure,Sci-Fi            165.0  425.732893
# 34     Action,Adventure,Sci-Fi            134.0  574.129112
# 35  Action,Adventure,Animation            118.0  521.260356
# 36     Action,Adventure,Sci-Fi            133.0  424.551428
# 37  Adventure,Animation,Comedy             97.0  410.607596
# 38  Adventure,Animation,Comedy            103.0  434.439761
# 39     Action,Adventure,Sci-Fi            130.0  507.696136
# 40    Adventure,Family,Fantasy            108.0  412.745555
# 42   Action,Adventure,Thriller            143.0  455.263490
# 43  Adventure,Animation,Comedy            104.0  271.794164
# 44    Adventure,Family,Fantasy            130.0  145.179525
# 45     Action,Adventure,Sci-Fi            132.0  273.931388
# 46     Action,Adventure,Sci-Fi            142.0  254.498168
# 47  Adventure,Animation,Comedy            106.0  180.077692
# 48    Adventure,Family,Fantasy            134.0  226.110043
# 49     Action,Adventure,Sci-Fi            114.0    9.767746
# 50     Action,Adventure,Sci-Fi            154.0  476.302843
# 51    Action,Adventure,Fantasy            110.0  110.232772
# 52           Adventure,Fantasy            114.0    1.378258
# 53       Action,Crime,Thriller            137.0  699.327786
# 54     Action,Adventure,Sci-Fi            132.0  145.990307
# 55     Action,Adventure,Horror            116.0  179.744553
# 56               Drama,Romance            143.0   84.758115
# 57     Action,Adventure,Sci-Fi            131.0  116.317319
# 58  Adventure,Animation,Comedy             93.0   78.011220

# %%
budgets_genres_df.isnull().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# primary_title        0
# genres               0
# runtime_minutes      0
# ROI                  0
# dtype: int64

# %% [markdown]
# ## Data Modeling: Runtime

# %%
#Checking for a correlation with runtime and ROI
runtime_correlation= budgets_genres_df['runtime_minutes'].corr(budgets_genres_df['ROI'])
runtime_correlation
# Out:
# -0.02083180425301194

# %%
#film runtime and ROI data visualization
fig, ax =plt.subplots(figsize=(15,10))
ax.scatter(x=budgets_genres_df['runtime_minutes'], y=budgets_genres_df['ROI'], color= 'purple')
ax.set_title('Film Runtime and ROI')
ax.set_xlabel('Runtime Minutes')
ax.set_ylabel('Film ROI')
ax.set_ylim(-1,8000)
ax.yaxis.set_major_formatter('{x:1}%')

# %% [markdown]
# There is a slight negative correlation between runtime and ROI but they are not meaningfully related.

# %%
budgets_genres_df['runtime_minutes'].describe()
# Out:
# count    1687.000000
# mean      106.363960
# std        17.409596
# min        75.000000
# 25%        93.000000
# 50%       104.000000
# 75%       116.000000
# max       181.000000
# Name: runtime_minutes, dtype: float64

# %%
#Calculate the number of 'successes' (ROI =>100) in each bin
fig, ax= plt.subplots(figsize=(10,7))
df_double= budgets_genres_df[budgets_genres_df['ROI']>= 100]
ax.hist(x=df_double['runtime_minutes'], bins= 10, range=(75,175), edgecolor='black')
plt.xticks()
ax.set_xlabel('Runtime Minutes')
ax.set_ylabel('Frequency')
ax.set_title('Runtime Distribution')
# Out:
# Text(0.5, 1.0, 'Runtime Distribution')

# %%
#Calculating the number of films in each bin
fig, ax= plt.subplots(figsize=(10,7))
ax.hist(x=budgets_genres_df['runtime_minutes'], bins= 10, range=(75,175), edgecolor='black')
plt.xticks()
ax.set_xlabel('Runtime Minutes')
ax.set_ylabel('Frequency')
ax.set_title('Runtime Distribution')
# Out:
# Text(0.5, 1.0, 'Runtime Distribution')

# %%
#Amount of 'successes' as compared with all entries 
y1=  df_double['runtime_minutes']
y2= budgets_genres_df['runtime_minutes']
colors= ['b','g']
labels= ['ROI =>100', 'Total']
fig, ax = plt.subplots(figsize=(15,10))
ax.hist([y1,y2], color= colors, label= labels, edgecolor= 'black', bins=10, range=(75,175))
ax.set_xlabel('Runtime Minutes')
ax.set_ylabel('Frequency')
ax.set_title('Double ROI stats')
ax.legend()

# %%
#Correlation Between Production budget and runtime
correlation1 = budgets_genres_df['runtime_minutes'].corr(budgets_genres_df['production_budget'])
correlation1
# Out:
# 0.38535646755558123

# %% [markdown]
# ## Evaluation: Runtime
#
# There is meaningful correlation between runtime and production budget that suggests smaller budgets tend to have shorter runtimes. Films 95-105 minutes had the most total entries, and was also the bin that offered the most 100% ROI
# (doubling their money) entries. As the runtime minutes goes up after 85 minutes, sample size goes down even though odds of a double tend to increase- likely due to having higher production budgets.
#
# Runtime alone is likely not a key predictor for ROI and is dependent on production budget.

# %% [markdown]
# ## Data Modeling: Genres

# %%
budgets_genres_df.sort_values(by='genres').head(60)
# Out:
#        id  release_date                                             movie  \
# 924    52          2014                                        Blood Ties
# 1288   79          2012                       The Man with the Iron Fists
# 343    19          2016                                 The Little Prince
# 2270   80          2014                                      Diamond Ruff
# 1346   28          2016                                Reign of Assassins
# 1818   54          2014                                     Falcon Rising
# 480    22          2016                          Kubo and the Two Strings
# 106    29          2014                                        Big Hero 6
# 35     44          2018                                     Incredibles 2
# 876   100          2018                        Bilal: A New Breed of Hero
# 413    44          2014                                    The Lego Movie
# 1597   36          2019                          Dragon Ball Super: Broly
# 146    99          2014                        How to Train Your Dragon 2
# 186    52          2011                          The Adventures of Tintin
# 107    30          2010                          How to Train Your Dragon
# 156    26          2013                                        The Croods
# 151    11          2016                                   Kung Fu Panda 3
# 134    74          2011                                   Kung Fu Panda 2
# 189    56          2019        How to Train Your Dragon: The Hidden World
# 148     2          2012                             Rise of the Guardians
# 370    20          2017                            The Lego Ninjago Movie
# 179    46          2011                                     Puss in Boots
# 252    90          2010     Legend of the Guardians: The Owls of Ga'Hoole
# 401     3          2015                                           Everest
# 258     1          2015                           In the Heart of the Sea
# 738    89          2018                                            Adrift
# 157    27          2015                                      The Revenant
# 66     82          2017                                    Thor: Ragnarok
# 217     2          2010                                    Knight and Day
# 239    54          2017                       Kingsman: The Golden Circle
# 284    38          2017                    Jumanji: Welcome to the Jungle
# 1979   46          2015                                             Stung
# 785    82          2015              The Young and Prodigious T.S. Spivet
# 280    29          2015                      Kingsman: The Secret Service
# 205    81          2017                                    Monster Trucks
# 2261   66          2013                             Detention of the Dead
# 340    10          2012                  Journey 2: The Mysterious Island
# 223    15          2018                                        Deadpool 2
# 235    42          2019                       Men in Black: International
# 765    39          2016                              The Brothers Grimsby
# 294    66          2016                                  Now You See Me 2
# 312    97          2019                                           Shazam!
# 166    41          2018                              Ant-Man and the Wasp
# 195    68          2014                      Teenage Mutant Ninja Turtles
# 188    55          2013                                          R.I.P.D.
# 94     14          2014                           Guardians of the Galaxy
# 1798   99          2016                                      The Hatching
# 596    51          2017                                          Snatched
# 585    19          2011                             Johnny English Reborn
# 24     35          2012                                    Men in Black 3
# 453    56          2016                                          Deadpool
# 167    43          2015                                           Ant-Man
# 161    32          2016  Teenage Mutant Ninja Turtles: Out of the Shadows
# 1601   50          2017                                 Posledniy bogatyr
# 602    64          2012                                    Man on a Ledge
# 2056    1          2015                                        Shark Lake
# 667    22          2018                               The Hurricane Heist
# 1089   43          2016                                             Nerve
# 359    64          2016                                           Inferno
# 1038   34          2015                          The Transporter Refueled
#
#       production_budget  domestic_gross  worldwide_gross  \
# 924            26000000           42472          2923959
# 1288           15000000        15634090         22018988
# 343            77500000         1311213        102028919
# 2270             500000               0                0
# 1346           14000000               0         11354230
# 1818            4500000           11774            11774
# 480            55000000        48023088         77548122
# 106           165000000       222527828        652127828
# 35            200000000       608581744       1242520711
# 876            30000000          490973           648599
# 413            60000000       257784718        457729388
# 1597            8500000        30376755        122747755
# 146           145000000       177002924        614586270
# 186           130000000        77591831        373993951
# 107           165000000       217581232        494870992
# 156           135000000       187168425        573068425
# 151           140000000       143528619        517599142
# 134           150000000       165249063        664837547
# 189           129000000       160791800        519258283
# 148           145000000       103412758        306900902
# 370            70000000        59281555        122737201
# 179           130000000       149260504        554987477
# 252           100000000        55675313        139716717
# 401            65000000        43482270        221297061
# 258           100000000        25020758         89693309
# 738            35000000        31445011         57897191
# 157           135000000       183637894        532938302
# 66            180000000       315058289        846980024
# 217           117000000        76423035        258751370
# 239           104000000       100234838        408803696
# 284            90000000       404508916        964496193
# 1979            2500000               0                0
# 785            33000000          176847           357687
# 280            94000000       128261724        404561724
# 205           125000000        33370166         61642798
# 2261             500000            1778             1778
# 340            79000000       103860290        318146162
# 223           110000000       324591735        786680557
# 235           110000000         3100000          3100000
# 765            35000000         6864016         28720470
# 294            90000000        65075540        328325007
# 312            85000000       139606856        362899733
# 166           130000000       216648740        623144660
# 195           125000000       191204754        485004754
# 188           130000000        33618855         79076678
# 94            170000000       333172112        770867516
# 1798            5000000               0                0
# 596            42000000        45852178         57852177
# 585            45000000         8406711        164640401
# 24            215000000       179020854        654213485
# 453            58000000       363070709        801025593
# 167           130000000       180202163        518858449
# 161           135000000        82051601        245328374
# 1601            8500000               0         30700192
# 602            42000000        18620000         49621440
# 2056            2000000               0                0
# 667            40000000         6115824         30963684
# 1089           20000000        38583626         70652284
# 359            75000000        34343574        219519367
# 1038           22000000        16029670         69698495
#
#                                          primary_title  \
# 924                                         Blood Ties
# 1288                       The Man with the Iron Fists
# 343                                  The Little Prince
# 2270                                      Diamond Ruff
# 1346                                Reign of Assassins
# 1818                                     Falcon Rising
# 480                           Kubo and the Two Strings
# 106                                         Big Hero 6
# 35                                       Incredibles 2
# 876                         Bilal: A New Breed of Hero
# 413                                     The Lego Movie
# 1597                          Dragon Ball Super: Broly
# 146                         How to Train Your Dragon 2
# 186                           The Adventures of Tintin
# 107                           How to Train Your Dragon
# 156                                         The Croods
# 151                                    Kung Fu Panda 3
# 134                                    Kung Fu Panda 2
# 189         How to Train Your Dragon: The Hidden World
# 148                              Rise of the Guardians
# 370                             The Lego Ninjago Movie
# 179                                      Puss in Boots
# 252      Legend of the Guardians: The Owls of Ga'Hoole
# 401                                            Everest
# 258                            In the Heart of the Sea
# 738                                             Adrift
# 157                                       The Revenant
# 66                                      Thor: Ragnarok
# 217                                     Knight and Day
# 239                        Kingsman: The Golden Circle
# 284                     Jumanji: Welcome to the Jungle
# 1979                                             Stung
# 785               The Young and Prodigious T.S. Spivet
# 280                       Kingsman: The Secret Service
# 205                                     Monster Trucks
# 2261                             Detention of the Dead
# 340                   Journey 2: The Mysterious Island
# 223                                         Deadpool 2
# 235                        Men in Black: International
# 765                               The Brothers Grimsby
# 294                                   Now You See Me 2
# 312                                            Shazam!
# 166                               Ant-Man and the Wasp
# 195                       Teenage Mutant Ninja Turtles
# 188                                           R.I.P.D.
# 94                             Guardians of the Galaxy
# 1798                                      The Hatching
# 596                                           Snatched
# 585                              Johnny English Reborn
# 24                                      Men in Black 3
# 453                                           Deadpool
# 167                                            Ant-Man
# 161   Teenage Mutant Ninja Turtles: Out of the Shadows
# 1601                                 Posledniy bogatyr
# 602                                     Man on a Ledge
# 2056                                        Shark Lake
# 667                                The Hurricane Heist
# 1089                                             Nerve
# 359                                            Inferno
# 1038                          The Transporter Refueled
#
#                           genres  runtime_minutes          ROI
# 924                       Action            120.0   -88.754004
# 1288                      Action             95.0    46.793253
# 343                       Action             93.0    31.650218
# 2270                      Action             82.0  -100.000000
# 1346            Action,Adventure            117.0   -18.898357
# 1818            Action,Adventure            103.0   -99.738356
# 480   Action,Adventure,Animation            101.0    40.996585
# 106   Action,Adventure,Animation            102.0   295.228987
# 35    Action,Adventure,Animation            118.0   521.260356
# 876   Action,Adventure,Animation            105.0   -97.838003
# 413   Action,Adventure,Animation            100.0   662.882313
# 1597  Action,Adventure,Animation            100.0  1344.091235
# 146   Action,Adventure,Animation            102.0   323.852600
# 186   Action,Adventure,Animation            107.0   187.687655
# 107   Action,Adventure,Animation             98.0   199.921813
# 156   Action,Adventure,Animation             98.0   324.495130
# 151   Action,Adventure,Animation             95.0   269.713673
# 134   Action,Adventure,Animation             90.0   343.225031
# 189   Action,Adventure,Animation            104.0   302.525801
# 148   Action,Adventure,Animation             97.0   111.655794
# 370   Action,Adventure,Animation            101.0    75.338859
# 179   Action,Adventure,Animation             90.0   326.913444
# 252   Action,Adventure,Animation             97.0    39.716717
# 401   Action,Adventure,Biography            121.0   240.457017
# 258   Action,Adventure,Biography            122.0   -10.306691
# 738   Action,Adventure,Biography             96.0    65.420546
# 157   Action,Adventure,Biography            156.0   294.769113
# 66       Action,Adventure,Comedy            130.0   370.544458
# 217      Action,Adventure,Comedy            109.0   121.155017
# 239      Action,Adventure,Comedy            141.0   293.080477
# 284      Action,Adventure,Comedy            119.0   971.662437
# 1979     Action,Adventure,Comedy             87.0  -100.000000
# 785      Action,Adventure,Comedy            105.0   -98.916100
# 280      Action,Adventure,Comedy            129.0   330.384813
# 205      Action,Adventure,Comedy            104.0   -50.685762
# 2261     Action,Adventure,Comedy             87.0   -99.644400
# 340      Action,Adventure,Comedy             94.0   302.716661
# 223      Action,Adventure,Comedy            119.0   615.164143
# 235      Action,Adventure,Comedy            115.0   -97.181818
# 765      Action,Adventure,Comedy             83.0   -17.941514
# 294      Action,Adventure,Comedy            129.0   264.805563
# 312      Action,Adventure,Comedy            132.0   326.940862
# 166      Action,Adventure,Comedy            118.0   379.342046
# 195      Action,Adventure,Comedy            101.0   288.003803
# 188      Action,Adventure,Comedy             96.0   -39.171786
# 94       Action,Adventure,Comedy            121.0   353.451480
# 1798     Action,Adventure,Comedy             90.0  -100.000000
# 596      Action,Adventure,Comedy             90.0    37.743279
# 585      Action,Adventure,Comedy            101.0   265.867558
# 24       Action,Adventure,Comedy            106.0   204.285342
# 453      Action,Adventure,Comedy            108.0  1281.078609
# 167      Action,Adventure,Comedy            117.0   299.121884
# 161      Action,Adventure,Comedy            112.0    81.724721
# 1601     Action,Adventure,Comedy            114.0   261.178729
# 602       Action,Adventure,Crime            102.0    18.146286
# 2056      Action,Adventure,Crime             92.0  -100.000000
# 667       Action,Adventure,Crime            103.0   -22.590790
# 1089      Action,Adventure,Crime             96.0   253.261420
# 359       Action,Adventure,Crime            121.0   192.692489
# 1038      Action,Adventure,Crime             96.0   216.811341

# %%
df_double.tail(50)
# Out:
#       id  release_date                                      movie  \
# 2023  41          2014                               The Babadook
# 2028  62          2015                                Knock Knock
# 2057   2          2010                                     Buried
# 2062   9          2011                                  Submarine
# 2069  11          2013                  ABCD (Any Body Can Dance)
# 2074  15          2010                          The Last Exorcism
# 2075  18          2012                Beasts of the Southern Wild
# 2081  42          2014                               The Lunchbox
# 2086  63          2011                                  Insidious
# 2087  64          2016                                  Moonlight
# 2089  70          2018                                     Unsane
# 2090  77          2013                             The To Do List
# 2110  21          2015                                    Mustang
# 2126  51          2014                          Dear White People
# 2127  52          2013                                Filly Brown
# 2129  66          2013                                   Home Run
# 2148  12          2012                           The Devil Inside
# 2149  14          2015                                 Unfriended
# 2150  17          2013                                You're Next
# 2151  18          2012                          Chernobyl Diaries
# 2152  25          2010                             Blue Valentine
# 2153  29          2018                       Unfriended: Dark Web
# 2154  31          2015                          The Green Inferno
# 2155  32          2017                        I Am Not Your Negro
# 2156  33          2012                               The Sessions
# 2157  35          2012                               October Baby
# 2158  36          2014                         The Skeleton Twins
# 2159  41          2014                              Obvious Child
# 2160  42          2011                   Martha Marcy May Marlene
# 2201  35          2017                                  Lowriders
# 2203  38          2013                          Fruitvale Station
# 2204  39          2016                            Meet the Blacks
# 2215  75          2011               Kevin Hart: Laugh at My Pain
# 2216  77          2012                      Safety Not Guaranteed
# 2251  39          2011  Sholem Aleichem: Laughing in the Darkness
# 2253  50          2010                                   Monsters
# 2295  59          2014                       All You Need Is Love
# 2304  68          2012                                 Compliance
# 2305  72          2017                                    Sleight
# 2327  10          2012                                       Burn
# 2329  18          2011                             The Grace Card
# 2330  21          2015                              The Overnight
# 2340  43          2011                                    Weekend
# 2344  48          2011                              Another Earth
# 2348  68          2012                          Sound of My Voice
# 2351  73          2012                       Your Sister's Sister
# 2352  80          2015                                The Gallows
# 2353  86          2017                              A Ghost Story
# 2375  18          2010                             Tiny Furniture
# 2387  38          2016                                     Krisha
#
#       production_budget  domestic_gross  worldwide_gross  \
# 2023            2000000          950792          7482387
# 2028            2000000           36336          6328516
# 2057            1987650         1044143         21270290
# 2062            1900000          467602          4581937
# 2069            1900000          222098         10137234
# 2074            1800000        41034350         70165900
# 2075            1800000        12795746         23265132
# 2081            1700000         4231500         12231500
# 2086            1500000        54009150         99870886
# 2087            1500000        27854931         65245512
# 2089            1500000         7690044         14244931
# 2090            1500000         3491669          4128828
# 2110            1400000          845464          5552584
# 2126            1250000         4404154          5403771
# 2127            1250000         2850357          2940411
# 2129            1200000         2859955          2859955
# 2148            1000000        53262945        101759490
# 2149            1000000        32789645         64364198
# 2150            1000000        18494006         26887177
# 2151            1000000        18119640         42411721
# 2152            1000000         9737892         16566240
# 2153            1000000         8866745         16434588
# 2154            1000000         7192291         12931420
# 2155            1000000         7123919          9617402
# 2156            1000000         6002451         11495204
# 2157            1000000         5355847          5391992
# 2158            1000000         5284309          5797192
# 2159            1000000         3122616          3324070
# 2160            1000000         2981038          5438911
# 2201             916000         6179955          6188421
# 2203             900000        16098998         17549645
# 2204             900000         9097072          9097072
# 2215             750000         7706436          7712436
# 2216             750000         4010957          4422318
# 2251             500000         1131261          1131261
# 2253             500000          237301          5639730
# 2295             300000               0          3565259
# 2304             270000          319285           830700
# 2305             250000         3930990          3934450
# 2327             225000         1109276          1109276
# 2329             200000         2430735          2430735
# 2330             200000         1109808          1165996
# 2340             190000          484592          1577585
# 2344             175000         1321194          2102779
# 2348             135000          408015           429448
# 2351             120000         1597486          3090593
# 2352             100000        22764410         41656474
# 2353             100000         1594798          2769782
# 2375              50000          391674           424149
# 2387              30000          144822           144822
#
#                                   primary_title                   genres  \
# 2023                               The Babadook             Drama,Horror
# 2028                                Knock Knock           Drama,Thriller
# 2057                                     Buried              Documentary
# 2062                                  Submarine     Comedy,Drama,Romance
# 2069                  ABCD (Any Body Can Dance)              Drama,Music
# 2074                          The Last Exorcism    Drama,Horror,Thriller
# 2075                Beasts of the Southern Wild  Adventure,Drama,Fantasy
# 2081                               The Lunchbox            Drama,Romance
# 2086                                  Insidious  Horror,Mystery,Thriller
# 2087                                  Moonlight                    Drama
# 2089                                     Unsane     Drama,Horror,Mystery
# 2090                             The To Do List           Comedy,Romance
# 2110                                    Mustang                    Drama
# 2126                          Dear White People     Comedy,Drama,Romance
# 2127                                Filly Brown              Drama,Music
# 2129                                   Home Run              Drama,Sport
# 2148                           The Devil Inside                   Horror
# 2149                                 Unfriended  Horror,Mystery,Thriller
# 2150                                You're Next     Action,Comedy,Horror
# 2151                          Chernobyl Diaries  Horror,Mystery,Thriller
# 2152                             Blue Valentine            Drama,Romance
# 2153                       Unfriended: Dark Web     Crime,Horror,Mystery
# 2154                          The Green Inferno         Adventure,Horror
# 2155                        I Am Not Your Negro              Documentary
# 2156                               The Sessions   Biography,Comedy,Drama
# 2157                               October Baby                    Drama
# 2158                         The Skeleton Twins     Comedy,Drama,Romance
# 2159                              Obvious Child     Comedy,Drama,Romance
# 2160                   Martha Marcy May Marlene   Drama,Mystery,Thriller
# 2201                                  Lowriders    Adventure,Crime,Drama
# 2203                          Fruitvale Station  Biography,Drama,Romance
# 2204                            Meet the Blacks            Comedy,Horror
# 2215               Kevin Hart: Laugh at My Pain       Comedy,Documentary
# 2216                      Safety Not Guaranteed     Comedy,Drama,Romance
# 2251  Sholem Aleichem: Laughing in the Darkness              Documentary
# 2253                                   Monsters           Drama,Thriller
# 2295                       All You Need Is Love           Comedy,Romance
# 2304                                 Compliance    Biography,Crime,Drama
# 2305                                    Sleight      Action,Drama,Sci-Fi
# 2327                                       Burn                 Thriller
# 2329                             The Grace Card                    Drama
# 2330                              The Overnight           Comedy,Mystery
# 2340                                    Weekend             Comedy,Drama
# 2344                              Another Earth     Drama,Romance,Sci-Fi
# 2348                          Sound of My Voice     Drama,Mystery,Sci-Fi
# 2351                       Your Sister's Sister             Comedy,Drama
# 2352                                The Gallows  Horror,Mystery,Thriller
# 2353                              A Ghost Story    Drama,Fantasy,Romance
# 2375                             Tiny Furniture     Comedy,Drama,Romance
# 2387                                     Krisha                    Drama
#
#       runtime_minutes           ROI
# 2023             94.0    274.119350
# 2028             99.0    216.425800
# 2057             88.0    970.122506
# 2062             97.0    141.154579
# 2069            160.0    433.538632
# 2074             87.0   3798.105556
# 2075             93.0   1192.507333
# 2081            104.0    619.500000
# 2086            103.0   6558.059067
# 2087            111.0   4249.700800
# 2089             98.0    849.662067
# 2090            104.0    175.255200
# 2110             97.0    296.613143
# 2126            108.0    332.301680
# 2127             80.0    135.232880
# 2129            113.0    138.329583
# 2148             83.0  10075.949000
# 2149             83.0   6336.419800
# 2150             95.0   2588.717700
# 2151             86.0   4141.172100
# 2152            112.0   1556.624000
# 2153             92.0   1543.458800
# 2154            100.0   1193.142000
# 2155             93.0    861.740200
# 2156             95.0   1049.520400
# 2157            107.0    439.199200
# 2158             93.0    479.719200
# 2159             84.0    232.407000
# 2160            102.0    443.891100
# 2201             98.0    575.591812
# 2203             85.0   1849.960556
# 2204             94.0    910.785778
# 2215             89.0    928.324800
# 2216             86.0    489.642400
# 2251             93.0    126.252200
# 2253             97.0   1027.946000
# 2295            113.0   1088.419667
# 2304             90.0    207.666667
# 2305             89.0   1473.780000
# 2327             90.0    393.011556
# 2329            101.0   1115.367500
# 2330             79.0    482.998000
# 2340             80.0    730.307895
# 2344             92.0   1101.588000
# 2348             85.0    218.109630
# 2351             90.0   2475.494167
# 2352             81.0  41556.474000
# 2353             92.0   2669.782000
# 2375             98.0    748.298000
# 2387             83.0    382.740000

# %%
#Understanding genre breakdown
print(budgets_genres_df['genres'].value_counts())
print(df_double['genres'].value_counts())
# Out:
# Drama                           83
# Adventure,Animation,Comedy      62
# Comedy,Drama                    61
# Comedy,Drama,Romance            61
# Comedy                          59
#                                 ..
# Action,Biography,Documentary     1
# Adventure,Horror,Sci-Fi          1
# Drama,History,Mystery            1
# Adventure,Horror                 1
# Adventure,Comedy,Sci-Fi          1
# Name: genres, Length: 249, dtype: int64
# Adventure,Animation,Comedy    45
# Action,Adventure,Sci-Fi       42
# Comedy,Drama,Romance          33
# Comedy,Drama                  30
# Drama                         30
#                               ..
# Comedy,Drama,Musical           1
# Adventure,Crime,Drama          1
# Romance,Sci-Fi,Thriller        1
# Biography,Drama,Fantasy        1
# Adventure,Comedy,Sci-Fi        1
# Name: genres, Length: 161, dtype: int64

# %%
df_double.head()
# Out:
#    id  release_date                                        movie  \
# 0   2          2011  Pirates of the Caribbean: On Stranger Tides
# 2   4          2015                      Avengers: Age of Ultron
# 3   7          2018                       Avengers: Infinity War
# 4   9          2017                               Justice League
# 5  10          2015                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0          410600000       241063875       1045663875
# 2          330600000       459005868       1403013963
# 3          300000000       678815482       2048134200
# 4          300000000       229024295        655945209
# 5          300000000       200074175        879620923
#
#                                  primary_title                     genres  \
# 0  Pirates of the Caribbean: On Stranger Tides   Action,Adventure,Fantasy
# 2                      Avengers: Age of Ultron    Action,Adventure,Sci-Fi
# 3                       Avengers: Infinity War    Action,Adventure,Sci-Fi
# 4                               Justice League   Action,Adventure,Fantasy
# 5                                      Spectre  Action,Adventure,Thriller
#
#    runtime_minutes         ROI
# 0            136.0  154.667286
# 2            141.0  324.384139
# 3            149.0  582.711400
# 4            120.0  118.648403
# 5            148.0  193.206974

# %%
#How much each genre appears in the list of movies with 100% ROI
print(df_double['genres'].str.contains('Action').sum(),
df_double['genres'].str.contains('Adventure').sum(),
df_double['genres'].str.contains('Fantasy').sum(),
df_double['genres'].str.contains('Drama').sum(),
df_double['genres'].str.contains('Comedy').sum(),
df_double['genres'].str.contains('Sci-Fi').sum(),
df_double['genres'].str.contains('Horror').sum(),
df_double['genres'].str.contains('Romance').sum(),
df_double['genres'].str.contains('Animation').sum(),
df_double['genres'].str.contains('Mystery').sum(),
df_double['genres'].str.contains('Thriller').sum(),
df_double['genres'].str.contains('Crime').sum(),
df_double['genres'].str.contains('War').sum(),
df_double['genres'].str.contains('Western').sum(),
df_double['genres'].str.contains('Music').sum(),
df_double['genres'].str.contains('History').sum(),
df_double['genres'].str.contains('Biography').sum(),
df_double['genres'].str.contains('Documentary').sum(),
df_double['genres'].str.contains('Sports').sum())
# Out:
# 244 222 65 355 294 92 100 108 68 79 138 97 6 2 31 18 64 18 0

# %%
#Remove secondary genres to emphasize primary genre in ROI 100 dataset
df_double['genres']= df_double['genres'].str.split(',').str[0]
df_double.head(50)
# Out:
# <ipython-input-36-2e8a248cd8e8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_double['genres']= df_double['genres'].str.split(',').str[0]
#     id  release_date                                             movie  \
# 0    2          2011       Pirates of the Caribbean: On Stranger Tides
# 2    4          2015                           Avengers: Age of Ultron
# 3    7          2018                            Avengers: Infinity War
# 4    9          2017                                    Justice League
# 5   10          2015                                           Spectre
# 6   11          2012                             The Dark Knight Rises
# 10  15          2010                                           Tangled
# 11  17          2016                        Captain America: Civil War
# 12  18          2016                Batman v Superman: Dawn of Justice
# 13  19          2012                 The Hobbit: An Unexpected Journey
# 14  21          2013               The Hobbit: The Desolation of Smaug
# 15  22          2014         The Hobbit: The Battle of the Five Armies
# 16  23          2017                           The Fate of the Furious
# 17  25          2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 18  27          2012                                      The Avengers
# 19  29          2013                                      Man of Steel
# 20  31          2012                            The Amazing Spider-Man
# 22  33          2017                     Transformers: The Last Knight
# 23  34          2015                                    Jurassic World
# 24  35          2012                                    Men in Black 3
# 25  37          2014                   Transformers: Age of Extinction
# 34  42          2018                                     Black Panther
# 35  44          2018                                     Incredibles 2
# 36  45          2016                      Rogue One: A Star Wars Story
# 37  46          2016                                      Finding Dory
# 38  47          2010                                       Toy Story 3
# 39  48          2013                                        Iron Man 3
# 40  51          2010                               Alice in Wonderland
# 42  52          2012                                           Skyfall
# 43  53          2013                               Monsters University
# 44  54          2013                         Oz the Great and Powerful
# 45  55          2014                        X-Men: Days of Future Past
# 46  56          2014                          The Amazing Spider-Man 2
# 47  57          2011                                            Cars 2
# 48  60          2018       Fantastic Beasts: The Crimes of Grindelwald
# 50  64          2011                    Transformers: Dark of the Moon
# 51  65          2017                                         The Mummy
# 53  67          2015                                         Furious 7
# 54  68          2013                           Star Trek Into Darkness
# 55  69          2013                                       World War Z
# 57  72          2013                                       Pacific Rim
# 61  78          2017                                Kong: Skull Island
# 64  81          2019                                           Aladdin
# 66  82          2017                                    Thor: Ragnarok
# 67  84          2014                                        Maleficent
# 68  85          2016           Fantastic Beasts and Where to Find Them
# 74  93          2016                                 X-Men: Apocalypse
# 75  94          2018                                           The Meg
# 76  95          2014                                  Edge of Tomorrow
# 77  96          2019                                    Captain Marvel
#
#     production_budget  domestic_gross  worldwide_gross  \
# 0           410600000       241063875       1045663875
# 2           330600000       459005868       1403013963
# 3           300000000       678815482       2048134200
# 4           300000000       229024295        655945209
# 5           300000000       200074175        879620923
# 6           275000000       448139099       1084439099
# 10          260000000       200821936        586477240
# 11          250000000       408084349       1140069413
# 12          250000000       330360194        867500281
# 13          250000000       303003568       1017003568
# 14          250000000       258366855        960366855
# 15          250000000       255119788        945577621
# 16          250000000       225764765       1234846267
# 17          230000000       172558876        788241137
# 18          225000000       623279547       1517935897
# 19          225000000       291045518        667999518
# 20          220000000       262030663        757890267
# 22          217000000       130168683        602893340
# 23          215000000       652270625       1648854864
# 24          215000000       179020854        654213485
# 25          210000000       245439076       1104039076
# 34          200000000       700059566       1348258224
# 35          200000000       608581744       1242520711
# 36          200000000       532177324       1049102856
# 37          200000000       486295561       1021215193
# 38          200000000       415004880       1068879522
# 39          200000000       408992272       1215392272
# 40          200000000       334191110       1025491110
# 42          200000000       304360277       1110526981
# 43          200000000       268488329        743588329
# 44          200000000       234770996        490359051
# 45          200000000       233921534        747862775
# 46          200000000       202853933        708996336
# 47          200000000       191450875        560155383
# 48          200000000       159555901        652220086
# 50          195000000       352390543       1123790543
# 51          195000000        80101125        409953905
# 53          190000000       353007020       1518722794
# 54          190000000       228778661        467381584
# 55          190000000       202359711        531514650
# 57          190000000       101802906        411002906
# 61          185000000       168052812        561072059
# 64          182000000       246734314        619234314
# 66          180000000       315058289        846980024
# 67          180000000       241407328        758536735
# 68          180000000       234037575        802402853
# 74          178000000       155442489        542537546
# 75          178000000       145443742        529530715
# 76          178000000       100206256        370541256
# 77          175000000       426525952       1123061550
#
#                                        primary_title     genres  \
# 0        Pirates of the Caribbean: On Stranger Tides     Action
# 2                            Avengers: Age of Ultron     Action
# 3                             Avengers: Infinity War     Action
# 4                                     Justice League     Action
# 5                                            Spectre     Action
# 6                              The Dark Knight Rises     Action
# 10                                           Tangled  Adventure
# 11                        Captain America: Civil War     Action
# 12                Batman v Superman: Dawn of Justice     Action
# 13                 The Hobbit: An Unexpected Journey  Adventure
# 14               The Hobbit: The Desolation of Smaug  Adventure
# 15         The Hobbit: The Battle of the Five Armies  Adventure
# 16                           The Fate of the Furious     Action
# 17  Pirates of the Caribbean: Dead Men Tell No Tales     Action
# 18                                      The Avengers     Action
# 19                                      Man of Steel     Action
# 20                            The Amazing Spider-Man     Action
# 22                     Transformers: The Last Knight     Action
# 23                                    Jurassic World     Action
# 24                                    Men in Black 3     Action
# 25                   Transformers: Age of Extinction     Action
# 34                                     Black Panther     Action
# 35                                     Incredibles 2     Action
# 36                      Rogue One: A Star Wars Story     Action
# 37                                      Finding Dory  Adventure
# 38                                       Toy Story 3  Adventure
# 39                                        Iron Man 3     Action
# 40                               Alice in Wonderland  Adventure
# 42                                           Skyfall     Action
# 43                               Monsters University  Adventure
# 44                         Oz the Great and Powerful  Adventure
# 45                        X-Men: Days of Future Past     Action
# 46                          The Amazing Spider-Man 2     Action
# 47                                            Cars 2  Adventure
# 48       Fantastic Beasts: The Crimes of Grindelwald  Adventure
# 50                    Transformers: Dark of the Moon     Action
# 51                                         The Mummy     Action
# 53                                         Furious 7     Action
# 54                           Star Trek Into Darkness     Action
# 55                                       World War Z     Action
# 57                                       Pacific Rim     Action
# 61                                Kong: Skull Island     Action
# 64                                           Aladdin  Adventure
# 66                                    Thor: Ragnarok     Action
# 67                                        Maleficent     Action
# 68           Fantastic Beasts and Where to Find Them  Adventure
# 74                                 X-Men: Apocalypse     Action
# 75                                           The Meg     Action
# 76                                  Edge of Tomorrow     Action
# 77                                    Captain Marvel     Action
#
#     runtime_minutes         ROI
# 0             136.0  154.667286
# 2             141.0  324.384139
# 3             149.0  582.711400
# 4             120.0  118.648403
# 5             148.0  193.206974
# 6             164.0  294.341491
# 10            100.0  125.568169
# 11            147.0  356.027765
# 12            151.0  247.000112
# 13            169.0  306.801427
# 14            161.0  284.146742
# 15            144.0  278.231048
# 16            136.0  393.938507
# 17            129.0  242.713538
# 18            143.0  574.638176
# 19            143.0  196.888675
# 20            136.0  244.495576
# 22            154.0  177.831032
# 23            124.0  666.909239
# 24            106.0  204.285342
# 25            165.0  425.732893
# 34            134.0  574.129112
# 35            118.0  521.260356
# 36            133.0  424.551428
# 37             97.0  410.607596
# 38            103.0  434.439761
# 39            130.0  507.696136
# 40            108.0  412.745555
# 42            143.0  455.263490
# 43            104.0  271.794164
# 44            130.0  145.179525
# 45            132.0  273.931388
# 46            142.0  254.498168
# 47            106.0  180.077692
# 48            134.0  226.110043
# 50            154.0  476.302843
# 51            110.0  110.232772
# 53            137.0  699.327786
# 54            132.0  145.990307
# 55            116.0  179.744553
# 57            131.0  116.317319
# 61            118.0  203.282194
# 64            128.0  240.238634
# 66            130.0  370.544458
# 67             97.0  321.409297
# 68            132.0  345.779363
# 74            144.0  204.796374
# 75            113.0  197.489166
# 76            113.0  108.169245
# 77            123.0  541.749457

# %%
#Remove secondary genres to emphasize primary genre in cumulative datset
budgets_genres_df['genres']= budgets_genres_df['genres'].str.split(',').str[0]
budgets_genres_df.head(50)
# Out:
#     id  release_date                                             movie  \
# 0    2          2011       Pirates of the Caribbean: On Stranger Tides
# 1    3          2019                                      Dark Phoenix
# 2    4          2015                           Avengers: Age of Ultron
# 3    7          2018                            Avengers: Infinity War
# 4    9          2017                                    Justice League
# 5   10          2015                                           Spectre
# 6   11          2012                             The Dark Knight Rises
# 7   12          2018                           Solo: A Star Wars Story
# 8   13          2013                                   The Lone Ranger
# 9   14          2012                                       John Carter
# 10  15          2010                                           Tangled
# 11  17          2016                        Captain America: Civil War
# 12  18          2016                Batman v Superman: Dawn of Justice
# 13  19          2012                 The Hobbit: An Unexpected Journey
# 14  21          2013               The Hobbit: The Desolation of Smaug
# 15  22          2014         The Hobbit: The Battle of the Five Armies
# 16  23          2017                           The Fate of the Furious
# 17  25          2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 18  27          2012                                      The Avengers
# 19  29          2013                                      Man of Steel
# 20  31          2012                            The Amazing Spider-Man
# 21  32          2012                                        Battleship
# 22  33          2017                     Transformers: The Last Knight
# 23  34          2015                                    Jurassic World
# 24  35          2012                                    Men in Black 3
# 25  37          2014                   Transformers: Age of Extinction
# 34  42          2018                                     Black Panther
# 35  44          2018                                     Incredibles 2
# 36  45          2016                      Rogue One: A Star Wars Story
# 37  46          2016                                      Finding Dory
# 38  47          2010                                       Toy Story 3
# 39  48          2013                                        Iron Man 3
# 40  51          2010                               Alice in Wonderland
# 42  52          2012                                           Skyfall
# 43  53          2013                               Monsters University
# 44  54          2013                         Oz the Great and Powerful
# 45  55          2014                        X-Men: Days of Future Past
# 46  56          2014                          The Amazing Spider-Man 2
# 47  57          2011                                            Cars 2
# 48  60          2018       Fantastic Beasts: The Crimes of Grindelwald
# 49  62          2011                                     Green Lantern
# 50  64          2011                    Transformers: Dark of the Moon
# 51  65          2017                                         The Mummy
# 52  66          2013                             Jack the Giant Slayer
# 53  67          2015                                         Furious 7
# 54  68          2013                           Star Trek Into Darkness
# 55  69          2013                                       World War Z
# 56  70          2013                                  The Great Gatsby
# 57  72          2013                                       Pacific Rim
# 58  73          2015                                 The Good Dinosaur
#
#     production_budget  domestic_gross  worldwide_gross  \
# 0           410600000       241063875       1045663875
# 1           350000000        42762350        149762350
# 2           330600000       459005868       1403013963
# 3           300000000       678815482       2048134200
# 4           300000000       229024295        655945209
# 5           300000000       200074175        879620923
# 6           275000000       448139099       1084439099
# 7           275000000       213767512        393151347
# 8           275000000        89302115        260002115
# 9           275000000        73058679        282778100
# 10          260000000       200821936        586477240
# 11          250000000       408084349       1140069413
# 12          250000000       330360194        867500281
# 13          250000000       303003568       1017003568
# 14          250000000       258366855        960366855
# 15          250000000       255119788        945577621
# 16          250000000       225764765       1234846267
# 17          230000000       172558876        788241137
# 18          225000000       623279547       1517935897
# 19          225000000       291045518        667999518
# 20          220000000       262030663        757890267
# 21          220000000        65233400        313477717
# 22          217000000       130168683        602893340
# 23          215000000       652270625       1648854864
# 24          215000000       179020854        654213485
# 25          210000000       245439076       1104039076
# 34          200000000       700059566       1348258224
# 35          200000000       608581744       1242520711
# 36          200000000       532177324       1049102856
# 37          200000000       486295561       1021215193
# 38          200000000       415004880       1068879522
# 39          200000000       408992272       1215392272
# 40          200000000       334191110       1025491110
# 42          200000000       304360277       1110526981
# 43          200000000       268488329        743588329
# 44          200000000       234770996        490359051
# 45          200000000       233921534        747862775
# 46          200000000       202853933        708996336
# 47          200000000       191450875        560155383
# 48          200000000       159555901        652220086
# 49          200000000       116601172        219535492
# 50          195000000       352390543       1123790543
# 51          195000000        80101125        409953905
# 52          195000000        65187603        197687603
# 53          190000000       353007020       1518722794
# 54          190000000       228778661        467381584
# 55          190000000       202359711        531514650
# 56          190000000       144840419        351040419
# 57          190000000       101802906        411002906
# 58          187500000       123087120        333771037
#
#                                        primary_title     genres  \
# 0        Pirates of the Caribbean: On Stranger Tides     Action
# 1                                       Dark Phoenix     Action
# 2                            Avengers: Age of Ultron     Action
# 3                             Avengers: Infinity War     Action
# 4                                     Justice League     Action
# 5                                            Spectre     Action
# 6                              The Dark Knight Rises     Action
# 7                            Solo: A Star Wars Story     Action
# 8                                    The Lone Ranger     Action
# 9                                        John Carter     Action
# 10                                           Tangled  Adventure
# 11                        Captain America: Civil War     Action
# 12                Batman v Superman: Dawn of Justice     Action
# 13                 The Hobbit: An Unexpected Journey  Adventure
# 14               The Hobbit: The Desolation of Smaug  Adventure
# 15         The Hobbit: The Battle of the Five Armies  Adventure
# 16                           The Fate of the Furious     Action
# 17  Pirates of the Caribbean: Dead Men Tell No Tales     Action
# 18                                      The Avengers     Action
# 19                                      Man of Steel     Action
# 20                            The Amazing Spider-Man     Action
# 21                                        Battleship     Action
# 22                     Transformers: The Last Knight     Action
# 23                                    Jurassic World     Action
# 24                                    Men in Black 3     Action
# 25                   Transformers: Age of Extinction     Action
# 34                                     Black Panther     Action
# 35                                     Incredibles 2     Action
# 36                      Rogue One: A Star Wars Story     Action
# 37                                      Finding Dory  Adventure
# 38                                       Toy Story 3  Adventure
# 39                                        Iron Man 3     Action
# 40                               Alice in Wonderland  Adventure
# 42                                           Skyfall     Action
# 43                               Monsters University  Adventure
# 44                         Oz the Great and Powerful  Adventure
# 45                        X-Men: Days of Future Past     Action
# 46                          The Amazing Spider-Man 2     Action
# 47                                            Cars 2  Adventure
# 48       Fantastic Beasts: The Crimes of Grindelwald  Adventure
# 49                                     Green Lantern     Action
# 50                    Transformers: Dark of the Moon     Action
# 51                                         The Mummy     Action
# 52                             Jack the Giant Slayer  Adventure
# 53                                         Furious 7     Action
# 54                           Star Trek Into Darkness     Action
# 55                                       World War Z     Action
# 56                                  The Great Gatsby      Drama
# 57                                       Pacific Rim     Action
# 58                                 The Good Dinosaur  Adventure
#
#     runtime_minutes         ROI
# 0             136.0  154.667286
# 1             113.0  -57.210757
# 2             141.0  324.384139
# 3             149.0  582.711400
# 4             120.0  118.648403
# 5             148.0  193.206974
# 6             164.0  294.341491
# 7             135.0   42.964126
# 8             150.0   -5.453776
# 9             132.0    2.828400
# 10            100.0  125.568169
# 11            147.0  356.027765
# 12            151.0  247.000112
# 13            169.0  306.801427
# 14            161.0  284.146742
# 15            144.0  278.231048
# 16            136.0  393.938507
# 17            129.0  242.713538
# 18            143.0  574.638176
# 19            143.0  196.888675
# 20            136.0  244.495576
# 21            131.0   42.489871
# 22            154.0  177.831032
# 23            124.0  666.909239
# 24            106.0  204.285342
# 25            165.0  425.732893
# 34            134.0  574.129112
# 35            118.0  521.260356
# 36            133.0  424.551428
# 37             97.0  410.607596
# 38            103.0  434.439761
# 39            130.0  507.696136
# 40            108.0  412.745555
# 42            143.0  455.263490
# 43            104.0  271.794164
# 44            130.0  145.179525
# 45            132.0  273.931388
# 46            142.0  254.498168
# 47            106.0  180.077692
# 48            134.0  226.110043
# 49            114.0    9.767746
# 50            154.0  476.302843
# 51            110.0  110.232772
# 52            114.0    1.378258
# 53            137.0  699.327786
# 54            132.0  145.990307
# 55            116.0  179.744553
# 56            143.0   84.758115
# 57            131.0  116.317319
# 58             93.0   78.011220

# %%
print(budgets_genres_df['genres'].value_counts('action'))
print(df_double['genres'].value_counts('action'))
# Out:
# Action         0.283343
# Comedy         0.205691
# Drama          0.177830
# Adventure      0.099585
# Biography      0.072318
# Horror         0.058684
# Crime          0.049200
# Documentary    0.026082
# Animation      0.006520
# Thriller       0.005335
# Family         0.003557
# Mystery        0.002964
# Fantasy        0.002964
# Sci-Fi         0.002371
# Romance        0.001186
# Sport          0.000593
# Western        0.000593
# Music          0.000593
# Musical        0.000593
# Name: genres, dtype: float64
# Action         0.306918
# Comedy         0.207547
# Drama          0.161006
# Adventure      0.122013
# Horror         0.069182
# Biography      0.067925
# Crime          0.032704
# Documentary    0.013836
# Animation      0.006289
# Mystery        0.003774
# Thriller       0.002516
# Romance        0.002516
# Fantasy        0.002516
# Family         0.001258
# Name: genres, dtype: float64

# %% [markdown]
# ### Comparison of cumulative genre dataset with ROI 100 dataset
# Action, adventure, and horror genres were the only three genres out of nineteen to see a material jump (more than 1%) in market share when the amongst all films that enjoyed at least a 100% ROI (doubled their money).

# %%
fig, ax= plt.subplots(figsize=(25,15))
a= df_double['genres']
b= budgets_genres_df['genres']
colors= ['b', 'g']
labels= ['ROI=>100', 'Total']
ax.hist([a,b], bins=19, color= colors, edgecolor='black', label= labels )
ax.set_xlabel('Genre Breakdown', fontsize=20)
ax.set_ylabel('Frequency', fontsize=20)
ax.set_title('Genre Distribution', fontsize= 20)
ax.legend(fontsize= 20)

# %% [markdown]
# While the most common genres produced are action, comedy, and drama and it is these three genres that appear most in the 100% ROI dataset; it is the action, adventure, and horror genre films that gained the most market share off all the movies that returned double their investment. Action went from 28.3% to 30.7%, Adventure went from 10.0% to 12.2%, and Horror went from 5.9% to 6.9%.

# %%
#Checking the average ROI of each genre
budgets_genres_df.groupby('genres')['ROI'].mean()
# Out:
# genres
# Action          161.603816
# Adventure       206.547539
# Animation       179.095483
# Biography       221.905949
# Comedy          188.280812
# Crime            80.582147
# Documentary      89.314064
# Drama           249.796254
# Family           59.241567
# Fantasy         119.435807
# Horror         1231.184085
# Music           -49.539411
# Musical         -90.503464
# Mystery         193.364429
# Romance         616.210393
# Sci-Fi          -91.006700
# Sport           -69.760511
# Thriller         20.853374
# Western        -100.000000
# Name: ROI, dtype: float64

# %%
#Horror films have the highest average ROI by a significant margin
budgets_genres_df.groupby(['genres'])['ROI'].mean().plot(kind='barh', figsize=(15,10), edgecolor='black')
plt.xlabel('ROI %', fontsize=20)
plt.ylabel('Genres', fontsize=20)
plt.title('Average ROI by Genre', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Average ROI by Genre')

# %%
#Horror films have an average budget of $10.05M
budgets_genres_df.groupby('genres')['production_budget'].mean()
# Out:
# genres
# Action         7.449464e+07
# Adventure      7.328515e+07
# Animation      4.172727e+07
# Biography      2.277434e+07
# Comedy         1.867091e+07
# Crime          2.025422e+07
# Documentary    1.260661e+07
# Drama          1.593778e+07
# Family         2.893333e+07
# Fantasy        2.580000e+07
# Horror         1.049058e+07
# Music          1.800000e+07
# Musical        5.600000e+06
# Mystery        3.167000e+07
# Romance        2.760000e+07
# Sci-Fi         8.130000e+06
# Sport          1.900000e+07
# Thriller       1.031389e+07
# Western        1.000000e+06
# Name: production_budget, dtype: float64

# %%
#Average budget is $39.35M, almost 4x Horror average budgets.
budgets_genres_df['production_budget'].describe()
# Out:
# count    1.687000e+03
# mean     3.934642e+07
# std      5.380370e+07
# min      1.400000e+03
# 25%      5.000000e+06
# 50%      1.950000e+07
# 75%      4.800000e+07
# max      4.106000e+08
# Name: production_budget, dtype: float64

# %%
#Average ROI of all genres is significantly below Horror genre.
budgets_genres_df['ROI'].describe()
# Out:
# count     1687.000000
# mean       246.848007
# std       1167.491655
# min       -100.000000
# 25%        -65.378312
# 50%         80.550905
# 75%        278.572344
# max      41556.474000
# Name: ROI, dtype: float64

# %%
budgets_genres_df.groupby('genres')['production_budget'].mean().plot(kind= 'barh', figsize=(15,7))
plt.xlabel('Average Production Budget in Millions', fontsize=15)
plt.ylabel('Genres', fontsize=15)
plt.title('Average Production Budget by Genre', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Average Production Budget by Genre')

# %% [markdown]
# ## Evaluation: Runtime
#
# Perhaps the most overpowering statistic of them all, the average ROI of horror films is multitudes higher then the second best performing genre (Romance).  Although action and adventure films show greater representation along with horror in the 100% ROI dataset, it is the horror films that offer the most upside for producers by a significant margin.
#
# Horror films also have amongst the lowest production budgets, which is likely a key contributor to their average ROI dominance but audiences definitely seem to have great demand for horror film independent of the size of their production budgets.

# %% [markdown]
# ## Data Modeling and Cleaning: Production Budgets

# %%
movie_budgets.dtypes
# Out:
# id                    int64
# release_date          int32
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
#genre_budgets_df is substitued by ROI_df as runtime minutes and genre is not need for this analysis.
#Movies made before 2010 are now included
ROI_df=movie_budgets

# %%
#Drop $ to worldwide gross to convert to int
ROI_df['production_budget']= movie_budgets['production_budget'].map(lambda x: x[1:])
ROI_df['domestic_gross']= movie_budgets['domestic_gross'].map(lambda x: x[1:])
ROI_df['worldwide_gross']= movie_budgets['worldwide_gross'].map(lambda x: x[1:])
ROI_df
# Out:
#       id  release_date                                        movie  \
# 0      1          2009                                       Avatar
# 1      2          2011  Pirates of the Caribbean: On Stranger Tides
# 2      3          2019                                 Dark Phoenix
# 3      4          2015                      Avengers: Age of Ultron
# 4      5          2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78          2018                                       Red 11
# 5778  79          1999                                    Following
# 5779  80          2005                Return to the Land of Wonders
# 5780  81          2015                         A Plague So Pleasant
# 5781  82          2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0          425,000,000    760,507,625   2,776,345,279
# 1          410,600,000    241,063,875   1,045,663,875
# 2          350,000,000     42,762,350     149,762,350
# 3          330,600,000    459,005,868   1,403,013,963
# 4          317,000,000    620,181,382   1,316,721,747
# ...                ...            ...             ...
# 5777             7,000              0               0
# 5778             6,000         48,482         240,495
# 5779             5,000          1,338           1,338
# 5780             1,400              0               0
# 5781             1,100        181,041         181,041
#
# [5782 rows x 6 columns]

# %%
#ROI_df['production_budget']= ROI_df['production_budget'].str.replace(',','').astype(int)
#ROI_df['domestic_gross']= ROI_df['domestic_gross'].str.replace(',','').astype(int)
#ROI_df['worldwide_gross']= ROI_df['worldwide_gross'].str.replace(',','').astype(int)

# %%
#Convert data type to int
ROI_df['production_budget']= ROI_df['production_budget'].str.replace(',','').astype(int)
ROI_df['domestic_gross']= ROI_df['domestic_gross'].str.replace(',','').astype(int)
ROI_df
# Out:
#       id  release_date                                        movie  \
# 0      1          2009                                       Avatar
# 1      2          2011  Pirates of the Caribbean: On Stranger Tides
# 2      3          2019                                 Dark Phoenix
# 3      4          2015                      Avengers: Age of Ultron
# 4      5          2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78          2018                                       Red 11
# 5778  79          1999                                    Following
# 5779  80          2005                Return to the Land of Wonders
# 5780  81          2015                         A Plague So Pleasant
# 5781  82          2005                            My Date With Drew
#
#       production_budget  domestic_gross worldwide_gross
# 0             425000000       760507625   2,776,345,279
# 1             410600000       241063875   1,045,663,875
# 2             350000000        42762350     149,762,350
# 3             330600000       459005868   1,403,013,963
# 4             317000000       620181382   1,316,721,747
# ...                 ...             ...             ...
# 5777               7000               0               0
# 5778               6000           48482         240,495
# 5779               5000            1338           1,338
# 5780               1400               0               0
# 5781               1100          181041         181,041
#
# [5782 rows x 6 columns]

# %%
ROI_df.dtypes
# Out:
# id                    int64
# release_date          int32
# movie                object
# production_budget     int32
# domestic_gross        int32
# worldwide_gross      object
# dtype: object

# %%
#convert data to int
import sys
ROI_df['worldwide_gross']= ROI_df['worldwide_gross'].astype('int64')

# %%
ROI_df.dtypes
# Out:
# id                    int64
# release_date          int32
# movie                object
# production_budget     int32
# domestic_gross        int32
# worldwide_gross       int64
# dtype: object

# %%
#Creating ROI column
ROI_df['ROI']= ((ROI_df['worldwide_gross'] / ROI_df['production_budget']-1)*100)
ROI_df
# Out:
#       id  release_date                                        movie  \
# 0      1          2009                                       Avatar
# 1      2          2011  Pirates of the Caribbean: On Stranger Tides
# 2      3          2019                                 Dark Phoenix
# 3      4          2015                      Avengers: Age of Ultron
# 4      5          2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78          2018                                       Red 11
# 5778  79          1999                                    Following
# 5779  80          2005                Return to the Land of Wonders
# 5780  81          2015                         A Plague So Pleasant
# 5781  82          2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross           ROI
# 0             425000000       760507625       2776345279    553.257713
# 1             410600000       241063875       1045663875    154.667286
# 2             350000000        42762350        149762350    -57.210757
# 3             330600000       459005868       1403013963    324.384139
# 4             317000000       620181382       1316721747    315.369636
# ...                 ...             ...              ...           ...
# 5777               7000               0                0   -100.000000
# 5778               6000           48482           240495   3908.250000
# 5779               5000            1338             1338    -73.240000
# 5780               1400               0                0   -100.000000
# 5781               1100          181041           181041  16358.272727
#
# [5782 rows x 7 columns]

# %%
ROI_df['production_budget'].describe()
# Out:
# count    5.782000e+03
# mean     3.158776e+07
# std      4.181208e+07
# min      1.100000e+03
# 25%      5.000000e+06
# 50%      1.700000e+07
# 75%      4.000000e+07
# max      4.250000e+08
# Name: production_budget, dtype: float64

# %%
print(ROI_df.loc[ROI_df['production_budget']<= 5000000, 'ROI'].mean())
print(ROI_df.loc[ROI_df['production_budget']<= 5000000, 'ROI'].median())
# Out:
# 896.9387294899469
# -3.525900000000004

# %%
ROI_df= ROI_df.drop(ROI_df[ROI_df['production_budget']<= 500000].index)
#Below 500k budget would be unbefitting for Microsoft's brand.  Removing these entries also take out ROI outliers, adult films
# and film projects that had their budgets artificially deflated due to cast favors/deferrals.

# %%
print(ROI_df.loc[ROI_df['production_budget']<= 5000000, 'ROI'].mean())
print(ROI_df.loc[ROI_df['production_budget']<= 5000000, 'ROI'].median())
# Out:
# 500.26431033545634
# 10.055459999999993

# %%
ROI_df.sort_values(by='ROI', ascending=False).tail(60)

# %%
#Average and Median definitions for each class of movie budget (low budget, mid-level budget, big budget, blockbuster budget)
avg_lb_ROI= ROI_df.loc[ROI_df['production_budget']<= 5000000, 'ROI'].mean()
med_lb_ROI= ROI_df.loc[ROI_df['production_budget']<= 5000000, 'ROI'].median()
avg_mb_ROI= ROI_df.loc[(ROI_df['production_budget']>= 5000000) & (ROI_df['production_budget']<= 50000000), 'ROI'].mean()
med_mb_ROI= ROI_df.loc[(ROI_df['production_budget']>= 5000000) & (ROI_df['production_budget']<= 50000000), 'ROI'].median()
avg_bb_ROI= ROI_df.loc[(ROI_df['production_budget']>= 50000000) & (ROI_df['production_budget']<= 100000000), 'ROI'].mean()
med_bb_ROI= ROI_df.loc[(ROI_df['production_budget']>= 50000000) & (ROI_df['production_budget']<100000000), 'ROI'].median()
avg_BBb_ROI= ROI_df.loc[ROI_df['production_budget']>= 100000000, 'ROI'].mean()
med_BBb_ROI= ROI_df.loc[ROI_df['production_budget']>= 100000000, 'ROI'].median()
print('Average ROI by tier:', avg_lb_ROI, avg_mb_ROI, avg_bb_ROI, avg_BBb_ROI)
print('Median ROI by tier:', med_lb_ROI, med_mb_ROI, med_bb_ROI, med_BBb_ROI)
# Out:
# Average ROI by tier: 500.26431033545634 210.84344666066235 154.66166089499376 208.90921347677798
# Median ROI by tier: 10.055459999999993 67.15202333333335 95.5444762605042 175.0417226909091

# %%
#Creating the 4 tiered ROI dfs
lb_ROI=ROI_df[ROI_df['production_budget']<= 5000000]
mb_ROI=ROI_df[(ROI_df['production_budget']>= 5000000) & (ROI_df['production_budget']<= 50000000)]
bb_ROI= ROI_df[(ROI_df['production_budget']>= 50000000) & (ROI_df['production_budget']<= 100000000)]
BBb_ROI= ROI_df[ROI_df['production_budget']>= 100000000]

# %%
print(lb_ROI.describe())
print(mb_ROI.describe())
print(bb_ROI.describe())
print(BBb_ROI.describe())
# Out:
#                 id  release_date  production_budget  domestic_gross  \
# count  1181.000000   1181.000000       1.181000e+03    1.181000e+03
# mean     50.701101   2000.770533       2.663755e+06    8.758829e+06
# std      29.057417     18.436764       1.430094e+06    2.062460e+07
# min       1.000000   1925.000000       5.461730e+05    0.000000e+00
# 25%      25.000000   1998.000000       1.300000e+06    1.299600e+04
# 50%      51.000000   2007.000000       2.500000e+06    1.001437e+06
# 75%      76.000000   2013.000000       4.000000e+06    8.025872e+06
# max     100.000000   2019.000000       5.000000e+06    2.414382e+08
#
#        worldwide_gross           ROI
# count     1.181000e+03   1181.000000
# mean      1.383053e+07    500.264310
# std       3.434881e+07   2071.798969
# min       0.000000e+00   -100.000000
# 25%       7.124800e+04    -96.822250
# 50%       2.419669e+06     10.055460
# 75%       1.205192e+07    380.773200
# max       3.905252e+08  41283.333333
#                 id  release_date  production_budget  domestic_gross  \
# count  3319.000000   3319.000000       3.319000e+03    3.319000e+03
# mean     50.731847   2004.121723       2.139261e+07    3.234070e+07
# std      28.952380     10.707701       1.277872e+07    4.159892e+07
# min       1.000000   1944.000000       5.000000e+06    0.000000e+00
# 25%      26.000000   1999.000000       1.000000e+07    4.698456e+06
# 50%      51.000000   2006.000000       1.900000e+07    1.898579e+07
# 75%      76.000000   2012.000000       3.000000e+07    4.400118e+07
# max     100.000000   2020.000000       5.000000e+07    4.609980e+08
#
#        worldwide_gross          ROI
# count     3.319000e+03  3319.000000
# mean      5.865711e+07   210.843447
# std       8.058150e+07   511.421204
# min       0.000000e+00  -100.000000
# 25%       1.013022e+07   -43.033569
# 50%       3.101335e+07    67.152023
# 75%       7.437993e+07   260.471666
# max       7.929653e+08  7452.050724
#                id  release_date  production_budget  domestic_gross  \
# count  845.000000    845.000000       8.450000e+02    8.450000e+02
# mean    51.443787   2005.791716       6.862114e+07    7.864612e+07
# std     29.283477      7.202828       1.498833e+07    6.859277e+07
# min      1.000000   1978.000000       5.000000e+07    0.000000e+00
# 25%     26.000000   2000.000000       5.500000e+07    3.370016e+07
# 50%     52.000000   2005.000000       6.500000e+07    5.962396e+07
# 75%     77.000000   2012.000000       8.000000e+07    1.030685e+08
# max    100.000000   2020.000000       1.000000e+08    4.412262e+08
#
#        worldwide_gross          ROI
# count     8.450000e+02   845.000000
# mean      1.761958e+08   154.661661
# std       1.697466e+08   235.788437
# min       0.000000e+00  -100.000000
# 25%       6.652053e+07    -1.772983
# 50%       1.314928e+08    95.746064
# 75%       2.214689e+08   225.752374
# max       1.160336e+09  1548.908863
#                id  release_date  production_budget  domestic_gross  \
# count  406.000000    406.000000       4.060000e+02    4.060000e+02
# mean    49.805419   2010.263547       1.523057e+08    1.743662e+08
# std     29.244631      5.884653       4.891461e+07    1.322064e+08
# min      1.000000   1991.000000       1.000000e+08    0.000000e+00
# 25%     24.250000   2006.000000       1.150000e+08    8.343070e+07
# 50%     50.000000   2011.000000       1.445000e+08    1.393894e+08
# 75%     75.000000   2015.000000       1.750000e+08    2.271726e+08
# max    100.000000   2020.000000       4.250000e+08    9.366622e+08
#
#        worldwide_gross          ROI
# count     4.060000e+02   406.000000
# mean      4.831972e+08   208.909213
# std       3.574227e+08   184.085482
# min       0.000000e+00  -100.000000
# 25%       2.371714e+08    76.173731
# 50%       3.829148e+08   175.041723
# 75%       6.513426e+08   315.222350
# max       2.776345e+09  1004.104198

# %%
#Scatterplot showing relationship between low budget films ($.5M-$5M) and ROI
fig, ax =plt.subplots(figsize=(15,10))
ax.scatter(x=ROI_df['production_budget'], y=ROI_df['ROI'], color= 'purple',)
plt.axhline(y=avg_lb_ROI, color= 'green', linewidth=4)
plt.axhline(y=med_lb_ROI, color= 'red', linewidth=4)
ax.set_title('Low Budget Films and ROI')
ax.set_xlabel('Production Budget (in millions)')
ax.set_ylabel('Film ROI')
ax.set_xlim(0, 5000000)
ax.set_ylim(-1,20000)
ax.yaxis.set_major_formatter('{x:1}%')

# %%
#Correlation with low budget film's production budget and ROI
lb_ROI['production_budget'].corr(lb_ROI['ROI'])
# Out:
# -0.07293181822868648

# %%
#Scatterplot showing relationship between mid-level budget films ($5M-$50M) and ROI
fig, ax =plt.subplots(figsize=(15,10))
ax.scatter(x=ROI_df['production_budget'], y=ROI_df['ROI'], color= 'purple')
plt.axhline(y=avg_mb_ROI, color= 'green', linewidth=4)
plt.axhline(y=med_mb_ROI, color= 'red', linewidth=4)
ax.set_title('Mid-level Budget Films and ROI')
ax.set_xlabel('Production Budget')
ax.set_ylabel('Film ROI')
ax.set_xlim(5000000, 50000000)
ax.set_ylim(-1,8000)
ax.yaxis.set_major_formatter('{x:1}%')

# %%
#correlation with Mid-level produciton budgets and ROI
mb_ROI['production_budget'].corr(mb_ROI['ROI'])
# Out:
# -0.120005936296624

# %%
#Scatterplot showing relationship between big budget films ($50M-$100M) and ROI
fig, ax =plt.subplots(figsize=(15,10))
ax.scatter(x=ROI_df['production_budget'], y=ROI_df['ROI'], color= 'purple')
plt.axhline(y=avg_bb_ROI, color= 'green', linewidth=4)
plt.axhline(y=med_bb_ROI, color= 'red', linewidth=4)
ax.set_title('Big Budget Films and ROI')
ax.set_xlabel('Production Budget')
ax.set_ylabel('Film ROI')
ax.set_xlim(50000000, 100000000)
ax.set_ylim(-1,2000)
ax.yaxis.set_major_formatter('{x:1}%')

# %%
#correlation with big produciton budgets and ROI
bb_ROI['production_budget'].corr(bb_ROI['ROI'])
# Out:
# 0.04090902499936554

# %%
#Scatterplot showing relationship between blockbuster budget films ($100M-$500M) and ROI
fig, ax =plt.subplots(figsize=(15,10))
ax.scatter(x=ROI_df['production_budget'], y=ROI_df['ROI'], color= 'purple')
plt.axhline(y=avg_BBb_ROI, color= 'green', linewidth=4)
plt.axhline(y=med_BBb_ROI, color= 'red', linewidth=4)
ax.set_title('Blockbuster Budget Films and ROI')
ax.set_xlabel('Production Budget')
ax.set_ylabel('Film ROI')
ax.set_xlim(100000000, 500000000)
ax.set_ylim(-1,2000)
ax.yaxis.set_major_formatter('{x:1}%')

# %%
#correlation with Blockbuster produciton budgets and ROI
BBb_ROI['production_budget'].corr(BBb_ROI['ROI'])
# Out:
# 0.1415115027281887

# %% [markdown]
# As production budget tiers get larger, so does its correlation with ROI.

# %%
#How does budget correlate with world-wide gross vs ROI
print(budgets_genres_df['production_budget'].corr(budgets_genres_df['worldwide_gross']))
print(budgets_genres_df['production_budget'].corr(budgets_genres_df['ROI']))
# Out:
# 0.7910789831247879
# -0.020878068027175862

# %%
#How does low budget tier compare to its counterpart in ROI 100 df?
y3= lb_ROI[lb_ROI['ROI']>=100]['production_budget']
y4= lb_ROI['production_budget']
y5= mb_ROI[mb_ROI['ROI']>=100]['production_budget']
y6= mb_ROI['production_budget']
y7= bb_ROI[bb_ROI['ROI']>=100]['production_budget']
y8= bb_ROI['production_budget']
y9= BBb_ROI[BBb_ROI['ROI']>=100]['production_budget']
y10= BBb_ROI['production_budget']
colors= ['b','g']
labels= ['ROI=>100', 'Total']
fig, ax = plt.subplots(figsize=(15,10))
ax.hist([y3,y4], color= colors, label= labels, edgecolor= 'black')
plt.xticks()
ax.set_xlabel('Production Budget', fontsize=20)
ax.set_ylabel('Frequency', fontsize=20)
ax.set_title('Double ROI stats for Low Budget Films', fontsize=20)
ax.legend(fontsize=20)

# %%
#How does Blockbuster budget compare to its counterpart in ROI 100 DF
colors= ['r','purple']
labels= ['ROI=>100', 'Total']
fig, ax = plt.subplots(figsize=(15,10))
ax.hist([y9,y10], color= colors, label= labels, edgecolor= 'black')
plt.xticks()
ax.set_xlabel('Production Budget', fontsize=20)
ax.set_ylabel('Frequency', fontsize=20)
ax.set_title('Double ROI stats for Blockbuster Budget Films', fontsize=20)
ax.legend(fontsize=20)

# %%
# Each tier's odds to achieve a 100% ROI or doubling of investment back.
print('Low Budget Movie odds of Double:', y3.count()/y4.count())
print('Mid-Level Budget Movie odds of Double:', y5.count()/y6.count())
print('Big Budget Movie odds of Double:', y7.count()/y8.count())
print('Blockbuster Budget Movie odds of Double:', y9.count()/y10.count())
# Out:
# Low Budget Movie odds of Double: 0.4072819644369179
# Mid-Level Budget Movie odds of Double: 0.44471226272973785
# Big Budget Movie odds of Double: 0.4911242603550296
# Blockbuster Budget Movie odds of Double: 0.6847290640394089

# %%
print('Average ROI by tier:', avg_lb_ROI, avg_mb_ROI, avg_bb_ROI, avg_BBb_ROI)
print('Median ROI by tier:', med_lb_ROI, med_mb_ROI, med_bb_ROI, med_BBb_ROI)
# Out:
# Average ROI by tier: 500.26431033545634 210.84344666066235 154.66166089499376 208.90921347677798
# Median ROI by tier: 10.055459999999993 67.15202333333335 95.5444762605042 175.0417226909091

# %% [markdown]
# ## Evaluation: Production Budget
# The lowest budget tier has the highest average ROI and lowest median ROI while the largest budger tier has the second lowest average ROI and highest median ROI.
#
# Low budget movies are inherently riskier than larger movies as their median return is only 10% but they also tend to offer the largest upside as hits really skew the average ROI up.  The safest investment is the blockbuster budget tier where the average returns aren't the best but the median value is the highest suggesting less volatility and a safer floor.  Blockbuster tier movies also have the lowest ROI standard deviation while low budget films have the highest.
#
# Blockbuster movies have a significantly higher chance to achieve a 100% ROI than all the other tiers. 68.5% of blockbuster tiered movies achieved a 100% ROI as compared to a 40.1% of low budget movies.
#
# Despite the decreased volatility of blockbuster tier movies, the average ROI stat disparity cannot be ignored and Microsoft's business model would be best served producing a plethora of low budgets films and playings the odds for making a hit movie to maximize their investment return.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Assuming the investment object for Microsoft is to start a movie studio that will produce a slate of movies (not just a single film), they should focus their investment to a specific niche of movies that will maximize ROI.  While there is a direct correlation between production budget and worldwide gross, it is the low budget movies ($.5M - $5m) that prove to be the most profitable by a significant margin.  The horror genre has a far higher average ROI than any other genre.  Film runtime is likely dependent on other variables such as genre and production budget and shouldn't be a factor in decision making
#
# Low budget movies have the highest expected average return on investment.
# Production budget has a large correlation to worldwide theatrical gross.
# The horror genre shows the most resilieince to requiring a large production budget in order to get a sizeable theatrical gross.
# Microsoft needs to focus on low budget horror films to maximize ROI.
